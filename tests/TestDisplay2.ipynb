# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 0.80</span>
#         </div>

# %%
dd = sqlContext.createDataFrame([
 ("a", "Alice", 34, 60, 1),
 ("b", "Bob", 36, 70, 2),
 ("c", "Charlie", 30, 99, 6),
 ("d", "Hector", 75, 87, 9),
 ("a", "Alice", 34, 44, 12),
 ("b", "Bob", 36, 109, 33),
 ("c", "Charlie", 30, 56, 77),
 ("d", "Hector", 75, 99, 2),
 ("a", "Alice", 34, 68, 7),
 ("b", "Bob", 36, 156, 54),
 ("c", "Charlie", 30, 89, 23),
 ("d", "Hector", 75, 64, 88),
 ("a", "Alice", 34, 45, 44),
 ("b", "Bob", 36, 97, 33),
 ("c", "Charlie", 30, 85, 41),
 ("d", "Hector", 75, 79, 6),
 ("a", "Alice", 34, 63, 9),
 ("b", "Bob", 36, 100, 28),
 ("c", "Charlie", 30, 85, 12),
 ("d", "Hector", 75, 73, 9)
], ["id", "name", "age", "weight", "something"])

dd.count()
# Out:
# 20

# %%
#SKIP_COMPARE_OUTPUT
display(dd, gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
display(dd,cell_id='B716869003B949508DC5DC4DFAD7D718',showLegend='true',stacked='true',rowCount='100',staticFigure='false',aggregation='SUM',handlerId='histogram',valueFields='age',keyFields='weight',nostore_cw='1098',nostore_bokeh='false',prefix='693de96c',mpld3='true',nostore_figureOnly='true')
# Out:
# <style>
#
# </style>
#
# <div id="fig_el5200847210610088342837376"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#        // don't remove this comment
# mpld3.register_plugin("dialog", DialogPlugin);
# DialogPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DialogPlugin.prototype.constructor = DialogPlugin;
# DialogPlugin.prototype.requiredProps = ["handlerId"];
# function DialogPlugin(fig, props) {
#     mpld3.Plugin.call(this, fig, props);
#     var DialogPluginButton = mpld3.ButtonFactory({
#         buttonID: "DialogPlugin",
#         sticky: false,
# ...

# %%
display(dd,cell_id='B716869003B949508DC5DC4DFAD7D718',showLegend='true',stacked='true',rowCount='100',staticFigure='false',aggregation='SUM',handlerId='scatterPlot',valueFields='age',keyFields='weight',nostore_cw='1098',nostore_bokeh='false',prefix='4e6c0e62',mpld3='true',nostore_figureOnly='true')
# Out:
# <style>
#
# </style>
#
# <div id="fig_el5200847238818087707513114"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#        // don't remove this comment
# mpld3.register_plugin("dialog", DialogPlugin);
# DialogPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DialogPlugin.prototype.constructor = DialogPlugin;
# DialogPlugin.prototype.requiredProps = ["handlerId"];
# function DialogPlugin(fig, props) {
#     mpld3.Plugin.call(this, fig, props);
#     var DialogPluginButton = mpld3.ButtonFactory({
#         buttonID: "DialogPlugin",
#         sticky: false,
# ...

# %%
display(dd,cell_id='B716869003B949508DC5DC4DFAD7D718',showLegend='true',stacked='true',rowCount='100',staticFigure='false',aggregation='SUM',handlerId='lineChart',valueFields='age',keyFields='weight',nostore_cw='1098',nostore_bokeh='false',prefix='7905a373',mpld3='true',nostore_figureOnly='true')
# Out:
# <style>
#
# </style>
#
# <div id="fig_el5200847238526885581398447"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#        // don't remove this comment
# mpld3.register_plugin("dialog", DialogPlugin);
# DialogPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DialogPlugin.prototype.constructor = DialogPlugin;
# DialogPlugin.prototype.requiredProps = ["handlerId"];
# function DialogPlugin(fig, props) {
#     mpld3.Plugin.call(this, fig, props);
#     var DialogPluginButton = mpld3.ButtonFactory({
#         buttonID: "DialogPlugin",
#         sticky: false,
# ...
