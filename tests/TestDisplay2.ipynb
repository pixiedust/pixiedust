# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 0.80</span>
#         </div>

# %%
dd = sqlContext.createDataFrame([
 ("a", "Alice", 34, 60, 1),
 ("b", "Bob", 36, 70, 2),
 ("c", "Charlie", 30, 99, 6),
 ("d", "Hector", 75, 87, 9),
 ("a", "Alice", 34, 44, 12),
 ("b", "Bob", 36, 109, 33),
 ("c", "Charlie", 30, 56, 77),
 ("d", "Hector", 75, 99, 2),
 ("a", "Alice", 34, 68, 7),
 ("b", "Bob", 36, 156, 54),
 ("c", "Charlie", 30, 89, 23),
 ("d", "Hector", 75, 64, 88),
 ("a", "Alice", 34, 45, 44),
 ("b", "Bob", 36, 97, 33),
 ("c", "Charlie", 30, 85, 41),
 ("d", "Hector", 75, 79, 6),
 ("a", "Alice", 34, 63, 9),
 ("b", "Bob", 36, 100, 28),
 ("c", "Charlie", 30, 85, 12),
 ("d", "Hector", 75, 73, 9)
], ["id", "name", "age", "weight", "something"])

dd.count()
# Out:
# 20

# %%
#SKIP_COMPARE_OUTPUT
display(dd, gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><div id="chartFigureec944803" class="pd_save is-viewer-good">
#
#
# <style>
#
# </style>
#
# ...

# %%
display(dd,cell_id='05B8C2382F454DA69B9AA9E78502B118',showLegend='true',stacked='true',rowCount='100',staticFigure='false',mpld3='true',aggregation='SUM',handlerId='lineChart',valueFields='age',keyFields='weight',nostore_cw='1098',nostore_bokeh='false',prefix='e4a250f6')
# Out:
# <script>
# $("#mapOptionse4a250f6").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...

# %%
display(dd,cell_id='05B8C2382F454DA69B9AA9E78502B118',showLegend='true',stacked='true',rowCount='100',staticFigure='false',mpld3='true',aggregation='SUM',handlerId='scatterPlot',valueFields='age',keyFields='weight',nostore_cw='1098',nostore_bokeh='false',prefix='0c39b597')
# Out:
# <script>
# $("#mapOptions0c39b597").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...

# %%
display(dd,cell_id='05B8C2382F454DA69B9AA9E78502B118',showLegend='true',stacked='true',rowCount='100',staticFigure='false',mpld3='true',aggregation='SUM',handlerId='histogram',valueFields='age',keyFields='weight',nostore_cw='1098',nostore_bokeh='false',prefix='17d0e87d')
# Out:
# <script>
# $("#mapOptions17d0e87d").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...
