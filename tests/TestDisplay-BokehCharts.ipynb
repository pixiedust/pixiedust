# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.9</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure135758b9" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-135758b9 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-135758b9" data-parent="#df-table-wrapper-135758b9">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-135758b9" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-135758b9" data-parent="#df-table-wrapper-135758b9"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-135758b9" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header" style="width: 765px;">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell" style="width: 72px;">abbr</div>
#
#                 <div class="fixed-cell" style="width: 149px;">medals.bronze</div>
#
#                 <div class="fixed-cell" style="width: 130px;">medals.gold</div>
#
#                 <div class="fixed-cell" style="width: 138px;">medals.silver</div>
#
#                 <div class="fixed-cell" style="width: 131px;">medals.total</div>
#
#                 <div class="fixed-cell" style="width: 146px;">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"f6d58792-cf1b-44e6-a78c-26a559eec8d1":{"roots":{"references":[{"attributes":{"axis_label":"Frequency","formatter":{"id":"3ad0d3ad-2276-48e5-a4b1-41c76396510c","type":"BasicTickFormatter"},"plot":{"id":"723060e6-b905-4f4f-8904-859d56cc7718","subtype":"Figure","type":"Plot"},"ticker":{"id":"72307999-7162-4b6a-a1fc-7f02c9c391e7","type":"BasicTicker"}},"id":"3b9a2b12-f246-4dee-8d5f-f46273dffcca","type":"LinearAxis"},{"attributes":{},"id":"418e06a5-fb50-4add-b70d-c1bbab3f99d6","type":"BasicTicker"},{"attributes":{},"id":"2097c1c2-3e37-4b1b-a1bb-d6d5d0981aec","type":"PanTool"},{"attributes":{},"id":"42fc564a-5c85-4b36-a203-e35151a1e1ec","type":"WheelZoomTool"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"ae8e2855-5e50-403d-8e5c-e4bf16bff75f","type":"BasicTickFormatter"},"plot":{"id":"723060e6-b905-4f4f-8904-859d56cc7718","subtype":"Figure","type":"Plot"},"ticker":{"id":"418e06a5-fb50-4add-b70d-c1bbab3f99d6","type":"BasicTicker"}},"id":"53190ad4-c4e1-44a0-ab10-16c66aa1306c","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2097c1c2-3e37-4b1b-a1bb-d6d5d0981aec","type":"PanTool"},{"id":"42fc564a-5c85-4b36-a203-e35151a1e1ec","type":"WheelZoomTool"},{"id":"9c1c3dfe-1e70-4c95-bbf6-8e2a7dbe1395","type":"BoxZoomTool"},{"id":"050a883d-88a3-4f42-a36b-c02dd04aaf41","type":"SaveTool"},{"id":"a98ecaef-34ab-48d4-9144-e34cf2ae40dd","type":"ResetTool"},{"id":"740f991e-0aa1-4a65-b198-deac4cb5c054","type":"HelpTool"}]},"id":"ec89ad79-dd1d-4194-9c88-0922bed95428","type":"Toolbar"},{"attributes":{"plot":{"id":"723060e6-b905-4f4f-8904-859d56cc7718","subtype":"Figure","type":"Plot"},"ticker":{"id":"418e06a5-fb50-4add-b70d-c1bbab3f99d6","type":"BasicTicker"}},"id":"bb9f3996-b568-4ab7-9405-3d923ee155c1","type":"Grid"},{"attributes":{"children":[{"id":"723060e6-b905-4f4f-8904-859d56cc7718","subtype":"Figure","type":"Plot"}]},"id":"f2f5b678-6d67-4fca-a7d8-8333901573f7","type":"Row"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1feb7f8f-fe5c-4784-88f4-a33e0f5727a3","type":"BoxAnnotation"},{"attributes":{},"id":"ae8e2855-5e50-403d-8e5c-e4bf16bff75f","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"66415a45-69e8-45f6-8ef8-19892bb2ff8d","type":"Quad"},{"attributes":{},"id":"050a883d-88a3-4f42-a36b-c02dd04aaf41","type":"SaveTool"},{"attributes":{"callback":null,"start":0},"id":"33790e8b-264d-4019-b3fd-67871ee3b66e","type":"DataRange1d"},{"attributes":{},"id":"72307999-7162-4b6a-a1fc-7f02c9c391e7","type":"BasicTicker"},{"attributes":{"children":[{"id":"c60f785b-b4de-4308-92e8-e11392922a82","type":"ToolbarBox"},{"id":"7019caa4-9698-40bd-8aa8-7c8bf7e8f90c","type":"Column"}]},"id":"6e9dba9d-a99e-483e-bef1-39b71a7785d8","type":"Column"},{"attributes":{},"id":"a98ecaef-34ab-48d4-9144-e34cf2ae40dd","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}}},"id":"37de7b30-acf5-42ab-a303-70c5a8d12947","type":"ColumnDataSource"}, ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"809a9700-f006-448a-a6f5-2b6d8acba518":{"roots":{"references":[{"attributes":{"data_source":{"id":"a1cd4bea-0b7c-4acf-84fc-e39a88a09df8","type":"ColumnDataSource"},"glyph":{"id":"3f920682-da5b-42ac-9509-c55877db277d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8336cc16-be11-4766-9dac-d5c33f7f3c80","type":"Circle"},"selection_glyph":null,"view":{"id":"1a760c3f-fb17-4ea2-9217-1b5ac1636f95","type":"CDSView"}},"id":"d159a3cf-4168-418e-a7e2-466a0fac4172","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#C5407D"},"line_color":{"value":"#C5407D"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"baccbd34-5385-493e-b8d7-af15713f56bc","type":"Circle"},{"attributes":{"label":{"value":"POL"},"renderers":[{"id":"ab9373a5-ec17-4b9f-8c43-fc9144805a8c","type":"GlyphRenderer"}]},"id":"97d1fc81-a200-4d34-a5da-a68ad7d2d0da","type":"LegendItem"},{"attributes":{},"id":"890c2231-895e-4fe9-b1e1-b9f014bfabd7","type":"BasicTicker"},{"attributes":{"source":{"id":"977eb05c-bf13-4da2-9eaa-545a58f68d23","type":"ColumnDataSource"}},"id":"54be2108-2d1c-49b9-8788-6cf1399c5844","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#CF4B74"},"line_color":{"value":"#CF4B74"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"42c0790a-398c-4058-ac75-b4b209035e9f","type":"Circle"},{"attributes":{"source":{"id":"2cd1610a-772a-4582-a968-edd86276dc2f","type":"ColumnDataSource"}},"id":"b8b72c57-3be1-4ae0-93c5-52eda6909031","type":"CDSView"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ae41e09b-c339-4521-b7be-076e04dda8ed","type":"BoxAnnotation"},{"attributes":{"label":{"value":"RUS"},"renderers":[{"id":"f6f3d907-9ab2-4980-a25a-c4037eb694ed","type":"GlyphRenderer"}]},"id":"07d76190-e2aa-46c9-bd7a-379bd315cbf3","type":"LegendItem"},{"attributes":{"label":{"value":"FIN"},"renderers":[{"id":"4ef8da25-5cc5-4f00-8920-cee0bd337813","type":"GlyphRenderer"}]},"id":"2ef7f6ae-eaea-4174-8d90-1ef06a57792d","type":"LegendItem"},{"attributes":{"data_source":{"id":"a4e3de20-c3c1-47f1-a091-441dcb62fe89","type":"ColumnDataSource"},"glyph":{"id":"556ca4fb-cb96-4995-b047-330870820166","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a01d4c77-7ef8-47a1-9cbb-81ff68ce9904","type":"Circle"},"selection_glyph":null,"view":{"id":"0e5a9ebc-614a-4484-9c77-6d40c4cf1076","type":"CDSView"}},"id":"03917ed9-95fc-4318-b520-d3f8c10512a3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"3661949e-0ea9-431f-a037-5371219bb483","type":"Circle"},{"attributes":{"label":{"value":"CAN"},"renderers":[{"id":"4a010e12-f9c6-4f90-b72d-31fe4599d04e","type":"GlyphRenderer"}]},"id":"1649e05b-2721-4cae-8e0b-1e9744e8c1f9","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"3daa3ce0-8c0a-481f-969e-2f1b85a81a28","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#E87059"},"line_color":{"value":"#E87059"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f920682-da5b-42ac-9509-c55877db277d","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"fi ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"b5f35d51-cb65-4071-ab5b-869763fcee2b":{"roots":{"references":[{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"5cef58ec-9635-40f1-b0ba-700ac627deca","type":"Line"},{"attributes":{},"id":"dad09bab-2bd1-4493-b385-ac3fb5963bf9","type":"BasicTickFormatter"},{"attributes":{},"id":"72e195f4-4caf-4d24-836a-a8ca20059597","type":"LinearScale"},{"attributes":{"data_source":{"id":"94eeacf0-f84a-4ced-9e8f-3f1068c7ffae","type":"ColumnDataSource"},"glyph":{"id":"5cef58ec-9635-40f1-b0ba-700ac627deca","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4451a904-cc46-48ed-8041-79e6a6db6697","type":"Line"},"selection_glyph":null,"view":{"id":"3399e890-3bff-4395-8bf3-5b25f0d410b2","type":"CDSView"}},"id":"750f0670-fa18-4848-91cf-36bcf6af8a12","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"509952fc-8d99-4b56-ba5c-d3c31236f53f","type":"DataRange1d"},{"attributes":{},"id":"b1dd33a7-c636-4888-8866-0062119e3568","type":"ResetTool"},{"attributes":{},"id":"60b24e0a-9261-4986-b048-4d692fe41f74","type":"HelpTool"},{"attributes":{"tools":[{"id":"26496e96-6653-4c2f-83f9-9ae806b9d99b","type":"PanTool"},{"id":"b31d786f-75ad-4b91-803c-b766c280bcbb","type":"WheelZoomTool"},{"id":"cbe331fb-9197-495b-b0f2-af448fe68718","type":"BoxZoomTool"},{"id":"6ff528a8-f1e4-422c-9b65-af8f51aa15c3","type":"SaveTool"},{"id":"b1dd33a7-c636-4888-8866-0062119e3568","type":"ResetTool"},{"id":"60b24e0a-9261-4986-b048-4d692fe41f74","type":"HelpTool"}]},"id":"65b9a436-bb87-4d1e-b8f7-8705310d2da6","type":"ProxyToolbar"},{"attributes":{"dimension":1,"plot":{"id":"329c5783-3681-46a9-a855-49d5c7e4dc44","subtype":"Figure","type":"Plot"},"ticker":{"id":"d14f920f-9c55-499a-995f-bf73b68e5a6d","type":"BasicTicker"}},"id":"294757d9-3140-4c6e-9390-0958407ec29a","type":"Grid"},{"attributes":{"callback":null},"id":"b99731d9-f4cc-45a3-a8c4-bd487fef9f6b","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6,8],"y":[11,4,6,15,15,2,8,10]}},"id":"94eeacf0-f84a-4ced-9e8f-3f1068c7ffae","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"82c5fc4f-f438-40cb-8d45-ea8c7230c54c","type":"LinearAxis"}],"left":[{"id":"e7b9553f-5c7f-4478-b51f-baa3edd4b94b","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"82c5fc4f-f438-40cb-8d45-ea8c7230c54c","type":"LinearAxis"},{"id":"8122f771-c83f-4ef7-8f22-33960fee3599","type":"Grid"},{"id":"e7b9553f-5c7f-4478-b51f-baa3edd4b94b","type":"LinearAxis"},{"id":"294757d9-3140-4c6e-9390-0958407ec29a","type":"Grid"},{"id":"b2afb829-8d2b-4c4d-8a59-f2b84092ea99","type":"BoxAnnotation"},{"id":"4933a98b-4d90-491b-a0e3-4bb1ce8eb640","type":"Legend"},{"id":"750f0670-fa18-4848-91cf-36bcf6af8a12","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"16741618-059c-4c5e-83ea-f4e30cc6e87f","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"b99731d9-f4cc-45a3-a8c4-bd487fef9f6b","type":"DataRange1d"},"x_scale":{"id":"cdcb5ef6-e9c8-4176-8c4c-6c1da814d132","type":"LinearScale"},"y_range":{"id":"509952fc-8d99-4b56-ba5c-d3c31236f53f","type":"DataRange1d"},"y_scale":{"id":"72e195f4-4caf-4d24-836a-a8ca20059597","type":"LinearScale"}},"id":"329c5783-3681-46a9-a855-49d5c7e4dc44","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d14f920f-9c55-499a-995f-bf73b68e5a6d","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"26496e96-6653-4c2f-83f9-9ae806b9d99b","type":"PanTool"},{"id":"b31d786f-75ad-4b91-803c-b766c280bcbb","type":"WheelZoomTool"},{"id":"cbe331fb-9197-495b-b0f2-af448fe68718","type":"BoxZoomTool"},{"id":"6ff528a8-f1e4-422c-9b65-af8f51aa15c3","type":"SaveTool"},{"id":"b1dd33a7-c636-4888-8866-0062119e3568","type":"ResetTool"},{"id":"60b24e0a-9261-4986-b048-4d692fe41f74","type":"HelpTool"}]},"id":"16741618-059c-4c5e-83ea-f4e30cc6e87f","type":"Toolbar"},{"attributes":{"plot":{"id":"329c5783-3681-4 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"ad631e6b-1c2f-4afc-8159-6249b75f965e":{"roots":{"references":[{"attributes":{},"id":"28c8d62a-a772-4b13-a856-e100d73e3d6e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"a98fa544-4906-4d92-b425-28760f8b3bdb","type":"ColumnDataSource"},"glyph":{"id":"d19b730b-517a-4616-9fa2-f8a90cf21760","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1165562e-c67e-4292-bc5c-d029f769b2b8","type":"VBar"},"selection_glyph":null,"view":{"id":"e6b80b1d-40e0-4de9-b0d4-c86efba67e86","type":"CDSView"}},"id":"198a4e96-46c7-4d73-be45-45345a1ed8f8","type":"GlyphRenderer"},{"attributes":{"fields":["medals.bronze","medals.silver"]},"id":"a36519fa-2ba3-4163-a650-425a50669620","type":"Stack"},{"attributes":{"dimension":1,"plot":{"id":"27c74eee-3c57-4b9a-9fe6-ce8b1d852c52","subtype":"Figure","type":"Plot"},"ticker":{"id":"13a24cb8-aa45-4d8c-a0d3-295f6efbd949","type":"BasicTicker"}},"id":"680be2e8-eb56-4ee6-8c23-2b8ec89d376b","type":"Grid"},{"attributes":{"below":[{"id":"87fc18d5-e854-4a46-a3b3-95811e9355db","type":"CategoricalAxis"}],"left":[{"id":"dc218032-119f-4f9a-9999-6a8afd6057d5","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":495,"plot_width":803,"renderers":[{"id":"87fc18d5-e854-4a46-a3b3-95811e9355db","type":"CategoricalAxis"},{"id":"1aa4256e-1383-4d4f-9ba0-b57c3305f5dc","type":"Grid"},{"id":"dc218032-119f-4f9a-9999-6a8afd6057d5","type":"LinearAxis"},{"id":"680be2e8-eb56-4ee6-8c23-2b8ec89d376b","type":"Grid"},{"id":"3588fe43-a50f-4eba-8bce-5d4a1316cb61","type":"BoxAnnotation"},{"id":"7319f3a9-5851-4f95-bf0a-5f22227edd95","type":"Legend"},{"id":"0fa93748-0b18-4e1a-a0c3-bbe6d8289542","type":"GlyphRenderer"},{"id":"ce36bb5c-ccd5-4d32-8ec9-1f12daafcb9a","type":"GlyphRenderer"},{"id":"198a4e96-46c7-4d73-be45-45345a1ed8f8","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"d179a3c5-a0ae-4f1b-ad66-cd9973501d7e","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"2c631b19-364f-46cc-913a-0da74efb2563","type":"FactorRange"},"x_scale":{"id":"52a959ea-5c5c-42e1-b063-558a1b517ae4","type":"CategoricalScale"},"y_range":{"id":"cf8af73d-f2df-4e13-be90-f70c5cea79da","type":"DataRange1d"},"y_scale":{"id":"092122aa-88b5-4745-8d21-72c777ecdb44","type":"LinearScale"}},"id":"27c74eee-3c57-4b9a-9fe6-ce8b1d852c52","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"a98fa544-4906-4d92-b425-28760f8b3bdb","type":"ColumnDataSource"},"glyph":{"id":"e57b37c0-5f23-45da-aabf-6fe7bb4982e4","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6ae78e64-9ce8-434b-a7ab-f12382dc3f6e","type":"VBar"},"selection_glyph":null,"view":{"id":"f30fbfda-19fc-428d-9855-3fc6bcb2f321","type":"CDSView"}},"id":"ce36bb5c-ccd5-4d32-8ec9-1f12daafcb9a","type":"GlyphRenderer"},{"attributes":{"source":{"id":"a98fa544-4906-4d92-b425-28760f8b3bdb","type":"ColumnDataSource"}},"id":"2e3b3509-e11e-42ff-b917-d2569ab42b38","type":"CDSView"},{"attributes":{"bottom":{"expr":{"id":"0b30d3a2-88dd-4cad-87df-1d6a6f58366f","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"4265eb94-718e-4496-a9c4-ac712f5cf043","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"e2a5dd89-cf10-4037-a3e6-3a8bfa1d57b1","type":"VBar"},{"attributes":{"axis_label":"name","formatter":{"id":"c0a6f50f-3527-430e-b56e-05e313feabc0","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"plot":{"id":"27c74eee-3c57-4b9a-9fe6-ce8b1d852c52","subtype":"Figure","type":"Plot"},"ticker":{"id":"02824fda-7236-464a-a1cc-2b614e4e6e3b","type":"CategoricalTicker"}},"id":"87fc18d5-e854-4a46-a3b3-95811e9355db","type":"CategoricalAxis"},{"attributes":{},"id":"95d5b0dd-df14-4049-8487-f88a0c7aa819","type":"SaveTool"},{"attributes":{"children":[{"id":"a0d54e18-19fa-4bcd-ba40-aa802172cecf","type":"ToolbarBox"},{"id":"ddbf197a-6acf-4f1b-85 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
