# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 0.83</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from bokeh.charts.utils import df_from_json

# utilize utility to make it easy to get json/dict data converted to a dataframe
df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['total'] > 0]
df = df.sort_values("total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  bronze  gold  silver  total           name
# 65  RUS       7     6       8     21   Russian Fed.
# 81  USA      10     6       4     20  United States
# 54  NLD       8     6       6     20    Netherlands
# 56  NOR       7     8       4     19         Norway
# 13  CAN       4     4       8     16         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><div id="chartFigure2361d03f" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#
#     <div class="bk-root">
#         <div class="bk-plot-layout bk-layout-fixed" id="modelid_b2693850-7640-4a27-89f8-f7781878e4b0" style="width: 798px; height: 596px;"><div class="bk-toolbar-wrapper bk-layout-null" id="modelid_3d03e1a5-db7c-4f5e-b7d1-94ff3db6dda3" style="left: 768px; top: 5px; width: 30px; height: 591px;"><div class="bk-toolbar-right bk-toolbar-sticky"><a href="http://bokeh.pydata.org/" target="_blank" class="bk-logo bk-logo-small"></a><div class="bk-button-bar"><div class="bk-button-bar-list" type="pan"><div class="bk-toolbar-button bk-active"><div class="bk-btn-icon bk-tool-icon-pan"></div><span class="bk-tip">Pan</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-box-zoom"></div><span class="bk-tip">Box Zoom</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-resize"></div><span class="bk-tip">Resize</span></div></div><div class="bk-button-bar-list" type="scroll"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-wheel-zoom"></div><span class="bk-tip">Wheel Zoom</span></div></div><div class="bk-button-bar-list" type="pinch"></div><div class="bk-button-bar-list" type="tap"></div><div class="bk-button-bar-list" type="press"></div><div class="bk-button-bar-list" type="rotate"></div><div class="bk-button-bar-list" type="actions"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-save"></div><span class="bk-tip">Save</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-reset"></div><span class="bk-tip">Reset</span></div></div><div class="bk-button-bar-list" type="inspectors"></div><div class="bk-button-bar-list" type="help"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-help"></div><span class="bk-tip">Click the question mark to learn more about Bokeh plot tools.</span></div></div></div></div></div><div class="bk-plot-wrapper" style="position: absolute; left: 0px; top: 0px; width: 798px; height: 596px;"><div class="bk-canvas-wrapper" style="touch-action: none; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); width: 798px; height: 596px;"><div class="bk-canvas-events"></div><div class="bk-canvas-overlays"><div class="bk-shading" style="display: none;"></div></div><canvas class="bk-canvas" width="1436.3999619483948" height="1072.7999715805054" style="width: 798px; height: 596px;"></canvas><div class="bk-resize-popup" style="display: none;"></div></div></div></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("41c26bd9-d2bb-4ffa-a754-4600de5bb44c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41c26bd9-d2bb-4ffa-a754-4600de5bb44c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41c26bd9-d2bb-4ffa-a754-4600de5bb44c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d270c87-2446-44fb-b99b-c2e28d2534c4":{"roots":{"references":[{"attributes":{},"id":"12fe18af-87ed-45e9-9d48-6796a45202e9","type":"BasicTickFormatter"},{"attributes":{},"id":"f5cfcaca-853d-439e-977c-ff5a06ead2a2","type":"BasicTicker"},{"attributes":{"overlay":{"id":"e45aac2c-a0e8-42cd-b0da-6cf135087bd9","type":"BoxAnnotation"},"plot":{"id":"b2693850-7640-4a27-89f8-f7781878e4b0","subtype":"Chart","type":"Plot"}},"id":"617da749-1eaa-4574-a527-979b389e288f","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(19.000000, 21.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(19.000000, 21.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["20.0"],"y":[2.0]}},"id":"a6581bfc-a079-4eb9-97fb-d0ecfe6a0793","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"cd6cd201-f560-410f-a08c-b12a5efe8e24","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"b21b2ba3-e0db-44be-8c47-ec45b99889c4","type":"LinearAxis"}],"plot_height":596,"plot_width":798,"renderers":[{"id":"e45aac2c-a0e8-42cd-b0da-6cf135087bd9","type":"BoxAnnotation"},{"id":"28df7179-07d1-481a-bce7-2b99918d537f","type":"GlyphRenderer"},{"id":"633007fa-ea08-4e87-b9b3-162be8494cb4","type":"GlyphRenderer"},{"id":"78899375-cafa-4458-a1fa-e730cbfe615d","type":"GlyphRenderer"},{"id":"d0055d3b-2bda-4d4a-ae1b-26e6a8d8b5b4","type":"GlyphRenderer"},{"id":"77c6598c-1c19-44aa-96f1-1183add61eee","type":"GlyphRenderer"},{"id":"8335e456-a716-473e-b82b-b96b702697e3","type":"GlyphRenderer"},{"id":"8f205213-3489-425e-95ac-9e432ee8e488","type":"GlyphRenderer"},{"id":"f9e393a8-b6e7-461a-a4e7-677ac29377db","type":"GlyphRenderer"},{"id":"6bc58015-c0cd-4cea-8712-1346ef55fd26","type":"GlyphRenderer"},{"id":"24d8e8d1-7d73-4990-b470-a9dd87703b38","type":

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='histogram',nostore_figureOnly='true',keyFields='total',valueFields='total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5ee6c97b-83d8-4b8a-8b96-8432050dea71"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5ee6c97b-83d8-4b8a-8b96-8432050dea71").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ee6c97b-83d8-4b8a-8b96-8432050dea71");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ee6c97b-83d8-4b8a-8b96-8432050dea71' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"59b0173f-cd7d-4d10-a3dc-e2e9655bb61a":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(9.000000, 11.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(9.000000, 11.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["10.0"],"y":[2.0]}},"id":"1cddc174-9380-4b54-a438-baafada9da75","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e4daf15-20c4-4b51-90d0-3d1873ebecd8","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"737ab722-e953-44d0-8a35-48675c430993","type":"PanTool"},{"id":"485a2161-e519-4716-aa41-7b9f431263a2","type":"WheelZoomTool"},{"id":"b46a9052-5d5e-4b6c-9907-3e3e65552c4a","type":"BoxZoomTool"},{"id":"86bb2825-b702-49e3-8483-bfead38c6e54","type":"SaveTool"},{"id":"1669f2f5-491e-4c1b-bc8c-fb28d74aa6fa","type":"ResetTool"},{"id":"c19dd33f-5632-461d-8d85-55d156043db6","type":"HelpTool"},{"id":"dd5c22a9-62da-4ecb-afad-6f1a3a3893fb","type":"ResizeTool"}]},"id":"2a0d6d1e-4a1d-4bbf-854d-8c0fc835ec45","type":"Toolbar"},{"attributes":{"data_source":{"id":"89057a2c-05de-4dbb-9fde-fa5eda413974","type":"ColumnDataSource"},"glyph":{"id":"e4aff479-30f7-4eb9-b826-2956f37c7e6d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a3285476-71b6-45d9-bb6c-649ea7603d87","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f386650f-c725-4f8d-a1a8-03507cab07e6","type":"ColumnDataSource"},"glyph":{"id":"62e35858-ab24-470f-8614-0b5058bbe46f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"95aca312-68f1-4d2d-9dd1-f8a8d8700a07","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(19.000000, 21.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(19.000000, 21.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["20.0"],"y":[2.0]}},"id":"074b00f6-d2ba-4dab-a308-403ea55355b6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"66c8d9f0-f975-45fd-820b-b1569445b6db","type":"Rect"},{"attributes":{"plot":{"id":"38e02958-b725-4e58-a434-5d38547916b9","subtype":"Chart","type":"Plot"}},"id":"c19dd33f-5632-461d-8d85-55d156043db6","type":"HelpTool"},{"attributes":{"callback":null,"end":5.5},"id":"92a37aa2-8374-491d-83b0-35160de58b50","type":"Range1d"},{"attributes":{"data_source":{"id":"074b00f6-d2ba-4dab-a308-403ea55355b6","type":"ColumnDataSource"},"glyph":{"id":"5162e057-b4ab-4fe8-b07b-68adf9b76856","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8699ba40-4f5d-4779-8f9b-5ade6fb68ff9","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b6c8b8be-eef3-4549-b5f0-ce1b3348a6bb","type":"ColumnDataSource"},"glyph":{"id":"16a4d714-e64b-4aa0-925e-f2c8c2dfcd38","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b4599f6b-c2cc-4f7d-aea1-2288e300a607","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1cddc174-9380-4b54-a438-baafada9da75","type":"ColumnDataSource"},"glyph":{"id":"66c8d9f0-f975-45fd-820b-b1569445b6db","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7521e323-1ba6-4e30-8632-c32ff32ec5eb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"156e68a4-2418-4038-8791-70a42b3d78 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='total',valueFields='gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0b9c17ac-5ca2-416e-904b-b879d24bdc98"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0b9c17ac-5ca2-416e-904b-b879d24bdc98").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0b9c17ac-5ca2-416e-904b-b879d24bdc98");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0b9c17ac-5ca2-416e-904b-b879d24bdc98' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2bf2a88f-27f0-4621-86b9-0c81856d0260":{"roots":{"references":[{"attributes":{"data_source":{"id":"1cc6238d-abba-40cd-b327-5d80fb4362a4","type":"ColumnDataSource"},"glyph":{"id":"bba73373-47ab-4711-9ae1-5208ce381238","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6302acdd-3220-4a3c-9b4e-f323f41038dd","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"abbr":["SVN"],"chart_index":[{"abbr":"SVN"}],"x_values":[7],"y_values":[2]}},"id":"a99cf48c-3d19-4e7f-be4b-9d9707c4cec6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"23f90e8a-606d-4f13-9f74-ed04b2055751","type":"ColumnDataSource"},"glyph":{"id":"4d4934aa-85d1-4e8c-936a-dc6f8f4bd700","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e0fd09d9-db90-4fa5-bb29-3d6d5a2bd027","type":"GlyphRenderer"},{"attributes":{"label":{"value":"SVK"},"renderers":[{"id":"ae962fc2-2749-41d0-9cf0-bbadf7a3ae0f","type":"GlyphRenderer"}]},"id":"09c85d97-a139-4151-9803-d34067282722","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"e4e7433b-9cdf-46ae-b0b5-7761cdead692","type":"Circle"},{"attributes":{"data_source":{"id":"21b113c3-881f-43d1-9d33-675bbc7cf8f1","type":"ColumnDataSource"},"glyph":{"id":"119aa19b-4843-47e1-b876-9504e3eb051d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"04b2221e-8bd3-4bb2-8868-1ed4b6e8e7f3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"abbr":["AUS"],"chart_index":[{"abbr":"AUS"}],"x_values":[3],"y_values":[0]}},"id":"d7b8358d-e745-4fb9-a384-cecfd5f70415","type":"ColumnDataSource"},{"attributes":{"label":{"value":"JPN"},"renderers":[{"id":"4a3825e8-abf9-4fc9-92d3-7243597ad3de","type":"GlyphRenderer"}]},"id":"a954272a-49d4-4781-ab0f-8ebf6fe390bc","type":"LegendItem"},{"attributes":{"data_source":{"id":"9174b7b2-af2e-48df-84fa-44716aa3d8b7","type":"ColumnDataSource"},"glyph":{"id":"51289045-179d-46bd-8adb-15ae7e68104c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ae962fc2-2749-41d0-9cf0-bbadf7a3ae0f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"18dd2113-a4a4-4d22-a8da-6166fb50db4f","type":"Circle"},{"attributes":{},"id":"8f56efba-23a6-4334-b576-969a11e4e603","type":"BasicTicker"},{"attributes":{"data_source":{"id":"4a5103a4-5e52-4ec1-b2e7-f3181eb89270","type":"ColumnDataSource"},"glyph":{"id":"142146ee-fca7-442f-9fa5-8600085834cc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d421d402-7b6c-493b-9146-250842e03b20","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#c33ff3"},"line_color":{"value":"#c33ff3"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"a81920a8-b17e-4081-a7dc-bb645ebc4955","type":"Circle"},{"attributes":{"data_source":{"id":"5395837e-7ecd-4e18-87a8-fdea15fc15e9","type":"ColumnDataSource"},"glyph":{"id":"e4e7433b-9cdf-46ae-b0b5-7761cdead692","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"83c22a72-78fa-42d0-bfcf-cf3e40b6f8c1","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"2efabaa0-b42a-4e11-ac2a-ca817b6c729c","type":"Title"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"abbr":["NOR"],"chart_index":[{"abbr":"NOR"}],"x_values":[19],"y_values":[8]}},"id":"6b43dc9d-42d2-46b6-ab9d-ba955a50335b","type":"ColumnDataSource"},{"attributes":{"label":{"value":"HRV"},"renderers":[{ ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='lineChart',rendererId='bokeh',keyFields='abbr',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0e208f44-e4ee-477f-bbea-89f8a53cb3b9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0e208f44-e4ee-477f-bbea-89f8a53cb3b9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0e208f44-e4ee-477f-bbea-89f8a53cb3b9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0e208f44-e4ee-477f-bbea-89f8a53cb3b9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b7913502-b636-4656-9c0c-daa24ee87dbb":{"roots":{"references":[{"attributes":{"axis_label":"gold","formatter":{"id":"4881a6a9-5292-4d0c-9013-6533b8801d85","type":"BasicTickFormatter"},"plot":{"id":"f96d79b5-d6ba-47ed-90c1-60351d94fc9d","subtype":"Chart","type":"Plot"},"ticker":{"id":"edd87c4b-2b60-4a7b-8ef9-2d949d22163c","type":"BasicTicker"}},"id":"92aee55a-97d3-4890-b1c9-a1b9ede9d7c6","type":"LinearAxis"},{"attributes":{"plot":{"id":"b517508c-3a93-499c-a629-461ce539d7df","subtype":"Chart","type":"Plot"}},"id":"f5994162-d943-49bd-8b8c-d46fdb4ee9fa","type":"SaveTool"},{"attributes":{},"id":"953c98f8-1cb9-4236-ab14-9e1c3871061c","type":"BasicTickFormatter"},{"attributes":{},"id":"edd87c4b-2b60-4a7b-8ef9-2d949d22163c","type":"BasicTicker"},{"attributes":{"data_source":{"id":"5c1541de-ecdc-4709-b802-9c7fa484793e","type":"ColumnDataSource"},"glyph":{"id":"4329eea7-1228-4e7c-9807-ca6ba16665de","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a5fee3fe-5f81-461c-97b1-b08136bb922b","type":"GlyphRenderer"},{"attributes":{},"id":"152c9f7e-411d-4ab6-ad48-5a135c3a3a79","type":"CategoricalTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"baafd5f1-1374-4ba7-9773-2ad9010ae70c","type":"PanTool"},{"id":"1ad3345f-13eb-42b8-bd4e-c5b0a859e361","type":"WheelZoomTool"},{"id":"09b52fed-12f0-4566-97c8-275fce8f675d","type":"BoxZoomTool"},{"id":"f5994162-d943-49bd-8b8c-d46fdb4ee9fa","type":"SaveTool"},{"id":"dc4e3561-937a-4956-9964-c3134817236b","type":"ResetTool"},{"id":"fd74ced4-859c-4a81-8ce2-dd3e1b4b42f4","type":"HelpTool"}]},"id":"f7877b8e-e493-4b0d-9d89-e6ff1b3cb4ed","type":"Toolbar"},{"attributes":{"below":[{"id":"7f358f98-2d81-44f9-9548-959216eb2228","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"d023eefd-6c36-454a-9c06-7c6d305b61d9","type":"LinearAxis"}],"plot_height":399,"plot_width":399,"renderers":[{"id":"2bd28abd-0297-4e64-9284-7adc1b2537f2","type":"BoxAnnotation"},{"id":"cb1fb208-a5cd-4466-b5d7-628327e11df5","type":"GlyphRenderer"},{"id":"ecd26da1-0e6e-4fb9-a508-cb482f4c1ab4","type":"Legend"},{"id":"7f358f98-2d81-44f9-9548-959216eb2228","type":"CategoricalAxis"},{"id":"d023eefd-6c36-454a-9c06-7c6d305b61d9","type":"LinearAxis"},{"id":"d1c40669-ee95-4d60-9f5c-f3ed0c80ee35","type":"Grid"},{"id":"c7755fc4-9164-459c-9c28-c49042bd08b3","type":"Grid"}],"title":{"id":"f770c0ff-3391-428e-af2f-82c087c6062f","type":"Title"},"tool_events":{"id":"585712d4-96bf-48f9-aee2-f06d54b85243","type":"ToolEvents"},"toolbar":{"id":"3bdd5daf-f7b2-4688-9d92-f3159a55eb92","type":"Toolbar"},"toolbar_location":null,"x_mapper_type":"auto","x_range":{"id":"4eeda53f-f6ec-47d4-8f13-167151ffda0f","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"7082a3a4-d453-4165-941b-7a3e5c07f5e9","type":"Range1d"}},"id":"a89968b4-cd4e-451a-a03c-13662bfca789","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"02e2f6a2-43c1-482b-8aa1-4fb3c994b4b2","type":"BasicTicker"},{"attributes":{"location":"top_left","plot":{"id":"f96d79b5-d6ba-47ed-90c1-60351d94fc9d","subtype":"Chart","type":"Plot"}},"id":"973a0612-0c27-4672-8d33-d71bd7fea3cd","type":"Legend"},{"attributes":{"plot":{"id":"f96d79b5-d6ba-47ed-90c1-60351d94fc9d","subtype":"Chart","type":"Plot"}},"id":"64501355-30bb-473a-8a25-9f48bd9c4c4f","type":"HelpTool"},{"attributes":{"below":[{"id":"37f68ac2-113b-446d-ad55-b09c332e7d52","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"92aee55a-97d3-4890-b1c9-a1b9ede9d7c6","type":"LinearAxis"}],"plot_height":399,"plot_width":399,"renderers":[{"id":"8c73a1e5-d48c-489c-acc1-6699bbec7c14","type":"BoxAnnotation"},{"id":"a5fee3fe-5f81-461c-97b1-b08136bb922b","type":"GlyphRenderer"},{"id":"973a0612-0c27-4672-8d33-d71bd7fea3cd","type":"Legend"},{"id":"37f68ac2-113b-446d-ad55-b09c332e7d52","type":"CategoricalAxis"},{"id":"92aee55a-97d3-4890-b1c9-a1b9ede9d7c6","type":"LinearAxis"},{"id":"2cbd9f09-9642-474f-881c-7eeca5fc9e15","type":"Gr ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d131dfe8-2be0-4acc-a4af-b07cbef57ced"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d131dfe8-2be0-4acc-a4af-b07cbef57ced").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d131dfe8-2be0-4acc-a4af-b07cbef57ced");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd131dfe8-2be0-4acc-a4af-b07cbef57ced' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ff67b959-4c75-410a-9767-742be45ebe9c":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc0a82bc-b198-48a0-a6fa-28338872271e","type":"Rect"},{"attributes":{},"id":"d5a334a0-9b9a-416e-ae8e-6aefad572fca","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b4b9ca49-0713-4d1e-bde0-1d533af4df5e","type":"Rect"},{"attributes":{"label":{"value":"silver"},"renderers":[{"id":"f438b8d1-66f8-43b8-b8ba-7734b9fe24df","type":"GlyphRenderer"}]},"id":"8d6fde15-e7fd-4ff3-b0f2-e58a4b956d97","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa8e6b57-fc3d-42e3-a46b-338aa1530f87","type":"Rect"},{"attributes":{"data_source":{"id":"1f39ca5e-19a5-4f63-9639-394bdbe401e2","type":"ColumnDataSource"},"glyph":{"id":"cc0e1971-a3d3-4f7b-b568-7e45070e06f5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a260a9b8-5ba8-4711-9dc2-aec5650daab6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c818bc63-f21e-40bf-b972-fdfc67b1e0cc","type":"Rect"},{"attributes":{"data_source":{"id":"bf55e262-6bcf-463c-a8de-ac9ceff52e0d","type":"ColumnDataSource"},"glyph":{"id":"49494e4a-d508-4303-99ed-d11959498c32","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"efee2540-93a5-4fbc-811f-2f93886633d2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bronze_silver_gold":["silver"],"chart_index":[{"bronze_silver_gold":"silver","name":"Poland"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[0.0],"label":[{"bronze_silver_gold":"silver","name":"Poland"}],"line_alpha":[1.0],"line_color":["white"],"name":["Poland"],"width":[0.8],"x":["Poland"],"y":[0.0]}},"id":"9b499373-b64f-4146-92e8-9ab85133d1c6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fa487ba1-f2ce-4545-97b9-093e9cfc01d2","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f036fed-c4cc-4c4d-b4be-900d1c80b67d","type":"Rect"},{"attributes":{"data_source":{"id":"e2e6f1ba-8fce-4a08-9965-0dbcf06b8d24","type":"ColumnDataSource"},"glyph":{"id":"46fdd6ed-1238-4b80-a0e8-a97d633f542f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b67a291f-48c2-41cc-bc03-1fba3d50d65e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9175fbd-c9b3-4ddc-aa4d-806199657b57","type":"Rect"},{"attributes":{"callback":null,"end":22.05},"id":"8ff5c7dd-e969-4baf-a89f-1142dcbbf875","type":"Range ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#               <div class="fixed-cell">abbr</div>
#
#               <div class="fixed-cell">bronze</div>
#
#               <div class="fixed-cell">gold</div>
#
#               <div class="fixed-cell">silver</div>
#
#               <div class="fixed-cell">total</div>
#
#               <div class="fixed-cell">name</div>
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#                 <th><div>abbr</div></th>
#
#                 <th><div>bronze</div></th>
#
#                 <th><div>gold</div></th>
#
#                 <th><div>silver</div></th>
#
#                 <th><div>total</div></th>
#
#                 <th><div>name</div></th>
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#                 <td>RUS</td>
#
#                 <td>7</td>
#
#                 <td>6</td>
#
#                 <td>8</td>
#
#                 <td>21</td>
#
#                 <td>Russian Fed.</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>USA</td>
#
#                 <td>10</td>
#
#                 <td>6</td>
#
#                 <td>4</td>
#
#                 <td>20</td>
#
#                 <td>United States</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NLD</td>
#
#                 <td>8</td>
#
#                 <td>6</td>
#
#                 <td>6</td>
#
#                 <td>20</td>
#
#                 <td>Netherlands</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NOR</td>
#
#                 <td>7</td>
#
#                 <td>8</td>
#
#                 <td>4</td>
#
#                 <td>19</td>
#
#                 <td>Norway</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CAN</td>
#
#                 <td>4</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>16</td>
#
#                 <td>Canada</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>DEU</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>3</td>
#
#                 <td>15</td>
#
#                 <td>Germany</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CHE</td>
#
#                 <td>1</td>
#
#                 <td>6</td>
#
#                 <td>3</td>
#
#                 <td>10</td>
#
#                 <td>Switzerland</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>FRA</td>
#
#                 <td>5</td>
#
#                 <td>3</td>
