# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.14</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure6306fa13" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6306fa13")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"25eb4453-3bcd-4138-951c-35ecf41302b7":{"roots":{"references":[{"attributes":{},"id":"1022","type":"WheelZoomTool"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"1045","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"1002","subtype":"Figure","type":"Plot"},"ticker":{"id":"1017","type":"BasicTicker"}},"id":"1016","type":"LinearAxis"},{"attributes":{"source":{"id":"1001","type":"ColumnDataSource"}},"id":"1042","type":"CDSView"},{"attributes":{"fields":[]},"id":"1036","type":"Stack"},{"attributes":{},"id":"1008","type":"CategoricalScale"},{"attributes":{"dimension":1,"plot":{"id":"1002","subtype":"Figure","type":"Plot"},"ticker":{"id":"1017","type":"BasicTicker"}},"id":"1020","type":"Grid"},{"attributes":{},"id":"1047","type":"CategoricalTickFormatter"},{"attributes":{},"id":"1013","type":"CategoricalTicker"},{"attributes":{"fields":["medals.total"]},"id":"1037","type":"Stack"},{"attributes":{},"id":"1058","type":"UnionRenderers"},{"attributes":{"bottom":{"expr":{"id":"1036","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"1037","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"1040","type":"VBar"},{"attributes":{"axis_label":"name","formatter":{"id":"1047","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"plot":{"id":"1002","subtype":"Figure","type":"Plot"},"ticker":{"id":"1013","type":"CategoricalTicker"}},"id":"1012","type":"CategoricalAxis"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"1002","subtype":"Figure","type":"Plot"},"ticker":{"id":"1013","type":"CategoricalTicker"}},"id":"1015","type":"Grid"},{"attributes":{"overlay":{"id":"1029","type":"BoxAnnotation"}},"id":"1023","type":"BoxZoomTool"},{"attributes":{"items":[{"id":"1050","type":"LegendItem"}],"location":"top_left","plot":{"id":"1002","subtype":"Figure","type":"Plot"}},"id":"1049","type":"Legend"},{"attributes":{},"id":"1059","type":"Selection"},{"attributes":{"children":[{"id":"1065","type":"ToolbarBox"},{"id":"1063","type":"Column"}]},"id":"1066","type":"Column"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["name","@pd_stacked_col{0.00}"],["medals.total","@medals.total{0.00}"]]},"id":"1051","type":"HoverTool"},{"attributes":{"bottom":{"expr":{"id":"1036","type":"Stack"}},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"1037","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"1039","type":"VBar"},{"attributes":{},"id":"1017","type":"BasicTicker"},{"attributes":{"label":{"value":"medals.total"},"renderers":[{"id":"1041","type":"GlyphRenderer"}]},"id":"1050","type":"LegendItem"},{"attributes":{},"id":"1021","type":"PanTool"},{"attributes":{},"id":"1045","type":"BasicTickFormatter"},{"attributes":{"callback":null,"start":0},"id":"1006","type":"DataRange1d"},{"attributes":{},"id":"1025","type":"ResetTool"},{"attributes":{"children":[{"id":"1062","type":"Row"}]},"id":"1063","type":"Column"},{"attributes":{"children":[{"id":"1002","subtype":"Figure","type":"Plot"}]},"id":"1062","type":"Row"},{"attributes":{"data_source":{"id":"1001","type":"ColumnDataSource"},"glyph":{"id":"1039","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"medals.total","nonselection_glyph":{"id":"1040","type":"VBar"},"selection_glyph":null,"view":{"id":"1042","type":"CDSView"}},"id":"1041","type":"GlyphRenderer"},{"attributes":{"tools":[{"id":"1021","type":"PanTool"},{"id":"1022","type":"WheelZoomTool"},{"id":"1023","type":"BoxZoomTool"},{"id":"1024","type":"SaveTool"},{"id":"1025","type":"ResetTool"},{"id":"1026","type":"HelpTool"},{"id":"1051","type":"HoverTool"}]},"id":"1064","type":"ProxyToolbar"},{"attributes":{},"id":"1026","type":"HelpTool"},{"attributes":{"callback":null,"data":{"medals.total":[3,9,6,16,6,1,6,3,10,15,2, ...
#           var render_items = [{"docid":"25eb4453-3bcd-4138-951c-35ecf41302b7","roots":{"1066":"0ded5c47-abc0-4f5e-8728-6e24637a8353"}}];
#           root.Bokeh.embed.embed_items(docs_json,

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"e09063b2-beed-43d1-aa80-d05485cee6c6":{"roots":{"references":[{"attributes":{"data_source":{"id":"1142","type":"ColumnDataSource"},"glyph":{"id":"1143","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1144","type":"Quad"},"selection_glyph":null,"view":{"id":"1146","type":"CDSView"}},"id":"1145","type":"GlyphRenderer"},{"attributes":{},"id":"1115","type":"LinearScale"},{"attributes":{},"id":"1154","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"1149","type":"Title"},{"attributes":{},"id":"1152","type":"BasicTickFormatter"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["Frequency","@top{0.00}"],["Interval","@left - @right"]]},"id":"1147","type":"HoverTool"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1143","type":"Quad"},{"attributes":{"dimension":1,"plot":{"id":"1108","subtype":"Figure","type":"Plot"},"ticker":{"id":"1123","type":"BasicTicker"}},"id":"1126","type":"Grid"},{"attributes":{"children":[{"id":"1162","type":"ToolbarBox"},{"id":"1160","type":"Column"}]},"id":"1163","type":"Column"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1127","type":"PanTool"},{"id":"1128","type":"WheelZoomTool"},{"id":"1129","type":"BoxZoomTool"},{"id":"1130","type":"SaveTool"},{"id":"1131","type":"ResetTool"},{"id":"1132","type":"HelpTool"},{"id":"1147","type":"HoverTool"}]},"id":"1133","type":"Toolbar"},{"attributes":{},"id":"1123","type":"BasicTicker"},{"attributes":{"callback":null},"id":"1109","type":"DataRange1d"},{"attributes":{},"id":"1156","type":"Selection"},{"attributes":{},"id":"1132","type":"HelpTool"},{"attributes":{"below":[{"id":"1117","type":"LinearAxis"}],"left":[{"id":"1122","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"1117","type":"LinearAxis"},{"id":"1121","type":"Grid"},{"id":"1122","type":"LinearAxis"},{"id":"1126","type":"Grid"},{"id":"1135","type":"BoxAnnotation"},{"id":"1145","type":"GlyphRenderer"}],"title":{"id":"1149","type":"Title"},"toolbar":{"id":"1133","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"1109","type":"DataRange1d"},"x_scale":{"id":"1113","type":"LinearScale"},"y_range":{"id":"1111","type":"DataRange1d"},"y_scale":{"id":"1115","type":"LinearScale"}},"id":"1108","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"1159","type":"Row"}]},"id":"1160","type":"Column"},{"attributes":{"tools":[{"id":"1127","type":"PanTool"},{"id":"1128","type":"WheelZoomTool"},{"id":"1129","type":"BoxZoomTool"},{"id":"1130","type":"SaveTool"},{"id":"1131","type":"ResetTool"},{"id":"1132","type":"HelpTool"},{"id":"1147","type":"HoverTool"}]},"id":"1161","type":"ProxyToolbar"},{"attributes":{},"id":"1128","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1135","type":"BoxAnnotation"},{"attributes":{"callback":null,"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}},"selected":{"id":"1156","type":"Selection"},"selection_policy":{"id":"1155","type":"UnionRenderers"}},"id":"1142","type":"ColumnDataSource"},{" ...
#           var render_items = [{"docid":"e09063b2-beed-43d1-aa80-d05485cee6c6","roots":{"1163":"9df41be5-a1cd-42f8-ae48-545ea715277c"}}];
#           root.Bokeh.embed.embed_items(docs_json, render_items);
#
#           }
#           if (root.Bokeh !== undefined) {
#             embed_document(root);
#           } else {
#             var attempts = 0;
#             var timer = setInterval(function(root) {
#               if (root.Bokeh !== undefined) {
#                 embed_document(root);
#                 clearInterval(timer);
#               }
#               attempts++;
#               if (attempts > 100) {
#                 console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                 clearInterval(timer);
#               }
#             }, 10, root)
#           }
#         })(window);
#       });
#     };
#     if (document.readyState != "loading") fn();
#     else document.addEventListener("DOMContentLoaded", fn);
#   })();
# <\/script>`
#                                 var chartscript = el.childNodes[1]
#                                 var s = document.createElement("script")
#                                 s.innerHTML = chartscript.innerHTML
#                                 d.parentNode.insertBefore(s, d)
#                             }
#                         }
#                     }
#                     if (!window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"a0c974d1-7bce-49cc-ace3-5e69a962bb18":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#7901A8"},"line_color":{"value":"#7901A8"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1354","type":"Circle"},{"attributes":{"source":{"id":"1465","type":"ColumnDataSource"}},"id":"1469","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#F6E525"},"line_color":{"value":"#F6E525"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"2110","type":"Circle"},{"attributes":{"callback":null,"data":{"x":[15],"y":[8]},"selected":{"id":"1431","type":"Selection"},"selection_policy":{"id":"1430","type":"UnionRenderers"}},"id":"1378","type":"ColumnDataSource"},{"attributes":{"callback":null,"data":{"x":[20],"y":[6]},"selected":{"id":"2295","type":"Selection"},"selection_policy":{"id":"2294","type":"UnionRenderers"}},"id":"2170","type":"ColumnDataSource"},{"attributes":{},"id":"1494","type":"UnionRenderers"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1355","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"2111","type":"Circle"},{"attributes":{},"id":"1495","type":"Selection"},{"attributes":{"data_source":{"id":"1353","type":"ColumnDataSource"},"glyph":{"id":"1354","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1355","type":"Circle"},"selection_glyph":null,"view":{"id":"1357","type":"CDSView"}},"id":"1356","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"2109","type":"ColumnDataSource"},"glyph":{"id":"2110","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2111","type":"Circle"},"selection_glyph":null,"view":{"id":"2113","type":"CDSView"}},"id":"2112","type":"GlyphRenderer"},{"attributes":{"label":{"value":"GBR"},"renderers":[{"id":"1468","type":"GlyphRenderer"}]},"id":"1497","type":"LegendItem"},{"attributes":{"source":{"id":"1353","type":"ColumnDataSource"}},"id":"1357","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#BB3586"},"line_color":{"value":"#BB3586"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1499","type":"Circle"},{"attributes":{"source":{"id":"2109","type":"ColumnDataSource"}},"id":"2113","type":"CDSView"},{"attributes":{"callback":null,"data":{"x":[6],"y":[0]},"selected":{"id":"1606","type":"Selection"},"selection_policy":{"id":"1605","type":"UnionRenderers"}},"id":"1533","type":"ColumnDataSource"},{"attributes":{},"id":"1374","type":"UnionRenderers"},{"attributes":{},"id":"2166","type":"UnionRenderers"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1500","type":"Circle"},{"attributes":{},"id":"1375","type":"Selection"},{"attributes":{},"id":"2167","type":"Selection"},{"attributes":{"data_source":{"id":"1498","type":"ColumnDataSource"},"glyph":{"id":"1499","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1500","type":"Circle"},"selection_glyph":null,"view":{"id":"1502","type":"CDSView"}},"id":"1501","type":"GlyphRenderer"},{"attributes":{"label":{"value":"CZE"},"renderers":[{"id":"1356","type":"GlyphRenderer"}]},"id":"1377","type":"LegendItem"},{"attributes":{"label":{"value":"UKR"},"renderers":[{"id":"2112","type":"GlyphRenderer"}]},"id":"2169","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#8807A5"},"line_color":{"value":"#8807A5"},"size":{"units":"sc ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"1c3ea556-e257-47be-8871-287990cecbd6":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2562","type":"BoxAnnotation"},{"attributes":{},"id":"2542","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2554","type":"PanTool"},{"id":"2555","type":"WheelZoomTool"},{"id":"2556","type":"BoxZoomTool"},{"id":"2557","type":"SaveTool"},{"id":"2558","type":"ResetTool"},{"id":"2559","type":"HelpTool"},{"id":"2582","type":"HoverTool"}]},"id":"2560","type":"Toolbar"},{"attributes":{},"id":"2558","type":"ResetTool"},{"attributes":{},"id":"2540","type":"LinearScale"},{"attributes":{"axis_label":"medals.silver","formatter":{"id":"2578","type":"BasicTickFormatter"},"plot":{"id":"2534","subtype":"Figure","type":"Plot"},"ticker":{"id":"2545","type":"BasicTicker"}},"id":"2544","type":"LinearAxis"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["medals.silver","@x"],["medals.gold","@y{0.00}"],["x","$x"],["y","$y"]]},"id":"2582","type":"HoverTool"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"2572","type":"GlyphRenderer"}]},"id":"2581","type":"LegendItem"},{"attributes":{"callback":null},"id":"2536","type":"DataRange1d"},{"attributes":{"toolbar":{"id":"2595","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"2596","type":"ToolbarBox"},{"attributes":{},"id":"2559","type":"HelpTool"},{"attributes":{},"id":"2554","type":"PanTool"},{"attributes":{"axis_label":"medals.gold","formatter":{"id":"2576","type":"BasicTickFormatter"},"plot":{"id":"2534","subtype":"Figure","type":"Plot"},"ticker":{"id":"2550","type":"BasicTicker"}},"id":"2549","type":"LinearAxis"},{"attributes":{"children":[{"id":"2596","type":"ToolbarBox"},{"id":"2594","type":"Column"}]},"id":"2597","type":"Column"},{"attributes":{},"id":"2557","type":"SaveTool"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2570","type":"Line"},{"attributes":{"callback":null},"id":"2538","type":"DataRange1d"},{"attributes":{},"id":"2555","type":"WheelZoomTool"},{"attributes":{"source":{"id":"2569","type":"ColumnDataSource"}},"id":"2573","type":"CDSView"},{"attributes":{"children":[{"id":"2593","type":"Row"}]},"id":"2594","type":"Column"},{"attributes":{},"id":"2589","type":"UnionRenderers"},{"attributes":{"items":[{"id":"2581","type":"LegendItem"}],"location":"top_left","plot":{"id":"2534","subtype":"Figure","type":"Plot"}},"id":"2580","type":"Legend"},{"attributes":{"data_source":{"id":"2569","type":"ColumnDataSource"},"glyph":{"id":"2570","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2571","type":"Line"},"selection_glyph":null,"view":{"id":"2573","type":"CDSView"}},"id":"2572","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"2562","type":"BoxAnnotation"}},"id":"2556","type":"BoxZoomTool"},{"attributes":{"tools":[{"id":"2554","type":"PanTool"},{"id":"2555","type":"WheelZoomTool"},{"id":"2556","type":"BoxZoomTool"},{"id":"2557","type":"SaveTool"},{"id":"2558","type":"ResetTool"},{"id":"2559","type":"HelpTool"},{"id":"2582","type":"HoverTool"}]},"id":"2595","type":"ProxyToolbar"},{"attributes":{},"id":"2545","type":"BasicTicker"},{"attributes":{"callback":null,"data":{"x":[0,1,2,3,4,5,6,8],"y":[11,4,6,15,15,2,8,10]},"selected":{"id":"2590","type":"Selection"},"selection_policy":{"id":"2589","type":"UnionRenderers"}},"id":"2569","type":"ColumnDataSource"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2571","type":"Line"},{"attributes":{},"id":"2576","type":"BasicTickFormatter"},{"attri ...
#           var render_items = [{"docid":"1c3ea556-e257-47be-8871-287990cecbd6","roots":{"2597":"f43886d1-6560-4db3-9371-d09887dc2187"}}];
#           root.Bokeh.embed.embed_items(docs_json, render_items);
#
#           }
#           if (root.Bokeh !== undefined) {
#             embed_document(root);
#           } else {
#             var attempts = 0;
#             var timer = setInterval(function(root) {
#               if (root.Bokeh !== undefined) {
#                 embed_document(root);
#                 clearInterval(timer);
#               }
#               attempts++;
#               if (attempts > 100) {
#                 console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                 clearInterval(timer);
#               }
#             }, 10, root)
#           }
#         })(window);
#       });
#     };
#     if (document.readyState != "loading") fn();
#     else document.addEventListener("DOMContentLoaded", fn);
#   })();
# <\/script>`
#                                 var chartscript = el.childNodes[1]
#                                 var s = document.createElement("script")
#                                 s.innerHTML = chartscript.innerHTML
#                                 d.parentNode.insertBefore(s, d)
#                             }
#                         }
#                     }
#                     if (!window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If load

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"dc5de8c9-7883-485f-9b22-c71b1dbca09d":{"roots":{"references":[{"attributes":{"data_source":{"id":"2639","type":"ColumnDataSource"},"glyph":{"id":"2681","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"medals.bronze","nonselection_glyph":{"id":"2682","type":"VBar"},"selection_glyph":null,"view":{"id":"2684","type":"CDSView"}},"id":"2683","type":"GlyphRenderer"},{"attributes":{},"id":"2659","type":"PanTool"},{"attributes":{},"id":"2703","type":"UnionRenderers"},{"attributes":{},"id":"2660","type":"WheelZoomTool"},{"attributes":{"bottom":{"expr":{"id":"2678","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"2679","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"2709","type":"VBar"},{"attributes":{"children":[{"id":"2640","subtype":"Figure","type":"Plot"}]},"id":"2732","type":"Row"},{"attributes":{"data_source":{"id":"2639","type":"ColumnDataSource"},"glyph":{"id":"2694","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"medals.silver","nonselection_glyph":{"id":"2695","type":"VBar"},"selection_glyph":null,"view":{"id":"2697","type":"CDSView"}},"id":"2696","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2659","type":"PanTool"},{"id":"2660","type":"WheelZoomTool"},{"id":"2661","type":"BoxZoomTool"},{"id":"2662","type":"SaveTool"},{"id":"2663","type":"ResetTool"},{"id":"2664","type":"HelpTool"},{"id":"2721","type":"HoverTool"}]},"id":"2665","type":"Toolbar"},{"attributes":{},"id":"2655","type":"BasicTicker"},{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"2642","type":"FactorRange"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"2710","type":"GlyphRenderer"}]},"id":"2720","type":"LegendItem"},{"attributes":{"source":{"id":"2639","type":"ColumnDataSource"}},"id":"2711","type":"CDSView"},{"attributes":{"below":[{"id":"2650","type":"CategoricalAxis"}],"left":[{"id":"2654","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":495,"plot_width":803,"renderers":[{"id":"2650","type":"CategoricalAxis"},{"id":"2653","type":"Grid"},{"id":"2654","type":"LinearAxis"},{"id":"2658","type":"Grid"},{"id":"2667","type":"BoxAnnotation"},{"id":"2691","type":"Legend"},{"id":"2683","type":"GlyphRenderer"},{"id":"2696","type":"GlyphRenderer"},{"id":"2710","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"2665","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"2642","type":"FactorRange"},"x_scale":{"id":"2646","type":"CategoricalScale"},"y_range":{"id":"2644","type":"DataRange1d"},"y_scale":{"id":"2648","type":"LinearScale"}},"id":"2640","subtype":"Figure","type":"Plot"},{"attributes":{"bottom":{"expr":{"id":"2676","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"2677","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"2695","type":"VBar"},{"attributes":{"callback":null,"start":0},"id":"2644","type":"DataRange1d"},{"attributes":{"overlay":{"id":"2667","type":"BoxAnnotation"}},"id":"2661","type":"BoxZoomTool"},{"attributes":{"label":{"value":"medals.silver"},"renderers":[{"id":"2696","type":"GlyphRenderer"}]},"id":"2706","type":"LegendItem"},{"attributes":{},"id":"2687","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"2639","type":"ColumnDataSource"}},"id":"2697","type":"CDSView"},{"attributes":{"fields":["medals.bronze","medals.silver","medals.gold"]},"id":"2679"," ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
