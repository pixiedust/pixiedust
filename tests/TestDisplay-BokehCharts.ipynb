# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 0.83</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from bokeh.charts.utils import df_from_json

# utilize utility to make it easy to get json/dict data converted to a dataframe
df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['total'] > 0]
df = df.sort_values("total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  bronze  gold  silver  total           name
# 65  RUS       7     6       8     21   Russian Fed.
# 81  USA      10     6       4     20  United States
# 54  NLD       8     6       6     20    Netherlands
# 56  NOR       7     8       4     19         Norway
# 13  CAN       4     4       8     16         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><div id="chartFigured6a49d3d" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#
#     <div class="bk-root">
#         <div class="bk-plot-layout bk-layout-fixed" id="modelid_3cd34eda-a69b-420f-b4be-afe2ae8cd7fd" style="width: 798px; height: 596px;"><div class="bk-toolbar-wrapper bk-layout-null" id="modelid_25731efa-cb7d-41dc-8dd4-51b8ea689316" style="left: 768px; top: 5px; width: 30px; height: 591px;"><div class="bk-toolbar-right bk-toolbar-sticky"><a href="http://bokeh.pydata.org/" target="_blank" class="bk-logo bk-logo-small"></a><div class="bk-button-bar"><div class="bk-button-bar-list" type="pan"><div class="bk-toolbar-button bk-active"><div class="bk-btn-icon bk-tool-icon-pan"></div><span class="bk-tip">Pan</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-box-zoom"></div><span class="bk-tip">Box Zoom</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-resize"></div><span class="bk-tip">Resize</span></div></div><div class="bk-button-bar-list" type="scroll"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-wheel-zoom"></div><span class="bk-tip">Wheel Zoom</span></div></div><div class="bk-button-bar-list" type="pinch"></div><div class="bk-button-bar-list" type="tap"></div><div class="bk-button-bar-list" type="press"></div><div class="bk-button-bar-list" type="rotate"></div><div class="bk-button-bar-list" type="actions"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-save"></div><span class="bk-tip">Save</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-reset"></div><span class="bk-tip">Reset</span></div></div><div class="bk-button-bar-list" type="inspectors"></div><div class="bk-button-bar-list" type="help"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-help"></div><span class="bk-tip">Click the question mark to learn more about Bokeh plot tools.</span></div></div></div></div></div><div class="bk-plot-wrapper" style="position: absolute; left: 0px; top: 0px; width: 798px; height: 596px;"><div class="bk-canvas-wrapper" style="touch-action: none; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); width: 798px; height: 596px;"><div class="bk-canvas-events"></div><div class="bk-canvas-overlays"><div class="bk-shading" style="display: none;"></div></div><canvas class="bk-canvas" width="1436.3999619483948" height="1072.7999715805054" style="width: 798px; height: 596px;"></canvas><div class="bk-resize-popup" style="display: none;"></div></div></div></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c13e1e13-e430-4a17-b89a-5a45ee8c96ae").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c13e1e13-e430-4a17-b89a-5a45ee8c96ae");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c13e1e13-e430-4a17-b89a-5a45ee8c96ae' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3a2af434-b42c-4d8f-96e9-c597488c6dbb":{"roots":{"references":[{"attributes":{"data_source":{"id":"f7e2b7b2-9092-4c9e-85ca-25b5559c5e73","type":"ColumnDataSource"},"glyph":{"id":"02cfd3c6-a7dc-4bc9-bd6c-332014b28eff","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"20245b54-3ed8-4c0a-8120-f1cd9a3ecfe4","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"3cd34eda-a69b-420f-b4be-afe2ae8cd7fd","subtype":"Chart","type":"Plot"}},"id":"a5fc47a2-1709-4dfd-b741-a35fa0d3ded2","type":"ResizeTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f748a574-6f54-4ea9-bbbb-76389c4b37f1","type":"Rect"},{"attributes":{"below":[{"id":"09cdd341-9ab5-484d-9423-5b3db34bbb7e","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"0794d792-8dcd-4a67-b557-0de8a4a6ce7a","type":"LinearAxis"}],"plot_height":596,"plot_width":798,"renderers":[{"id":"1dfaf64f-7895-43c5-a01c-8403db2490b1","type":"BoxAnnotation"},{"id":"acd90ab4-9616-44fe-bdde-c0a7ce25a15f","type":"GlyphRenderer"},{"id":"46e9a92f-23b8-4b50-8b6e-8e1669587f1e","type":"GlyphRenderer"},{"id":"436a73b1-ce51-44ea-8528-b186b6c6f97b","type":"GlyphRenderer"},{"id":"92abd852-1b4e-473d-b5cd-d25dccc4ffe2","type":"GlyphRenderer"},{"id":"06f0952b-366d-4094-a1f4-1ecd362d0efd","type":"GlyphRenderer"},{"id":"e6eae35b-046b-498c-aa6a-4c8c425fb3c0","type":"GlyphRenderer"},{"id":"8c4e5189-eae2-4593-a6d2-e17327f19411","type":"GlyphRenderer"},{"id":"20245b54-3ed8-4c0a-8120-f1cd9a3ecfe4","type":"GlyphRenderer"},{"id":"02248583-599a-4c8f-b2d5-8502493bfe79","type":"GlyphRenderer"},{"id":"e040c1d1-c6a4-4b3d-b778-b98df859d130","type":"GlyphRenderer"},{"id":"4b7e2157-b8af-4f90-aa81-d1634e108cde","type

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='histogram',nostore_figureOnly='true',keyFields='total',valueFields='total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd5180de-5741-410b-be99-b5529ee2df51"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bd5180de-5741-410b-be99-b5529ee2df51").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd5180de-5741-410b-be99-b5529ee2df51");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd5180de-5741-410b-be99-b5529ee2df51' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3388a2c6-96ed-4fc3-be53-66c3b48f351c":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c3dcdc7b-64c8-4dd8-a836-678cb32cf8b9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad4e54f7-4879-4c3d-b608-39004ed66207","type":"Rect"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"652899f3-7075-4c23-93da-0f7a54805178","subtype":"Chart","type":"Plot"},"ticker":{"id":"7924cf55-01fd-4448-9330-aacfcc221b94","type":"BasicTicker"}},"id":"a70dae30-f8ec-4e77-b344-d349b2fc0868","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["[1.000000, 3.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"label":["[1.000000, 3.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["2.0"],"y":[2.5]}},"id":"ed7437d9-f2a0-43a4-a604-a62649ad81c2","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":21.55,"start":0.44999999999999996},"id":"804ba759-5224-4f00-a4a6-984f7d7e6a46","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(19.000000, 21.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(19.000000, 21.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["20.0"],"y":[2.0]}},"id":"21d892e7-3b15-419c-923d-093679026732","type":"ColumnDataSource"},{"attributes":{"location":"top_left","plot":{"id":"652899f3-7075-4c23-93da-0f7a54805178","subtype":"Chart","type":"Plot"}},"id":"8d0c354f-8fc8-4427-81c8-ff9e76d81595","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d303ad6-5f4a-4be7-ae4d-45672f3816d4","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"aa79ca18-c354-409b-a134-724d2f34573a","type":"PanTool"},{"id":"9c054bf4-4cf9-4c3d-8626-efb7c6772369","type":"WheelZoomTool"},{"id":"9bba1856-bab3-41bd-aa32-13c6d3d61c84","type":"BoxZoomTool"},{"id":"6e6ff323-d322-42bf-87c8-ca88230e1476","type":"SaveTool"},{"id":"ec827404-0e18-4f41-a203-827ffb37969b","type":"ResetTool"},{"id":"3e8e14b1-c978-40b2-88a8-8b6d7d702ad5","type":"HelpTool"},{"id":"2d88a8a5-7a52-444c-9919-bb307c4cc02f","type":"ResizeTool"}]},"id":"4486cb64-eb5f-4946-92f0-91deaae9d533","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(15.000000, 17.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(15.000000, 17.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["16.0"],"y":[1.0]}},"id":"12417dae-01d8-4113-af50-4f20baa8eea3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"12417dae-01d8-4113-af50-4f20baa8eea3","type":"ColumnDataSource"},"glyph":{"id":"e501c7b7-ea19-46d6-8548-e22b0bbbe384","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a69a17b7-495d-4f78-88e3-f43202a9e46b","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"0e1a77b5-feeb-4694-bcc4-4e19fedcfd87","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"c55c1f30-519b-4f7f-ba23-fd73cd16923b","type":"LinearAxis"}],"plot_height":596,"plot_width":798,"renderers":[{"id":"c28a5407-1990-467e-b03c ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='scatterPlot',nostore_figureOnly='true',keyFields='total',valueFields='gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..."  class="pd_save"></center>

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='lineChart',keyFields='abbr',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="abd43fa7-251a-4e77-95cc-5b69f8059e88"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("abd43fa7-251a-4e77-95cc-5b69f8059e88").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("abd43fa7-251a-4e77-95cc-5b69f8059e88");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'abd43fa7-251a-4e77-95cc-5b69f8059e88' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7a1005df-e579-4f4a-bcf9-51710e52282f":{"roots":{"references":[{"attributes":{"axis_label":"silver","formatter":{"id":"8d918b05-9e7d-47c6-9b0d-5204b7acc527","type":"BasicTickFormatter"},"plot":{"id":"24dae9ee-6cf2-442b-bb78-1e49808a06ac","subtype":"Chart","type":"Plot"},"ticker":{"id":"a8ff2edd-d2fc-463a-bce5-95757e95558b","type":"BasicTicker"}},"id":"7b922b96-088e-4a34-a5ee-60fcd080a956","type":"LinearAxis"},{"attributes":{"plot":{"id":"6105d137-0383-4144-af92-897a8050d287","subtype":"Chart","type":"Plot"}},"id":"e9bfccbb-7db2-4791-8998-52f2449534c4","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6105d137-0383-4144-af92-897a8050d287","subtype":"Chart","type":"Plot"}},"id":"e447aa69-48d1-4c53-8549-01e640ba9b47","type":"HelpTool"},{"attributes":{},"id":"0d56673e-5598-4123-bb38-abd87211f786","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"7271a4a0-af75-43f3-b516-5598dc6177b1","subtype":"Chart","type":"Plot"}},"id":"15d29ae1-f591-4424-8685-1a0c05f7dabf","type":"HelpTool"},{"attributes":{"axis_label":"abbr","formatter":{"id":"a9ebf441-77e3-44bd-b1be-67f1b464e216","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"24dae9ee-6cf2-442b-bb78-1e49808a06ac","subtype":"Chart","type":"Plot"},"ticker":{"id":"6518cdd3-2265-43b0-88cf-65caf33c13c2","type":"CategoricalTicker"}},"id":"a2c61dad-e285-419b-9115-68feb1be665f","type":"CategoricalAxis"},{"attributes":{},"id":"8d918b05-9e7d-47c6-9b0d-5204b7acc527","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"c43f3fb0-3f96-47a2-9489-12ee786cc1c9","type":"ToolbarBox"},{"id":"0ac60d8c-c3bd-4608-b376-718ba727f879","type":"Column"}]},"id":"24381ba5-ae33-4e07-b7b6-575d72d93f62","type":"Column"},{"attributes":{},"id":"86b8cb8f-523b-4a1c-b695-f999e909c14d","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"a13c8041-14f4-445e-aad7-afa4e70355ab","type":"ColumnDataSource"},"glyph":{"id":"8ab95aaf-4650-435b-93f6-44b7fcb10567","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"87189f51-cc47-4a3e-a2fa-61ca8f139036","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":["AUS","AUT","BLR","CAN","CHE","CHN","CZE","DEU","FIN","FRA","GBR","HRV","ITA","JPN","KAZ","KOR","LVA","NLD","NOR","POL","RUS","SVK","SVN","SWE","UKR","USA"],"y_values":[2,6,0,8,3,2,3,3,3,2,0,1,2,4,0,1,1,6,4,0,8,0,1,5,0,4]}},"id":"a13c8041-14f4-445e-aad7-afa4e70355ab","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"24dae9ee-6cf2-442b-bb78-1e49808a06ac","subtype":"Chart","type":"Plot"}},"id":"780cc843-a21c-4a8a-b7ce-188dee1e991b","type":"PanTool"},{"attributes":{"overlay":{"id":"34e15ccf-ee71-4cb9-b9b4-9dd87e626520","type":"BoxAnnotation"},"plot":{"id":"7271a4a0-af75-43f3-b516-5598dc6177b1","subtype":"Chart","type":"Plot"}},"id":"83e0c29b-7b50-4754-b518-ef388e6ef386","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"e0711b38-809e-49a4-a6db-7b9b96925589","type":"ColumnDataSource"},"glyph":{"id":"e7528c10-77a7-40c0-b285-39314b4c4ec4","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2346b584-bff3-4525-ae00-8b50d9a295a4","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"6105d137-0383-4144-af92-897a8050d287","subtype":"Chart","type":"Plot"}},"id":"4aa6e45f-1cda-470d-bb6b-6a46d6d4a469","type":"Legend"},{"attributes":{"below":[{"id":"fe7c1864-c2c0-4bc7-ac47-067c86660a4a","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"37228d92-8253-4a11-9677-e9c43185345e","type":"LinearAxis"}],"plot_height":399,"plot_width":399,"renderers":[{"id":"4b300f3a-6bde-4bdd-a465-94e12f30b81f","type":"BoxAnnotation"},{"id":"ecc5dcd3-1a4a-4f60-9192-3597463db703","type":"GlyphRenderer"},{"id":"4aa6e45f-1cda-470d-bb6b-6a46d6d4a469"," ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',handlerId='barChart',keyFields='name',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..."  class="pd_save"></center>
#
#
#                         <div>Some labels are not displayed because of a lack of space. Click on Stretch image to see them all</div>

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#               <div class="fixed-cell">abbr</div>
#
#               <div class="fixed-cell">bronze</div>
#
#               <div class="fixed-cell">gold</div>
#
#               <div class="fixed-cell">silver</div>
#
#               <div class="fixed-cell">total</div>
#
#               <div class="fixed-cell">name</div>
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#                 <th><div>abbr</div></th>
#
#                 <th><div>bronze</div></th>
#
#                 <th><div>gold</div></th>
#
#                 <th><div>silver</div></th>
#
#                 <th><div>total</div></th>
#
#                 <th><div>name</div></th>
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#                 <td>RUS</td>
#
#                 <td>7</td>
#
#                 <td>6</td>
#
#                 <td>8</td>
#
#                 <td>21</td>
#
#                 <td>Russian Fed.</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>USA</td>
#
#                 <td>10</td>
#
#                 <td>6</td>
#
#                 <td>4</td>
#
#                 <td>20</td>
#
#                 <td>United States</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NLD</td>
#
#                 <td>8</td>
#
#                 <td>6</td>
#
#                 <td>6</td>
#
#                 <td>20</td>
#
#                 <td>Netherlands</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NOR</td>
#
#                 <td>7</td>
#
#                 <td>8</td>
#
#                 <td>4</td>
#
#                 <td>19</td>
#
#                 <td>Norway</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CAN</td>
#
#                 <td>4</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>16</td>
#
#                 <td>Canada</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>DEU</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>3</td>
#
#                 <td>15</td>
#
#                 <td>Germany</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CHE</td>
#
#                 <td>1</td>
#
#                 <td>6</td>
#
#                 <td>3</td>
#
#                 <td>10</td>
#
#                 <td>Switzerland</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>FRA</td>
#
#                 <td>5</td>
#
#                 <td>3</td>
