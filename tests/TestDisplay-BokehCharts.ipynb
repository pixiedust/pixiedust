# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.10</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure2ce6d330" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-2ce6d330 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-2ce6d330" data-parent="#df-table-wrapper-2ce6d330">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-2ce6d330" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-2ce6d330" data-parent="#df-table-wrapper-2ce6d330"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-2ce6d330" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header" style="width: 763px;">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell" style="width: 72px;">abbr</div>
#
#                 <div class="fixed-cell" style="width: 148px;">medals.bronze</div>
#
#                 <div class="fixed-cell" style="width: 129px;">medals.gold</div>
#
#                 <div class="fixed-cell" style="width: 138px;">medals.silver</div>
#
#                 <div class="fixed-cell" style="width: 131px;">medals.total</div>
#
#                 <div class="fixed-cell" style="width: 146px;">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"e0043320-26fd-44ce-bf29-a4c9d82ee5fc":{"roots":{"references":[{"attributes":{"children":[{"id":"3994700b-596b-467b-b15b-d3c3171559c0","type":"ToolbarBox"},{"id":"a7d94b48-81fb-4484-95f5-1c0621101a5e","type":"Column"}]},"id":"5dc34490-ff26-4c35-8c86-e2ab11979dcb","type":"Column"},{"attributes":{"plot":{"id":"cb2ff530-9379-4224-aec7-d080fea9f13e","subtype":"Figure","type":"Plot"},"ticker":{"id":"962a15ca-a0e2-4c19-b335-36b798d29d75","type":"BasicTicker"}},"id":"a794a7f8-0235-472a-a1b1-5cc284589f4c","type":"Grid"},{"attributes":{"below":[{"id":"dcb7537e-b172-4465-ab48-5928826095ac","type":"LinearAxis"}],"left":[{"id":"45da66bc-745b-4eab-818f-5a3c78997b41","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"dcb7537e-b172-4465-ab48-5928826095ac","type":"LinearAxis"},{"id":"a794a7f8-0235-472a-a1b1-5cc284589f4c","type":"Grid"},{"id":"45da66bc-745b-4eab-818f-5a3c78997b41","type":"LinearAxis"},{"id":"8b26d46c-1b1d-4fa0-a5d4-af1ef9eba57d","type":"Grid"},{"id":"c719047a-97a7-4e6d-a1cb-879b92c60d75","type":"BoxAnnotation"},{"id":"b1ea983c-6534-4ea2-87bc-f89c0bc70a19","type":"GlyphRenderer"}],"title":{"id":"adacd84f-6364-40f4-8179-515f99cbf3f7","type":"Title"},"toolbar":{"id":"eeddc711-3772-4d7b-a5f3-45a9152d10de","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"9885c47d-5955-4f0a-ab9e-50b41196d213","type":"DataRange1d"},"x_scale":{"id":"cae33a72-d03c-40ce-893f-cc1574d5c975","type":"LinearScale"},"y_range":{"id":"d56d9919-8645-4736-8a81-112008917ee3","type":"DataRange1d"},"y_scale":{"id":"ad67af15-a750-45b4-b863-f7f23f3723ac","type":"LinearScale"}},"id":"cb2ff530-9379-4224-aec7-d080fea9f13e","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"d6123829-4cb1-4a0a-8a71-ed7b4beb0cea","type":"BasicTickFormatter"},"plot":{"id":"cb2ff530-9379-4224-aec7-d080fea9f13e","subtype":"Figure","type":"Plot"},"ticker":{"id":"a478d40c-bf95-4544-ac75-2a74b4feaf0d","type":"BasicTicker"}},"id":"45da66bc-745b-4eab-818f-5a3c78997b41","type":"LinearAxis"},{"attributes":{},"id":"0c72ae58-4e8a-4e08-867e-859bbd53f80d","type":"Selection"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c719047a-97a7-4e6d-a1cb-879b92c60d75","type":"BoxAnnotation"},{"attributes":{},"id":"962a15ca-a0e2-4c19-b335-36b798d29d75","type":"BasicTicker"},{"attributes":{},"id":"0af49c82-b07b-427a-99a6-bd7aff053837","type":"SaveTool"},{"attributes":{"callback":null},"id":"9885c47d-5955-4f0a-ab9e-50b41196d213","type":"DataRange1d"},{"attributes":{"children":[{"id":"cb2ff530-9379-4224-aec7-d080fea9f13e","subtype":"Figure","type":"Plot"}]},"id":"8371aff6-8d2b-4d8f-ae90-a5e9b6583ac1","type":"Row"},{"attributes":{},"id":"d6123829-4cb1-4a0a-8a71-ed7b4beb0cea","type":"BasicTickFormatter"},{"attributes":{"toolbar":{"id":"38feaf5d-6d98-46db-a9a7-d4bef6b1f685","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"3994700b-596b-467b-b15b-d3c3171559c0","type":"ToolbarBox"},{"attributes":{"overlay":{"id":"c719047a-97a7-4e6d-a1cb-879b92c60d75","type":"BoxAnnotation"}},"id":"748664d6-bc20-46c9-bd9f-5149c8dbb79f","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"cb2ff530-9379-4224-aec7-d080fea9f13e","subtype":"Figure","type":"Plot"},"ticker":{"id":"a478d40c-bf95-4544-ac75-2a74b4feaf0d","type":"BasicTicker"}},"id":"8b26d46c-1b1d-4fa0-a5d4-af1ef9eba57d","type":"Grid"},{"attributes":{},"id":"d9c84899-17ad-41a6-9926-1eb976df5fa4","type":"UnionRenderers"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"19191c80-8d02-4aab-86f9-b4b8a9b932cb","type":"Quad"},{"attributes":{"active_drag":"auto","ac ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"0ec9c40a-2ffe-4329-96a0-b28a13bc76b5":{"roots":{"references":[{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"5852c597-4e22-4468-a3f9-3a017a3417da","subtype":"Figure","type":"Plot"},"ticker":{"id":"271fa5c9-cbc2-4960-aa55-28858be8a85b","type":"BasicTicker"}},"id":"a4796afa-c0a5-4fc5-bee1-c3a714d36047","type":"Grid"},{"attributes":{"data_source":{"id":"4aaff43b-bb1d-42a1-957f-532af1af3cdb","type":"ColumnDataSource"},"glyph":{"id":"85f4cd8f-f600-4799-9886-a878a0abef56","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3b9018c6-8dba-4bb4-9fa7-23483433937c","type":"Circle"},"selection_glyph":null,"view":{"id":"a850a4ba-2f76-4899-b670-f1ecae78f041","type":"CDSView"}},"id":"5b7f165a-4de0-442f-8b80-ce53df2d1049","type":"GlyphRenderer"},{"attributes":{},"id":"b2521819-80d7-4d4b-8c4e-855a1fc082bd","type":"UnionRenderers"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"d60151b4-e40d-4140-b5a4-8c6c777c2ea9","type":"Circle"},{"attributes":{"data_source":{"id":"40a75a5c-318b-4fd2-a9db-d07a0b49006e","type":"ColumnDataSource"},"glyph":{"id":"67bd6b54-3ef0-4269-8fc3-ff9ca78b9ec0","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c91b346e-3034-4baa-84d8-2ff2a08b99a8","type":"Circle"},"selection_glyph":null,"view":{"id":"22a6846d-923e-49f5-8196-129398f8c042","type":"CDSView"}},"id":"ebb779c4-c50f-49a2-81e1-36e03baaa42b","type":"GlyphRenderer"},{"attributes":{},"id":"16417783-4ec7-4638-b3c2-96b0156cddb2","type":"Selection"},{"attributes":{},"id":"7e31e591-67d1-4279-ae40-734fa723014b","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"69bcac68-548a-4168-93b1-9d73ee9b7dec","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"a746d0dd-1c7e-4cb0-8183-f3ea602e226a","type":"Circle"},{"attributes":{},"id":"59516bb4-556a-4c23-ac80-a59ccdd835e5","type":"Selection"},{"attributes":{"data_source":{"id":"98a2c3c5-a618-4701-9511-a3774b8c7709","type":"ColumnDataSource"},"glyph":{"id":"4e428d26-940d-426d-8d3d-bf8bed0c8352","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"91f7e488-6fac-40dc-9b88-bc46a9bf37ab","type":"Circle"},"selection_glyph":null,"view":{"id":"7dcedf1b-f23a-49b2-bdb8-08076fb85f06","type":"CDSView"}},"id":"41465b81-2b18-47aa-8f10-0f8a39c5e0f3","type":"GlyphRenderer"},{"attributes":{"source":{"id":"8f912184-4c08-42c7-9e12-1c99a959cd7b","type":"ColumnDataSource"}},"id":"f509af99-a0e5-402e-9c0b-6a31ee934233","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#D7576B"},"line_color":{"value":"#D7576B"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"6135bfbe-afd5-4772-b1d3-5045cee42ad0","type":"Circle"},{"attributes":{"source":{"id":"441707cc-4552-465b-9fa8-ee4f09bb247c","type":"ColumnDataSource"}},"id":"a5d4b1e2-ec4b-43b3-91a4-dab4b69f8ce1","type":"CDSView"},{"attributes":{},"id":"fb2123f0-0bae-4ab9-a94e-e06ebbd5318d","type":"UnionRenderers"},{"attributes":{"label":{"value":"USA"},"renderers":[{"id":"8df6b364-3115-481a-88d7-e6d8a5ab61fb","type":"GlyphRenderer"}]},"id":"75552ee2-4801-40f8-932e-675b45bff541","type":"LegendItem"},{"attributes":{"callback":null,"data":{"x":[1],"y":[0]},"selected":{"id":"83de1b7d-4ba5-409d-95ac-1be1cdc4f657","type":"Selection"},"selection_policy":{"id":"45246f62-5b93-4770-9ca6-4621981695e7","type":"UnionRenderers"}},"id":"0d47fb58-1351-432c-8993-534b356de04e","type":"ColumnDataSource"},{" ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"4dd91ae0-0eeb-42e3-aad0-a6b02d6cdae0":{"roots":{"references":[{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"d792433a-5e50-471a-bf7e-1df131fae16c","type":"GlyphRenderer"}]},"id":"310bad50-4a29-4802-ae1f-845d420a3936","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7a4f5470-b327-42a7-88e4-8642cd979c99","type":"PanTool"},{"id":"d4f1c852-4132-4dcf-bad5-a50fedfe965a","type":"WheelZoomTool"},{"id":"4da3fdff-0082-4c13-8087-85828c45ac66","type":"BoxZoomTool"},{"id":"e94e76c4-2cc2-484e-80cc-802a20ac7a78","type":"SaveTool"},{"id":"79226267-1665-435f-8de7-4aaf3042bb5e","type":"ResetTool"},{"id":"f4822f69-4ddd-4c6f-ae36-fe23ae2aa97d","type":"HelpTool"}]},"id":"15104695-842c-4a06-87c8-408a79cfdf9d","type":"Toolbar"},{"attributes":{},"id":"59d24eab-11e5-43d0-81f6-a650b65482d6","type":"UnionRenderers"},{"attributes":{},"id":"cde63d96-5cad-4536-addc-abf50a1fbdeb","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"755e4d0d-5a3f-4981-a88d-b2d6f5ebc995","type":"ToolbarBox"},{"id":"0f21ee76-d7f7-436a-9a70-860901e7e8dd","type":"Column"}]},"id":"b9d2c5c6-1f32-4de6-85c1-1bc726bad245","type":"Column"},{"attributes":{"tools":[{"id":"7a4f5470-b327-42a7-88e4-8642cd979c99","type":"PanTool"},{"id":"d4f1c852-4132-4dcf-bad5-a50fedfe965a","type":"WheelZoomTool"},{"id":"4da3fdff-0082-4c13-8087-85828c45ac66","type":"BoxZoomTool"},{"id":"e94e76c4-2cc2-484e-80cc-802a20ac7a78","type":"SaveTool"},{"id":"79226267-1665-435f-8de7-4aaf3042bb5e","type":"ResetTool"},{"id":"f4822f69-4ddd-4c6f-ae36-fe23ae2aa97d","type":"HelpTool"}]},"id":"32ea5d60-6b16-4c7a-a8aa-fa57aeee34ad","type":"ProxyToolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3d7216b7-4553-4e3a-8f80-360d3ed724a4","type":"BoxAnnotation"},{"attributes":{},"id":"4cb328ef-afd8-46b1-afa3-78f3b4820060","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"733fd822-3b09-4814-aad5-7a6d06ba88b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"ded5649f-c6d8-45fb-a714-e764146bd1b0","type":"BasicTicker"}},"id":"8e611f5e-71b9-411b-b508-3cd374338923","type":"Grid"},{"attributes":{"source":{"id":"a0e38e68-09c0-459b-9080-93e7a7a6148b","type":"ColumnDataSource"}},"id":"5acb9d4c-d43b-4a9c-bf36-4d6fd7e8465f","type":"CDSView"},{"attributes":{},"id":"d4f1c852-4132-4dcf-bad5-a50fedfe965a","type":"WheelZoomTool"},{"attributes":{},"id":"266dad61-1eb5-4712-aeee-a9c3cee62f82","type":"Selection"},{"attributes":{"overlay":{"id":"3d7216b7-4553-4e3a-8f80-360d3ed724a4","type":"BoxAnnotation"}},"id":"4da3fdff-0082-4c13-8087-85828c45ac66","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"733fd822-3b09-4814-aad5-7a6d06ba88b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"3e425d54-7c3a-47e1-bb2c-e9b9adf7df66","type":"BasicTicker"}},"id":"fbbdb140-2db0-4119-8067-1b019ef52bd0","type":"Grid"},{"attributes":{},"id":"3e425d54-7c3a-47e1-bb2c-e9b9adf7df66","type":"BasicTicker"},{"attributes":{},"id":"79226267-1665-435f-8de7-4aaf3042bb5e","type":"ResetTool"},{"attributes":{"children":[{"id":"358ef8f9-5c55-46d2-bfc3-b272ea8543d0","type":"Row"}]},"id":"0f21ee76-d7f7-436a-9a70-860901e7e8dd","type":"Column"},{"attributes":{"data_source":{"id":"a0e38e68-09c0-459b-9080-93e7a7a6148b","type":"ColumnDataSource"},"glyph":{"id":"51a2b272-8b8b-4f92-9a27-ccbe69ba3810","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"32956d85-5fd9-4abb-98c5-7531d7df9341","type":"Line"},"selection_glyph":null,"view":{"id":"5acb9d4c-d43b-4a9c-bf36-4d6fd7e8465f","type":"CDSView"}},"id":"d792433a-5e50-471a-bf7e-1df131fae16c","type":"GlyphRenderer"},{"attributes":{"axis_label":"medals.gold","formatter ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"15dbc4a5-d3f5-4c48-bb97-ddd90bdcf597":{"roots":{"references":[{"attributes":{},"id":"dc482ebf-60cd-4ca6-bd1a-341eb04c1037","type":"ResetTool"},{"attributes":{},"id":"912da82c-1ca6-41a5-8eae-5293faefa425","type":"LinearScale"},{"attributes":{"fields":["medals.bronze"]},"id":"cb48adec-ed8d-4f39-8572-e41da79b99b1","type":"Stack"},{"attributes":{"fields":["medals.bronze","medals.silver","medals.gold"]},"id":"9f515201-4a93-4011-8ce4-14d8eecd331a","type":"Stack"},{"attributes":{"bottom":{"expr":{"id":"747b8d23-2313-4f67-a55d-d6c6d1927b84","type":"Stack"}},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"14095567-0fcb-495a-9a97-2df2427a2470","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"d44863a9-a9dd-4a31-b80a-4fb25f4c32a2","type":"VBar"},{"attributes":{"label":{"value":"medals.bronze"},"renderers":[{"id":"f67bd307-2d76-402b-84dc-84cde936c3a8","type":"GlyphRenderer"}]},"id":"0b4126e8-18b5-4cb6-948c-e29ba25be65a","type":"LegendItem"},{"attributes":{"bottom":{"expr":{"id":"0c247579-1d8f-4b53-a666-7bb436c4a35a","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"9f515201-4a93-4011-8ce4-14d8eecd331a","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"31528d87-5c11-4b44-a681-75d0a68c3459","type":"VBar"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"bc694944-8d97-4e75-a36f-9b3d79a43e48","type":"GlyphRenderer"}]},"id":"1f6248be-8e72-4a38-bf1c-e86710ed431f","type":"LegendItem"},{"attributes":{"bottom":{"expr":{"id":"cb48adec-ed8d-4f39-8572-e41da79b99b1","type":"Stack"}},"fill_color":{"value":"#ff7f0e"},"line_color":{"value":"#ff7f0e"},"top":{"expr":{"id":"4319151e-a2ef-42ed-ac80-5156b471e4d7","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"a24f6b52-aedf-4f54-b550-d71c5cbbd5b2","type":"VBar"},{"attributes":{"overlay":{"id":"d0b3a420-b7e4-4cef-a108-fe621092e5b2","type":"BoxAnnotation"}},"id":"e4f7c2fb-2ec1-4d89-92e1-82cce87c624c","type":"BoxZoomTool"},{"attributes":{},"id":"2e8b2a78-d2ff-4374-a1b2-e1ae44a0c8ed","type":"BasicTickFormatter"},{"attributes":{"fields":["medals.bronze","medals.silver"]},"id":"0c247579-1d8f-4b53-a666-7bb436c4a35a","type":"Stack"},{"attributes":{"toolbar":{"id":"91b0435a-e6de-42a5-b1c9-34e313c06a40","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"3fad5de0-283b-474f-957b-192338ce1102","type":"ToolbarBox"},{"attributes":{"axis_label":"name","formatter":{"id":"4d3f5001-fb9f-4260-a583-6909b73506e2","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"plot":{"id":"aef1bdd2-abc3-415c-bc03-d2d47ee58655","subtype":"Figure","type":"Plot"},"ticker":{"id":"060a4db8-c58b-4696-9faa-9b26cec9cb77","type":"CategoricalTicker"}},"id":"96322533-c54e-4cb7-ae81-83fb432fcf26","type":"CategoricalAxis"},{"attributes":{"fields":[]},"id":"747b8d23-2313-4f67-a55d-d6c6d1927b84","type":"Stack"},{"attributes":{},"id":"c0a0d8db-dfb1-4e5f-b1ca-fc146d645353","type":"Selection"},{"attributes":{"bottom":{"expr":{"id":"747b8d23-2313-4f67-a55d-d6c6d1927b84","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"14095567-0fcb-495a-9a97-2df2427a2470","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"d81fa77a-81a5-488c-b52f-28f4de46ab03","type":"VBar"},{"attributes":{"fields":["medals.bronze","medals.silver"]},"id":"4319151e-a2ef-42ed-ac80-5156b471e4d7","type":"Stack"},{"attributes":{"dimension":1,"plot":{"id":"aef1bdd2-abc3-415c-bc03-d2d47ee58655","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a64c15a-5c9e-4b44-b8d9-6eed2817eaa2","type":"BasicTicker"}},"id":"e836da3f-286f-4075-9a30-667e4e174bf6","type":"Grid"},{"attributes":{"children":[{"id":"3fad5de0-283b-474f-957b-192338ce1102","type":"Too ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
