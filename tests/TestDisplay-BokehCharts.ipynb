# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.6</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-e91671d1 panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-e91671d1" data-parent="#df-table-wrapper-e91671d1">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-e91671d1" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-e91671d1" data-parent="#df-table-wrapper-e91671d1">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-e91671d1" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">abbr</div>
#
#
#
#               <div class="fixed-cell">medals.bronze</div>
#
#
#
#               <div class="fixed-cell">medals.gold</div>
#
#
#
#               <div class="fixed-cell">medals.silver</div>
#
#
#
#               <div class="fixed-cell">medals.total</div>
#
#
#
#               <div class="fixed-cell">name</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>abbr</div></th>
#
#
#
#                 <th><div>medals.bronze</div></th>
#
#
#
#                 <th><div>medals.gold</div></th>
#
#
#
#                 <th><div>medals.silver</div></th>
#
#
#
#                 <th><div>medals.total</div></th>
#
#
#
#                 <th><div>name</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>RUS</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>21</td>
#
#
#
#                 <td>Russian Fed.</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>USA</td>
#
#
#
#                 <td>10</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>4</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>United States</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NLD</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>Netherlands</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NOR</td>

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"5c4962ca-8a0f-4728-a9cf-160cc704b6f3":{"roots":{"references":[{"attributes":{"toolbar":{"id":"f4f336a7-3189-4fef-8339-d7a08f3aa05b","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"f993d109-0fdd-4614-a5b6-7916227340e3","type":"ToolbarBox"},{"attributes":{},"id":"c298bc84-7672-4b6c-9bce-f1cf2356420a","type":"SaveTool"},{"attributes":{"overlay":{"id":"cc5e3871-3c90-4cb8-8f7c-32335da9876a","type":"BoxAnnotation"}},"id":"3a72d434-dfb8-42bc-9901-c7c2ef558077","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}}},"id":"6d435bf4-efe2-4198-bd23-5f08e94e9147","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"b26ab84a-d6a6-4e34-bb7d-e9ce04dad447","type":"LinearAxis"}],"left":[{"id":"d6508727-5d54-4efb-b6fa-a3592fccd558","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"b26ab84a-d6a6-4e34-bb7d-e9ce04dad447","type":"LinearAxis"},{"id":"f180b4fb-dc3d-4a63-b7dd-7f712fa00ad3","type":"Grid"},{"id":"d6508727-5d54-4efb-b6fa-a3592fccd558","type":"LinearAxis"},{"id":"76f087f5-8e81-47fe-a9ba-cb37610b8ba4","type":"Grid"},{"id":"cc5e3871-3c90-4cb8-8f7c-32335da9876a","type":"BoxAnnotation"},{"id":"e8ce3408-2e20-4d29-b6f7-b266a0ed3b87","type":"GlyphRenderer"}],"title":{"id":"3c16b87d-2e54-421c-a665-11a35f22d41d","type":"Title"},"toolbar":{"id":"b640f717-a627-4287-8831-65d801bf6e43","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"31fe586b-27d7-4e9b-80c1-465086dd7c62","type":"DataRange1d"},"x_scale":{"id":"22b7d9c7-43a0-4190-9c12-87ee82257717","type":"LinearScale"},"y_range":{"id":"ae7b6023-86a8-48d1-955f-0375568ef256","type":"DataRange1d"},"y_scale":{"id":"b3b47430-ac88-4dad-b1d4-a646ea87a0e1","type":"LinearScale"}},"id":"c438b9d1-5a38-4a77-bb41-3ff69a1151f5","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"358e91da-1434-4cce-a2e6-21f1cc47a031","type":"WheelZoomTool"},{"attributes":{},"id":"c4d50f2a-64df-408d-9a17-e12fcee69306","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cc5e3871-3c90-4cb8-8f7c-32335da9876a","type":"BoxAnnotation"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"01e7337e-ca62-49ba-849f-0381f6dc6b47","type":"BasicTickFormatter"},"plot":{"id":"c438b9d1-5a38-4a77-bb41-3ff69a1151f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"c4d50f2a-64df-408d-9a17-e12fcee69306","type":"BasicTicker"}},"id":"b26ab84a-d6a6-4e34-bb7d-e9ce04dad447","type":"LinearAxis"},{"attributes":{},"id":"6d708d82-9fdb-4c16-9354-5b3bb71a634c","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"0aa739db-92f3-4aa8-96a4-3a7caef05fa5","type":"Quad"},{"attributes":{"callback":null,"start":0},"id":"ae7b6023-86a8-48d1-955f-0375568ef256","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"96da2838-001c-48b6-83bc-b030a6b4503d","type":"PanTool"},{"id":"358e91da-1434-4cce-a2e6-21f1cc47a031","type":"WheelZoomTool"},{"id":"3a72d434-dfb8-42bc-9901-c7c2ef558077","type":"BoxZoomTool"},{"id":"c298bc84-7672-4b6 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"7ad6a78e-fc7e-4acc-b610-9f2338bd73da":{"roots":{"references":[{"attributes":{"label":{"value":"CAN"},"renderers":[{"id":"1743c331-22f8-40df-a6ec-97d33b788fa4","type":"GlyphRenderer"}]},"id":"aa94620e-48b3-424a-92a9-28396e7785dd","type":"LegendItem"},{"attributes":{"label":{"value":"GBR"},"renderers":[{"id":"85c6aa23-ba5b-4876-b579-2652dca38ecf","type":"GlyphRenderer"}]},"id":"fddcf25c-d4e8-4cab-a93e-49ba4ee02b3d","type":"LegendItem"},{"attributes":{"source":{"id":"0a63806c-39aa-4206-827d-46f74972e547","type":"ColumnDataSource"}},"id":"6ca6eed3-a717-418e-905e-4644d0a293b1","type":"CDSView"},{"attributes":{"data_source":{"id":"184893c5-6282-4401-b902-29e7044dc361","type":"ColumnDataSource"},"glyph":{"id":"346c80db-e1fe-4c3e-8dbb-403ca06a14d9","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c1f143ba-e100-4c49-9f54-16e4a22a2e4d","type":"Circle"},"selection_glyph":null,"view":{"id":"60d0afaf-a249-4787-ae39-4258ddf42423","type":"CDSView"}},"id":"225e23ea-22e8-4e6f-96bd-7221e3e53e70","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[7],"y":[1]}},"id":"23f6b1f7-55a1-4a0f-ad11-03667f362a24","type":"ColumnDataSource"},{"attributes":{"label":{"value":"HRV"},"renderers":[{"id":"29dad51d-60c0-41a2-92ea-e171b1d56a72","type":"GlyphRenderer"}]},"id":"5e793b14-2fbe-4d8a-9b6d-e0511ad973e4","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3],"y":[0]}},"id":"14d75299-1f60-43d7-b824-38036040655c","type":"ColumnDataSource"},{"attributes":{"source":{"id":"b452d725-a2bb-4e94-993b-317d8c86b4e5","type":"ColumnDataSource"}},"id":"13337c61-8984-48bf-a556-40213af7b78b","type":"CDSView"},{"attributes":{"label":{"value":"UKR"},"renderers":[{"id":"e65e25b1-898f-4e02-9901-03e673c05cfa","type":"GlyphRenderer"}]},"id":"33980311-0ad5-41ba-b485-8dcf35c24086","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[9],"y":[2]}},"id":"1e6affc6-1f14-4f8d-aa5a-6558c38d2b80","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#FDC427"},"line_color":{"value":"#FDC427"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"dc47c160-b505-481f-aaba-c4afb6681d5c","type":"Circle"},{"attributes":{"source":{"id":"61beea72-adb6-41ba-aa49-c6b6c2573195","type":"ColumnDataSource"}},"id":"2549c1a1-47e6-40e0-b91d-95b1615b5519","type":"CDSView"},{"attributes":{"data_source":{"id":"28073742-8340-4d86-a126-48b0bf70b5f2","type":"ColumnDataSource"},"glyph":{"id":"536f3e22-533c-4f38-ac36-d8f7ea8d3aee","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fe79ed4a-13e9-4f33-9127-af659f5f7956","type":"Circle"},"selection_glyph":null,"view":{"id":"2bab38fd-794d-45da-b5ad-0e4e5f3c7538","type":"CDSView"}},"id":"9a86e19f-c63e-4d51-8212-34d8bcba9c70","type":"GlyphRenderer"},{"attributes":{"label":{"value":"BLR"},"renderers":[{"id":"a4b5c644-500c-4c1e-a5f4-a513d5a43d16","type":"GlyphRenderer"}]},"id":"734aaa3d-c253-41cf-b45c-85dcc7ff5cc4","type":"LegendItem"},{"attributes":{"label":{"value":"SVK"},"renderers":[{"id":"afeb5ea0-9943-47f7-8a9a-637b4a8fda3b","type":"GlyphRenderer"}]},"id":"ebfe8148-201c-42fb-abab-a41e047e2027","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0a7b09f-633e-4f60-a44e-5957e75d36c4","type":"Circle"},{"attributes":{"label":{"value":"POL"},"renderers":[{"id":"8fcb338f-0987-4c5f-b788-2f0e7f06b765","type":"GlyphRenderer"}]},"id":"5bcc0fd7-2359-476f-80ff-9ece265c2aea","type":"LegendItem"},{"attributes":{"data_source":{"id":"14d75299-1f60-43d7-b824-38036040655c","type":"ColumnDataSource"},"glyph":{"id":"cdcb418b-f199-40c9-b37d-5a8a4354beba","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"23bc0d46-8a63-4b50-bef0-2fc7b0d17544":{"roots":{"references":[{"attributes":{},"id":"03106125-007d-42bd-b580-fbdc3e8482d9","type":"BasicTicker"},{"attributes":{},"id":"d79aec30-81fc-43bb-8be5-aad2aee34a69","type":"BasicTicker"},{"attributes":{"children":[{"id":"fbdfc8bd-6484-41e9-98e0-b5cb657b6012","type":"Row"}]},"id":"384d4d95-f166-43a6-b69b-ed286420dab1","type":"Column"},{"attributes":{"tools":[{"id":"0701020d-7c92-4d51-8e6e-1beba5d8c2d9","type":"PanTool"},{"id":"34c24268-965b-481c-a7ef-3b61516074be","type":"WheelZoomTool"},{"id":"c86184aa-39dd-4b64-abec-50c2ba659943","type":"BoxZoomTool"},{"id":"213af821-3b08-4a55-a186-b64c479801b9","type":"SaveTool"},{"id":"55dc6f95-2e08-4e19-b125-3c5fa1fd85a0","type":"ResetTool"},{"id":"95fd17aa-40ff-4477-bd13-96834bbf52cc","type":"HelpTool"}]},"id":"87e8f54c-9a38-4037-b05f-b45ea696f2ed","type":"ProxyToolbar"},{"attributes":{"children":[{"id":"fb0d3d15-82e2-484a-8d8c-100baa96df3c","subtype":"Figure","type":"Plot"}]},"id":"fbdfc8bd-6484-41e9-98e0-b5cb657b6012","type":"Row"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2ab20583-1b59-4423-9a36-0a3377a36343","type":"Line"},{"attributes":{},"id":"0701020d-7c92-4d51-8e6e-1beba5d8c2d9","type":"PanTool"},{"attributes":{"axis_label":"medals.silver","formatter":{"id":"565618af-d9bd-4870-8214-3bebb46fcec5","type":"BasicTickFormatter"},"plot":{"id":"fb0d3d15-82e2-484a-8d8c-100baa96df3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"03106125-007d-42bd-b580-fbdc3e8482d9","type":"BasicTicker"}},"id":"89f5933a-6406-4d8c-879b-ba31368067af","type":"LinearAxis"},{"attributes":{},"id":"95fd17aa-40ff-4477-bd13-96834bbf52cc","type":"HelpTool"},{"attributes":{"items":[{"id":"2247a4c8-3b9b-4689-b01e-cb15e6ff1355","type":"LegendItem"}],"location":"top_left","plot":{"id":"fb0d3d15-82e2-484a-8d8c-100baa96df3c","subtype":"Figure","type":"Plot"}},"id":"b5d812d4-29bd-429b-ba56-9d93b4f82a18","type":"Legend"},{"attributes":{"data_source":{"id":"1a03dca2-c408-4a62-a2bb-a39c71461bb4","type":"ColumnDataSource"},"glyph":{"id":"2ab20583-1b59-4423-9a36-0a3377a36343","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d65461d7-0bd9-44c4-8f93-78281f7dc306","type":"Line"},"selection_glyph":null,"view":{"id":"6461c3f1-2d1e-4960-887f-f8a698a212c5","type":"CDSView"}},"id":"7afe7361-fdc5-4353-983e-76378105d129","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0701020d-7c92-4d51-8e6e-1beba5d8c2d9","type":"PanTool"},{"id":"34c24268-965b-481c-a7ef-3b61516074be","type":"WheelZoomTool"},{"id":"c86184aa-39dd-4b64-abec-50c2ba659943","type":"BoxZoomTool"},{"id":"213af821-3b08-4a55-a186-b64c479801b9","type":"SaveTool"},{"id":"55dc6f95-2e08-4e19-b125-3c5fa1fd85a0","type":"ResetTool"},{"id":"95fd17aa-40ff-4477-bd13-96834bbf52cc","type":"HelpTool"}]},"id":"0132f37c-95f1-453f-bcc4-106c944f5ef4","type":"Toolbar"},{"attributes":{},"id":"a0496e37-c5e5-4ead-a175-f72967d515ca","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6,8],"y":[11,4,6,15,15,2,8,10]}},"id":"1a03dca2-c408-4a62-a2bb-a39c71461bb4","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"fb0d3d15-82e2-484a-8d8c-100baa96df3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"d79aec30-81fc-43bb-8be5-aad2aee34a69","type":"BasicTicker"}},"id":"3e911cf1-2040-43fe-b51a-1ebd3ae8d437","type":"Grid"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"7afe7361-fdc5-4353-983e-76378105d129","type":"GlyphRenderer"}]},"id":"2247a4c8-3b9b-4689-b01e-cb15e6ff1355","type":"LegendItem"},{"attributes":{"plot":{"id":"fb0d3d15-82e2-484a-8d8c-100baa96df3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"03106125-007d-42bd-b580-fbdc3e8482d9","type":"BasicTicker"}},"id":"5ae40a5f-a0b4-4244-b351-47f95dae3c52","type":"Grid"},{"attributes":{"axis_label":"medals.gold","for ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"7fabc340-7385-4fa0-968b-a4521ac64925":{"roots":{"references":[{"attributes":{"data_source":{"id":"90b0d019-008a-410d-b353-ae720177ed36","type":"ColumnDataSource"},"glyph":{"id":"151b0c6e-9f6c-4526-9758-b384bd516bb6","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9254e7fb-a6d0-4d63-8f77-6282c43c4999","type":"VBar"},"selection_glyph":null,"view":{"id":"d72f959e-6115-4a01-8f0f-7f93f5e1c38b","type":"CDSView"}},"id":"10c8588f-468e-41e9-95b3-141bc05a419d","type":"GlyphRenderer"},{"attributes":{"tools":[{"id":"c9b582f9-55a0-46ba-9283-d0710b4534fd","type":"PanTool"},{"id":"4ac05834-7ced-4067-8a0f-2ad52ebe749d","type":"WheelZoomTool"},{"id":"d078dea7-a5dc-4661-a5f0-bdcdaba7ac27","type":"BoxZoomTool"},{"id":"3de0d67d-00dd-4660-9b52-decdd5be1b86","type":"SaveTool"},{"id":"0db63dec-808e-4440-b30c-42ff44dfe50d","type":"ResetTool"},{"id":"e21577f0-71b5-4e83-ad61-cdd0e1daec48","type":"HelpTool"}]},"id":"94e38700-f775-4e17-8c7e-da9f2b0edb5b","type":"ProxyToolbar"},{"attributes":{"data_source":{"id":"90b0d019-008a-410d-b353-ae720177ed36","type":"ColumnDataSource"},"glyph":{"id":"91913a0e-a42f-4bfc-9450-ec8a53293140","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a887a1a8-cadd-474c-8b5f-34b3624a803b","type":"VBar"},"selection_glyph":null,"view":{"id":"afc1a7bd-f87e-4b60-92b7-e547149f1263","type":"CDSView"}},"id":"de287286-615b-4f5f-8781-d75d34bf49cb","type":"GlyphRenderer"},{"attributes":{},"id":"0b7ac174-dd25-42ad-8c0d-aae07029f731","type":"CategoricalTicker"},{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"d120c3db-0d67-4b11-9ebd-d24331c9ebee","type":"FactorRange"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f807ac7f-bc51-4f0f-bf37-194f58c35b51","type":"BoxAnnotation"},{"attributes":{"toolbar":{"id":"94e38700-f775-4e17-8c7e-da9f2b0edb5b","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"ffa3fe88-3040-41c8-87a5-ce8ad15e8553","type":"ToolbarBox"},{"attributes":{"bottom":{"expr":{"id":"9b523202-7f53-468a-9a39-72644cc90726","type":"Stack"}},"fill_color":{"value":"#ff7f0e"},"line_color":{"value":"#ff7f0e"},"top":{"expr":{"id":"8ff954a8-d33f-47ff-ae79-faf6114c5fcd","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"068c61d9-df4a-40dc-91d9-55ddc6f6f3f3","type":"VBar"},{"attributes":{"bottom":{"expr":{"id":"f5f45eb8-76db-4583-8b8c-93d19bf0afbe","type":"Stack"}},"fill_color":{"value":"#2ca02c"},"line_color":{"value":"#2ca02c"},"top":{"expr":{"id":"019bdad3-4147-44b7-af78-5795c03118f8","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"151b0c6e-9f6c-4526-9758-b384bd516bb6","type":"VBar"},{"attributes":{"bottom":{"expr":{"id":"9b523202-7f53-468a-9a39-72644cc90726","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"8ff954a8-d33f-47ff-ae79-faf6114c5fcd","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"753096d4-e7dd-4245-a170-d6020066160d","type":"VBar"},{"attributes":{},"id":"3de0d67d-00dd-4660-9b52-decdd5be1b86","type":"SaveTool"},{"attributes":{"overlay":{"id":"f807ac7f-bc51-4f0f-bf37-194f58c35b51","type":"BoxAnnotation"}},"id":"d078dea7-a5dc-4661-a5f0-bdcdaba7ac27","type":"BoxZoomTool"},{"attributes":{},"id":"0db63dec-808e-4440-b30c-42ff44dfe50d","type":"ResetTool"},{"attributes":{},"id":"3 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">abbr</div>
#
#
#
#               <div class="fixed-cell">medals.bronze</div>
#
#
#
#               <div class="fixed-cell">medals.gold</div>
#
#
#
#               <div class="fixed-cell">medals.silver</div>
#
#
#
#               <div class="fixed-cell">medals.total</div>
#
#
#
#               <div class="fixed-cell">name</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>abbr</div></th>
#
#
#
#                 <th><div>medals.bronze</div></th>
#
#
#
#                 <th><div>medals.gold</div></th>
#
#
#
#                 <th><div>medals.silver</div></th>
#
#
#
#                 <th><div>medals.total</div></th>
#
#
#
#                 <th><div>name</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>RUS</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>21</td>
#
#
#
#                 <td>Russian Fed.</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>USA</td>
#
#
#
#                 <td>10</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>4</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>United States</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NLD</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>Netherlands</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NOR</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>4</td>

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
