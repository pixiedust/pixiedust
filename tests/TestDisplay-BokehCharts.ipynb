# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.14</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><script class="pd_save is-viewer-good">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-81484e0c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"e7239d91-9709-4b47-a3cd-2558aebcf02f":{"roots":{"references":[{"attributes":{},"id":"06408036-9457-4d97-9117-e63d3eced1d2","type":"ResetTool"},{"attributes":{},"id":"7fc71bfd-4ee4-4d5b-8777-c346cc5cc432","type":"PanTool"},{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"448e11af-9e3d-491c-8822-eeb843b8a445","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["pd_stacked_col","medals.total"],"data":{"medals.total":[3,9,6,16,6,1,6,3,10,15,2,6,7,1,4,3,20,19,4,21,1,7,9,10,1,20],"pd_stacked_col":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"]}},"id":"80fb2e5e-9762-4e61-95f3-c171efdb51b8","type":"ColumnDataSource"},{"attributes":{},"id":"f0b504f5-71af-45ab-99e4-86ced522444d","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"060d48ca-c77b-4fa8-9db0-26576711d5de","type":"BoxAnnotation"}},"id":"cc18ea7c-4d46-48fd-bddd-c1b7f1d4d36e","type":"BoxZoomTool"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"4fa39bf8-8b0b-4326-b9f6-239c90ec5037","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"09805b8d-f5c8-4b52-bd67-b623bac9beb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"47856f2a-8e62-4230-b6cd-1783018419a8","type":"BasicTicker"}},"id":"de7d8259-27b8-43fb-b0ec-b56dac0d47ee","type":"LinearAxis"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"09805b8d-f5c8-4b52-bd67-b623bac9beb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"4ab5bfb3-c880-4594-9460-077d3fbb2307","type":"CategoricalTicker"}},"id":"ec109e54-41d5-4ce7-8c4d-33f9b5b7aa93","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"09805b8d-f5c8-4b52-bd67-b623bac9beb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"47856f2a-8e62-4230-b6cd-1783018419a8","type":"BasicTicker"}},"id":"b5756c73-fe10-416e-917f-440f6f7257c2","type":"Grid"},{"attributes":{"callback":null,"tooltips":[["name","@pd_stacked_col{0.00}"],["medals.total","@medals.total{0.00}"]]},"id":"a023598f-66bd-44af-89a0-aa63c9be09ef","type":"HoverTool"},{"attributes":{},"id":"eba983cf-4215-4daa-b66c-7abee75bd5c4","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"060d48ca-c77b-4fa8-9db0-26576711d5de","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"89c107e6-bea5-4f73-8828-75d88a61cb1c","type":"ToolbarBox"},{"id":"c7373e5b-1306-418b-bb66-0a244031fb48","type":"Column"}]},"id":"c22d00b7-665d-4471-807e-c23779bbecc1","type":"Column"},{"attributes":{},"id":"516ed373-2f2f-45d2-8321-eb52a739b0cf","type":"LinearScale"},{"attributes":{"below":[{"id":"8785266a-394b-4f03-8d5a-4a9975fe479f","type":"CategoricalAxis"}],"left":[{"id":"de7d8259-27b8-43fb-b0ec-b56dac0d47ee","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":495,"plot_width":770,"renderers":[{"id":"8785266a-394b-4f03-8d5a-4a9975fe479f","type":"CategoricalAxis"},{"id":"ec109e54-41d5-4ce7-8c4d-33f9b5b7aa93","type":"Grid"},{"id":"de7d8259-27b8-43fb-b0ec-b56dac0d47ee","type":"LinearAxis"},{"id":"b5756c73-fe10-416e-917f-440f6f7257c2","type":"Grid"},{"id":"060d48ca-c77b-4fa8-9db0-26576711d5de","type":"BoxAnnotation"},{"id":"9beac4dc-a9a4-45d4-a4eb-f6021969eb7f","type":"Legend"},{"id":"dc1e5a22-a79d-450c-b185-0 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"f450614f-fa6a-44b8-8c46-5a2028b69c2e":{"roots":{"references":[{"attributes":{},"id":"20bdbe25-d731-4c2a-bdfe-d581ec1dc9e2","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"a4c2c737-5083-46ee-8593-177471873090","type":"LinearAxis"}],"left":[{"id":"9254b2c9-d8c6-4499-9e34-6d63cb8f2c88","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"a4c2c737-5083-46ee-8593-177471873090","type":"LinearAxis"},{"id":"b5d66126-1550-4c1f-a2ed-0f6998ba66f4","type":"Grid"},{"id":"9254b2c9-d8c6-4499-9e34-6d63cb8f2c88","type":"LinearAxis"},{"id":"b207e40f-db85-4359-af89-6189ca1186f9","type":"Grid"},{"id":"1e6dc5c2-1969-4b3b-92c1-fd0628709412","type":"BoxAnnotation"},{"id":"25f2a561-57cb-4718-81e0-f7678bc03be6","type":"GlyphRenderer"}],"title":{"id":"e9d0fa7d-63a6-42d4-8727-13d093a5bc2b","type":"Title"},"toolbar":{"id":"01dca268-5764-437f-8cf9-3ce63c29026d","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"73b47d8a-9ac4-410b-b086-e9761987fdcc","type":"DataRange1d"},"x_scale":{"id":"a713ff42-9c11-4af9-809c-a3dcd0c53d65","type":"LinearScale"},"y_range":{"id":"a047cab5-e118-4865-9f0d-9a840ab395fc","type":"DataRange1d"},"y_scale":{"id":"7432523e-0f3e-43af-8c5e-d80e8acc2ed5","type":"LinearScale"}},"id":"1329492e-2727-4433-9a2b-54216cc8a9d3","subtype":"Figure","type":"Plot"},{"attributes":{"source":{"id":"b2e62f95-b1f9-4a5d-9c80-bb70bf212e35","type":"ColumnDataSource"}},"id":"4e62074f-a6bb-4474-84d1-3dcc5517c15c","type":"CDSView"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"5cbf5a7f-dfb0-491e-8b92-8ba6d16f3db7","type":"Quad"},{"attributes":{},"id":"b4841604-4cbe-41f4-bc27-56464b932255","type":"BasicTicker"},{"attributes":{},"id":"a713ff42-9c11-4af9-809c-a3dcd0c53d65","type":"LinearScale"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"e7c293c8-b6ce-4ac6-ba01-829176f60770","type":"PanTool"},{"id":"dbb3e135-7145-4b20-9a26-5c25613b3b40","type":"WheelZoomTool"},{"id":"399c5005-8c56-471a-9d78-98f5e6a1479b","type":"BoxZoomTool"},{"id":"3173b603-e2e0-44f3-a2a2-73e95c7e83f4","type":"SaveTool"},{"id":"05cc115a-ee1a-475c-81fb-4a3fdea862df","type":"ResetTool"},{"id":"61add9b6-c89f-4253-b0b8-3f935114258e","type":"HelpTool"},{"id":"e6426f7c-8a48-4101-94b1-a9bd6faf8786","type":"HoverTool"}]},"id":"5aa63929-e6ef-41e0-8a5a-0160e69be2d8","type":"ToolbarBox"},{"attributes":{},"id":"3475423a-9f21-49ef-ab8e-c9b542b843af","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e7c293c8-b6ce-4ac6-ba01-829176f60770","type":"PanTool"},{"id":"dbb3e135-7145-4b20-9a26-5c25613b3b40","type":"WheelZoomTool"},{"id":"399c5005-8c56-471a-9d78-98f5e6a1479b","type":"BoxZoomTool"},{"id":"3173b603-e2e0-44f3-a2a2-73e95c7e83f4","type":"SaveTool"},{"id":"05cc115a-ee1a-475c-81fb-4a3fdea862df","type":"ResetTool"},{"id":"61add9b6-c89f-4253-b0b8-3f935114258e","type":"HelpTool"},{"id":"e6426f7c-8a48-4101-94b1-a9bd6faf8786","type":"HoverTool"}]},"id":"01dca268-5764-437f-8cf9-3ce63c29026d","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}}},"id":"b2e62f95-b1f9-4a5d-9c80-bb70bf212e35","type":"ColumnDataSource"},{"attributes":{},"id":"5e54ba63-c1a5-4068-9cfc-77e3ccbf7285","type":"BasicTickFormatter"},{"attributes":{"callback":null,"start":0},"id":"a ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"fd43c0ba-c027-4bf0-95ae-74798fbc243d":{"roots":{"references":[{"attributes":{"label":{"value":"SWE"},"renderers":[{"id":"0d4fb1cf-ede4-4d41-9621-8fa8ebdc485e","type":"GlyphRenderer"}]},"id":"77f50aab-879d-4bcb-a795-11af284d32d8","type":"LegendItem"},{"attributes":{"data_source":{"id":"8d3b6a0d-0090-414e-8214-b19a919bcf74","type":"ColumnDataSource"},"glyph":{"id":"2a1d44ea-9f8a-407f-b096-8af49eb87e69","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"37fded1a-7bf3-4d29-9bcb-1b583cf13020","type":"Circle"},"selection_glyph":null,"view":{"id":"fe43d248-d7d1-4569-94c1-f72839d71ade","type":"CDSView"}},"id":"979c47a1-bea4-4915-a100-3ef5072615bd","type":"GlyphRenderer"},{"attributes":{},"id":"864334ff-fded-4cd1-ac51-2f95729ca4af","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"137b3746-cbca-42f7-92eb-43e63eb338b2","type":"ColumnDataSource"},"glyph":{"id":"7d8cb8c0-32a3-42c1-8658-1b9fd277dcda","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"717cbd83-aaac-4733-ae9f-cd3963fc652d","type":"Circle"},"selection_glyph":null,"view":{"id":"f29c6403-6722-4a11-98d2-dd3c556cf588","type":"CDSView"}},"id":"20e1c842-7d75-4b8e-b171-a33f0c629c36","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#250591"},"line_color":{"value":"#250591"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"959b8551-0464-4199-b12f-c0b44a0dabf1","type":"Circle"},{"attributes":{"source":{"id":"390c2129-6df0-4ac7-bd12-e1cf6faf0134","type":"ColumnDataSource"}},"id":"acccad10-3d60-4a73-acf2-12c8063d3c49","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#6A00A7"},"line_color":{"value":"#6A00A7"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"742c509b-cf45-40b4-9589-32a7d5357460","type":"Circle"},{"attributes":{"data_source":{"id":"d4ba3799-c4be-455f-bd67-bc21c30f1575","type":"ColumnDataSource"},"glyph":{"id":"4fa31812-0a3c-4ffb-8757-f61f044e6738","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ace280c9-f0e7-4b9e-ae7c-dc16a6e1c6a9","type":"Circle"},"selection_glyph":null,"view":{"id":"0498cd36-46cb-4f30-8fca-254c5e8b7b77","type":"CDSView"}},"id":"5e8b48d7-d5a8-4fb2-b47e-2f5d16b5c40c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#9612A0"},"line_color":{"value":"#9612A0"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"df67b004-581d-4dc9-9f97-a16799a748ae","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[3],"y":[0]}},"id":"a8721a36-0f96-46ef-939e-87cfef81c92c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1],"y":[1]}},"id":"c0154818-c3f1-4818-a0d9-8686cf9a7cea","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3ec009dc-f7af-45ea-9031-6a440bb71292","type":"ColumnDataSource"},"glyph":{"id":"4c87dac2-1b41-4c67-9064-eb8f620a300b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3e6d4dab-e379-4e27-9987-64eedfbb2009","type":"Circle"},"selection_glyph":null,"view":{"id":"ec9e98ec-b777-4a3d-855a-6febaa3a1a2b","type":"CDSView"}},"id":"94bfec04-6b46-498c-a580-e2ad7ee725ca","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"97324b12-b4d8-4336-807c-a79e5ad46aeb","type":"Circle"},{"attributes":{"source":{"id":"e28186d5-9794-445d-9177-e2f382b6c27b","type":"ColumnDataSource"}},"id":"5a2ccdf7-99e7-4b7d-b39c-2897b40904de","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#E87059"},"line_color":{"value":"#E87059"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"4fa31812-0 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"f7bc5d77-516d-43cb-a361-a21418eb8557":{"roots":{"references":[{"attributes":{},"id":"ac859e65-ff2e-43de-b197-6e4760ff6a3c","type":"HelpTool"},{"attributes":{"plot":{"id":"f7afe7d1-483d-4cd4-82e3-53806b9e9a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"0b047253-d3c0-42a1-bebf-71eba35f4862","type":"BasicTicker"}},"id":"fa9d8db8-6503-41ba-b205-06c6c07cb078","type":"Grid"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"7f6e2c5d-3c87-4a01-b189-0d9dfc991808","type":"GlyphRenderer"}]},"id":"646d7cf0-d383-40db-b3dd-8f6846acd9bf","type":"LegendItem"},{"attributes":{"children":[{"id":"0b007ed9-8de0-4794-8a22-a66b9f80ac40","type":"Row"}]},"id":"19f2b7fa-55ee-4536-83f7-ca32d9108e2a","type":"Column"},{"attributes":{},"id":"abac627d-6723-4349-9e11-d46f97328c13","type":"PanTool"},{"attributes":{"source":{"id":"f0b27dbd-bea3-49d8-b5f6-2c5cf2952c00","type":"ColumnDataSource"}},"id":"aa16cebd-b156-440e-a5d1-9d51cf5cb7dc","type":"CDSView"},{"attributes":{"dimension":1,"plot":{"id":"f7afe7d1-483d-4cd4-82e3-53806b9e9a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3a8ce7d8-864b-4cc1-b090-29ed0c6ee1c0","type":"BasicTicker"}},"id":"c703b429-4d66-4984-be93-5d1330b61cc4","type":"Grid"},{"attributes":{},"id":"48426a1c-5d72-4e53-951d-7dd1ba3fd258","type":"WheelZoomTool"},{"attributes":{},"id":"f7579d1d-52f2-498c-8a1f-3f60e2dffff9","type":"SaveTool"},{"attributes":{},"id":"85f9ec72-f1c0-46ec-85db-1d84bb6dc638","type":"LinearScale"},{"attributes":{"items":[{"id":"646d7cf0-d383-40db-b3dd-8f6846acd9bf","type":"LegendItem"}],"location":"top_left","plot":{"id":"f7afe7d1-483d-4cd4-82e3-53806b9e9a4c","subtype":"Figure","type":"Plot"}},"id":"64427247-66d6-4fc4-a6a1-03d985b03413","type":"Legend"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"2314db5f-7730-4362-865e-d038d964f3a6","type":"Line"},{"attributes":{},"id":"13fdfdb9-e623-4049-9559-75a6089cb279","type":"ResetTool"},{"attributes":{},"id":"7257d5ed-27e7-4c0e-a540-1a65ce639b7e","type":"LinearScale"},{"attributes":{"data_source":{"id":"f0b27dbd-bea3-49d8-b5f6-2c5cf2952c00","type":"ColumnDataSource"},"glyph":{"id":"9f3da906-56a8-4108-b0a5-c0579578488a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2314db5f-7730-4362-865e-d038d964f3a6","type":"Line"},"selection_glyph":null,"view":{"id":"aa16cebd-b156-440e-a5d1-9d51cf5cb7dc","type":"CDSView"}},"id":"7f6e2c5d-3c87-4a01-b189-0d9dfc991808","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"f7afe7d1-483d-4cd4-82e3-53806b9e9a4c","subtype":"Figure","type":"Plot"}]},"id":"0b007ed9-8de0-4794-8a22-a66b9f80ac40","type":"Row"},{"attributes":{"axis_label":"medals.silver","formatter":{"id":"90da88e4-e1d2-41aa-93e2-91f758c0bbfd","type":"BasicTickFormatter"},"plot":{"id":"f7afe7d1-483d-4cd4-82e3-53806b9e9a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"0b047253-d3c0-42a1-bebf-71eba35f4862","type":"BasicTicker"}},"id":"c0666772-3774-4d12-961b-886070ea7c08","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"abac627d-6723-4349-9e11-d46f97328c13","type":"PanTool"},{"id":"48426a1c-5d72-4e53-951d-7dd1ba3fd258","type":"WheelZoomTool"},{"id":"4e83d5f1-31d0-4f58-9811-151cdc46a973","type":"BoxZoomTool"},{"id":"f7579d1d-52f2-498c-8a1f-3f60e2dffff9","type":"SaveTool"},{"id":"13fdfdb9-e623-4049-9559-75a6089cb279","type":"ResetTool"},{"id":"ac859e65-ff2e-43de-b197-6e4760ff6a3c","type":"HelpTool"},{"id":"f50c7672-7c0b-42cf-8b65-9a1634a0c3df","type":"HoverTool"}]},"id":"9c6583eb-2f37-408a-8f96-98e631427b60","type":"Toolbar"},{"attributes":{"below":[{"id":"c0666772-3774-4d12-961b-886070ea7c08","type":"LinearAxis"}],"left":[{"id":"c98904c2-8b34-4019-b43f-bdd086fe85da","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"c0666772-3774-4d12-961b-886070ea7c08","type":"LinearAxis"},{"i ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"6cf4cdc2-2fab-4583-9df0-5f349e316d3b":{"roots":{"references":[{"attributes":{"axis_label":"medals.bronze,medals.silver,medals.gold","formatter":{"id":"0765b7d2-f5ea-4d7b-bf3a-b4dcf813f49b","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"e19ca307-032e-4976-be8c-979fc3ca3a3a","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b443430-71aa-4687-be43-c217e5ca1e66","type":"BasicTicker"}},"id":"2304ae95-b85d-4de7-bd03-d188402cd1e6","type":"LinearAxis"},{"attributes":{"data_source":{"id":"980e6829-adc7-425e-a336-4eb26e87d163","type":"ColumnDataSource"},"glyph":{"id":"b3f63c16-2886-4fe1-9c18-9571f4ab06c4","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"56823496-7292-4135-bd47-d31c52abf53c","type":"VBar"},"selection_glyph":null,"view":{"id":"3e518adf-cd0a-4ffb-a4ca-719bfefc28d1","type":"CDSView"}},"id":"413bdb9e-31d3-407b-838d-8a1113eab16e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"980e6829-adc7-425e-a336-4eb26e87d163","type":"ColumnDataSource"},"glyph":{"id":"32f9c4d0-d46a-461e-9d94-67c4132948e7","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"61eff9a5-f86c-4fef-aa34-c8d8f1051274","type":"VBar"},"selection_glyph":null,"view":{"id":"1af793a4-5bd1-4c4b-a8f3-113519c1afc8","type":"CDSView"}},"id":"cdff892b-d4b9-40fa-929b-28dd2650cad1","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"980e6829-adc7-425e-a336-4eb26e87d163","type":"ColumnDataSource"},"glyph":{"id":"2fe9f0e2-e4ee-4fcf-a631-062d332a0a5a","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"512813fd-d2f5-4065-a581-3b0ab9fe8bdc","type":"VBar"},"selection_glyph":null,"view":{"id":"89b7d9a6-db13-4408-8421-4e597bf1b900","type":"CDSView"}},"id":"a7676d04-2bbd-4ab6-a65b-51a3f2f15b31","type":"GlyphRenderer"},{"attributes":{"bottom":{"expr":{"id":"697176bf-1a24-4296-8bb8-9a751e3ed86d","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"a8079f03-c8e5-4f66-97c8-a42a8c13a89e","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"61eff9a5-f86c-4fef-aa34-c8d8f1051274","type":"VBar"},{"attributes":{},"id":"c11451fc-fdea-4729-81b6-386a679ab478","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["pd_stacked_col","medals.bronze","medals.silver","medals.gold"],"data":{"medals.bronze":[1,1,1,4,1,0,2,0,5,4,1,4,2,1,1,2,8,7,0,7,0,4,2,1,1,10],"medals.gold":[0,2,5,4,3,0,1,0,3,8,1,0,1,0,2,0,6,8,4,6,1,2,2,6,0,6],"medals.silver":[2,6,0,8,2,1,3,3,2,3,0,2,4,0,1,1,6,4,0,8,0,1,5,3,0,4],"pd_stacked_col":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"]}},"id":"980e6829-adc7-425e-a336-4eb26e87d163","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"02bab40f-2717-45f1-a843-df63c5264b35","type":"PanTool"},{"id":"82e318f6-049b-4773-b4cd-23e0aa4c8b32","type":"WheelZoomTool"},{"id":"5e1aaf27-f1d1-4359-8fa2-5550d2311e13","type":"BoxZoomTool"},{"id":"c11451fc-fdea-4729-81b6-386a679ab478","type":"SaveTool"},{"id":"f0d80f50-80a5-4d56-89cb-0a0960c2c70e","type":"ResetTool"},{"id":"2ee9251f-6c0e-488e-94b4-eee23217c20a","type":"HelpTool"},{"id":"272341e6-7213-4f78-bf05-4821bf65a0bb","type":"HoverTool"}]},"id":"670406e3-42ae-4cb7-a483-c75591f4df3a","type":"Toolbar"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"02bab40f-2717-45f1-a843-df63c5264b35","type":"PanTool"},{"id":"82e318f6-049b-4773-b4cd-23e0aa4c8b32","type":"WheelZoomTool"},{"id":"5e1aaf27-f1d1-4359-8fa2-5550d2311e13","type":"BoxZoomTool"},{"id":"c11451fc-fdea-4729-81b6-386a679 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
