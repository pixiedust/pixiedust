# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.3</span>
#         </div>
# /Users/jbarbosa/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: bokeh.util.notebook was deprecated in Bokeh 0.12.10 and will be removed, use bokeh.io.notebook instead.
#   warn(message)

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-0b601645 panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-0b601645" data-parent="#df-table-wrapper-0b601645">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-0b601645" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-0b601645" data-parent="#df-table-wrapper-0b601645">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-0b601645" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">abbr</div>
#
#
#
#               <div class="fixed-cell">medals.bronze</div>
#
#
#
#               <div class="fixed-cell">medals.gold</div>
#
#
#
#               <div class="fixed-cell">medals.silver</div>
#
#
#
#               <div class="fixed-cell">medals.total</div>
#
#
#
#               <div class="fixed-cell">name</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>abbr</div></th>
#
#
#
#                 <th><div>medals.bronze</div></th>
#
#
#
#                 <th><div>medals.gold</div></th>
#
#
#
#                 <th><div>medals.silver</div></th>
#
#
#
#                 <th><div>medals.total</div></th>
#
#
#
#                 <th><div>name</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>RUS</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>21</td>
#
#
#
#                 <td>Russian Fed.</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>USA</td>
#
#
#
#                 <td>10</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>4</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>United States</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NLD</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>Netherlands</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NOR</td>

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#c3f8bb9b-c071-43d7-9cfd-16a3368d6657").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"21e9dda8-5402-4e1f-8014-e87ff6d244fc":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b2880bcc-cb44-4bc8-8e29-9a6e28dc10d6","type":"PanTool"},{"id":"613f2af7-960d-4a14-ad2d-8ac798cdfc56","type":"WheelZoomTool"},{"id":"6c9db73c-1115-4039-a842-ab1258355fb8","type":"BoxZoomTool"},{"id":"b294511b-0768-4cfc-a0f8-320db86cbb93","type":"SaveTool"},{"id":"e30ed5d6-6105-4954-85a3-48a870f4dd16","type":"ResetTool"},{"id":"b972bb38-871a-40b7-984f-19f6fb32f191","type":"HelpTool"}]},"id":"b92cd7ec-c574-4a43-a8d9-193d059bab78","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"2427520e-3be1-4448-8efe-eea3cc9531e3","type":"Title"},{"attributes":{"overlay":{"id":"d0fee04b-de3d-4648-ad2a-a91a7dedf85d","type":"BoxAnnotation"}},"id":"6c9db73c-1115-4039-a842-ab1258355fb8","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}}},"id":"1bb60f40-41b7-41c7-8511-5cb714570634","type":"ColumnDataSource"},{"attributes":{},"id":"226fd9b0-2286-4daa-b991-56a4847a41fd","type":"LinearScale"},{"attributes":{"children":[{"id":"7ad5f124-cead-418f-9c95-f211cf0b02a0","type":"Row"}]},"id":"65fb762c-3eb2-4764-b5f0-68351fbdf80f","type":"Column"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"b3bae8df-c9cf-4731-ab1e-661423cf090c","type":"Quad"},{"attributes":{},"id":"5d0ba509-fdf7-4a07-9cc0-86a3f4ecea97","type":"BasicTickFormatter"},{"attributes":{},"id":"711c441c-1b21-4e7c-bba8-aaa13e4bf2d2","type":"BasicTicker"},{"attributes":{},"id":"b294511b-0768-4cfc-a0f8-320db86cbb93","type":"SaveTool"},{"attributes":{"toolbar":{"id":"dd36f7c8-de86-4058-be38-e516dfbcc5c3","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"c1abf8e0-18e6-4e98-9df2-6f39bd480112","type":"ToolbarBox"},{"attributes":{},"id":"b972bb38-871a-40b7-984f-19f6fb32f191","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"9877c97a-5d88-4385-a0de-a501beaac14d","subtype":"Figure","type":"Plot"},"ti

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#8923811a-6a78-4da8-a21a-ffc9b14eb4ba").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"6f335caf-51f9-46c6-a1b6-91e88f60dc0b":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3],"y":[0]}},"id":"71ac8223-e4a9-4f49-be0f-81f9d4d16601","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#49029F"},"line_color":{"value":"#49029F"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ed556c4-d7e9-4922-8b05-b5054b9ebc8a","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#D7576B"},"line_color":{"value":"#D7576B"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"623f1eaf-211b-4666-bc12-ee867e241544","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#FDB52D"},"line_color":{"value":"#FDB52D"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"54716d01-9709-4571-8619-a1865ae4d6b5","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[6],"y":[5]}},"id":"e3bcc20c-4917-4941-9c16-bde60dd2fc7f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"013985f2-ff45-4144-8573-a218622567aa","type":"ColumnDataSource"},"glyph":{"id":"f094c9f2-2ae2-46ef-9445-53f61921546a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c1612f8e-9a8b-4b5a-925e-b0d74c35d8b8","type":"Circle"},"selection_glyph":null,"view":{"id":"6795cbc8-99d2-4a49-9a16-d7d58e4fbbea","type":"CDSView"}},"id":"b48fff01-ef97-4acb-a947-88072a2e3190","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[20],"y":[6]}},"id":"013985f2-ff45-4144-8573-a218622567aa","type":"ColumnDataSource"},{"attributes":{"label":{"value":"NLD"},"renderers":[{"id":"43e33f33-a51c-4699-8885-505d27edd06b","type":"GlyphRenderer"}]},"id":"d8b78bd1-4ed0-4535-86d0-bb5bbfd5e238","type":"LegendItem"},{"attributes":{"label":{"value":"RUS"},"renderers":[{"id":"44674f5e-aa8c-4f87-8e09-bb2323379ad3","type":"GlyphRenderer"}]},"id":"72fc106a-50aa-449b-9b2e-38b4eca77394","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"3dc1a2d9-d26e-46a7-9fe9-89c49627bb05","type":"Circle"},{"attributes":{"data_source":{"id":"4c8bcc3b-18ee-403e-88bc-d7798efec6da","type":"ColumnDataSource"},"glyph":{"id":"533dfe53-63e9-4b63-9b35-4cf33271a39f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2af85599-4212-468c-b84c-3a7a015b5fda","type":"Circle"},"selection_glyph":null,"view":{"id":"dc41b7cf-c338-4

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#41891c00-4337-496e-a259-5dfdc9ef4260").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"5bc059c4-70c0-4251-afef-370572fa7084":{"roots":{"references":[{"attributes":{"children":[{"id":"73693ef9-74e5-4a59-8bc1-c237821818b0","subtype":"Figure","type":"Plot"}]},"id":"4c1260bd-81ab-42d0-be87-41f70ce3415d","type":"Row"},{"attributes":{"children":[{"id":"47f19216-7ac4-4f51-a51b-5c7cebfcf039","type":"ToolbarBox"},{"id":"78a2e42b-570b-445e-ac8e-52f257f436c5","type":"Column"}]},"id":"35c8ef19-abcf-4d70-84d8-23de0b8a5ea9","type":"Column"},{"attributes":{"source":{"id":"4ee9ca46-22f2-49af-8ec3-b589dd080740","type":"ColumnDataSource"}},"id":"04e97305-0324-4287-8d8f-f555d5d937bf","type":"CDSView"},{"attributes":{"children":[{"id":"4c1260bd-81ab-42d0-be87-41f70ce3415d","type":"Row"}]},"id":"78a2e42b-570b-445e-ac8e-52f257f436c5","type":"Column"},{"attributes":{"axis_label":"medals.gold","formatter":{"id":"b9bf1ea9-b155-4362-8580-97adfbe68c0e","type":"BasicTickFormatter"},"plot":{"id":"73693ef9-74e5-4a59-8bc1-c237821818b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"e32bd5b8-e27e-4e50-adc3-e1572662a30e","type":"BasicTicker"}},"id":"d8c2e23b-5a4d-4d2e-b89f-2d625fefdab6","type":"LinearAxis"},{"attributes":{"axis_label":"medals.silver","formatter":{"id":"d83f4b7a-2957-4baa-8d76-6a2faaa0e9a9","type":"BasicTickFormatter"},"plot":{"id":"73693ef9-74e5-4a59-8bc1-c237821818b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"064d16ee-778d-47c3-a433-c4ca08e26b80","type":"BasicTicker"}},"id":"c4e58d95-a88a-4597-919e-a765cf514302","type":"LinearAxis"},{"attributes":{},"id":"cec2ad11-9987-404e-88fb-9e689527c7fd","type":"SaveTool"},{"attributes":{"callback":null},"id":"4c63b8f9-978f-426c-8970-345e1fc88a80","type":"DataRange1d"},{"attributes":{"tools":[{"id":"651008ef-de9d-40de-9549-605e9c6bb599","type":"PanTool"},{"id":"a209b934-a803-4afe-85d3-6eba8fc481e1","type":"WheelZoomTool"},{"id":"c1b74521-d5da-4f72-9754-ced3b5203f72","type":"BoxZoomTool"},{"id":"cec2ad11-9987-404e-88fb-9e689527c7fd","type":"SaveTool"},{"id":"5de9a894-51fc-462c-a16a-26600ea9f828","type":"ResetTool"},{"id":"8d2f03a1-a85d-43cf-a133-7cebfd0645e4","type":"HelpTool"}]},"id":"a0c6efa4-94c1-48d5-ba7d-a841d104cca3","type":"ProxyToolbar"},{"attributes":{"data_source":{"id":"4ee9ca46-22f2-49af-8ec3-b589dd080740","type":"ColumnDataSource"},"glyph":{"id":"f43d12cf-7f52-4e79-b662-8584928c2574","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"effa32b1-2bb9-45ca-9fd2-f14e2941c751","type":"Line"},"selection_glyph":null,"view":{"id":"04e97305-0324-4287-8d8f-f555d5d937bf","type":"CDSView"}},"id":"87ab1ec1-b754-41db-9b57-d1e275d0aca2","type":"GlyphRenderer"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"87ab1ec1-b754-41db-9b57-d1e275d0aca2","type

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#b2f2a12f-32a1-4c70-b18b-b24d15e8b024").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"5e3330ac-21c0-4552-b6ce-26d4e18d1049":{"roots":{"references":[{"attributes":{},"id":"ad8dd728-4cea-432f-a7b9-de467856b3ab","type":"CategoricalTickFormatter"},{"attributes":{},"id":"e2d9b1ab-af36-499c-9795-13fd32806de5","type":"BasicTicker"},{"attributes":{"toolbar":{"id":"2cb987aa-1211-4650-bc3a-17d33a710f50","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"1a1c49f8-ad88-478d-b489-6b66c79be6be","type":"ToolbarBox"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3c375cc0-7647-4507-acfa-16f9468bb396","type":"BoxAnnotation"},{"attributes":{"bottom":{"expr":{"id":"33ef065e-0701-4886-b4e6-541689b80acb","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"889e05b3-b495-4781-beda-97e1a71c8a45","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"a36ad549-a6aa-43fc-a88c-a07f865e6093","type":"VBar"},{"attributes":{"fields":["medals.bronze"]},"id":"5a4cddb6-a280-4725-96af-e53142f38f4f","type":"Stack"},{"attributes":{"data_source":{"id":"f848d478-2731-4683-a456-52ca52488331","type":"ColumnDataSource"},"glyph":{"id":"362ff72d-596b-448d-8b91-e393a862b343","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f794b410-c8ec-4248-8e38-f5fc2adfb795","type":"VBar"},"selection_glyph":null,"view":{"id":"f798c726-fd4e-49b6-9c92-521dc4cb1bd7","type":"CDSView"}},"id":"00632c59-3bf7-41e8-8205-89606a3e1467","type":"GlyphRenderer"},{"attributes":{"source":{"id":"f848d478-2731-4683-a456-52ca52488331","type":"ColumnDataSource"}},"id":"f926b91d-0019-4f73-9c0a-9d095f182b16","type":"CDSView"},{"attributes":{"data_source":{"id":"f848d478-2731-4683-a456-52ca52488331","type":"ColumnDataSource"},"glyph":{"id":"02390ced-1d2d-4b55-924a-91936f243252","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a36ad549-a6aa-43fc-a88c-a07f865e6093","type":"VBar"},"selection_glyph":null,"view":{"id":"f926b91d-0019-4f73-9c0a-9d095f182b16","type":"CDSView"}},"id":"8af7a7dd-a19b-4c9f-b28d-e5e7b74e933d","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4e7073d1-c81b-4cff-bbbd-c74bd869d35f","type":"PanTool"},{"id":"8bade2d7-6473-4822-98ca-fe94188f9f7e","type":"WheelZoomTool"},{"id":"8c1801fe-70d8-46d3-92a2-11202e79bce7","type":"BoxZoomTool"},{

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">abbr</div>
#
#
#
#               <div class="fixed-cell">medals.bronze</div>
#
#
#
#               <div class="fixed-cell">medals.gold</div>
#
#
#
#               <div class="fixed-cell">medals.silver</div>
#
#
#
#               <div class="fixed-cell">medals.total</div>
#
#
#
#               <div class="fixed-cell">name</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>abbr</div></th>
#
#
#
#                 <th><div>medals.bronze</div></th>
#
#
#
#                 <th><div>medals.gold</div></th>
#
#
#
#                 <th><div>medals.silver</div></th>
#
#
#
#                 <th><div>medals.total</div></th>
#
#
#
#                 <th><div>name</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>RUS</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>21</td>
#
#
#
#                 <td>Russian Fed.</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>USA</td>
#
#
#
#                 <td>10</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>4</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>United States</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NLD</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>Netherlands</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NOR</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>4</td>

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
