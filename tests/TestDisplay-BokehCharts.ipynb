# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.12</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.1.12, Latest is 1.1.11</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure769de4ad" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-769de4ad")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"e69082dd-4e0e-474c-9123-b2405988012b":{"roots":{"references":[{"attributes":{},"id":"06d36c26-d5a9-4f56-b51c-aa186c9b8d0e","type":"UnionRenderers"},{"attributes":{},"id":"2d67fa36-abab-4fab-87dd-b7fe175919a1","type":"CategoricalTickFormatter"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"166f5b4c-cc09-419a-b0af-6364c7f66df4","subtype":"Figure","type":"Plot"},"ticker":{"id":"cfaa325a-75b2-4e9a-9fd8-11d325fe0846","type":"CategoricalTicker"}},"id":"eaf2b34e-a068-482b-8508-6a38856d6f70","type":"Grid"},{"attributes":{"label":{"value":"medals.total"},"renderers":[{"id":"cabf0e3e-4cec-4eb7-a59d-9ac84d9dfe18","type":"GlyphRenderer"}]},"id":"c92e9e37-0f22-4e75-861f-039eb5bc00a4","type":"LegendItem"},{"attributes":{},"id":"c1ab43c8-87d2-43e0-afe7-a83960385866","type":"BasicTicker"},{"attributes":{},"id":"18dde802-86f0-4a7a-981e-ccb4e6347929","type":"Selection"},{"attributes":{"bottom":{"expr":{"id":"8e0c2225-cc6e-4f85-bc06-533bf9d73d09","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"91d04898-fc50-41b7-9768-9b6d9fb12a72","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"9606a000-7482-4dec-8460-88a6bff8d9ef","type":"VBar"},{"attributes":{"fields":[]},"id":"8e0c2225-cc6e-4f85-bc06-533bf9d73d09","type":"Stack"},{"attributes":{"children":[{"id":"152c527e-759e-4775-abb0-0c3381a3f3b8","type":"ToolbarBox"},{"id":"5026ec43-906b-4bf9-9b31-d3ce523855d0","type":"Column"}]},"id":"9beeb9e3-bf77-4bbd-8854-9bfbf7016985","type":"Column"},{"attributes":{"axis_label":"name","formatter":{"id":"2d67fa36-abab-4fab-87dd-b7fe175919a1","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"plot":{"id":"166f5b4c-cc09-419a-b0af-6364c7f66df4","subtype":"Figure","type":"Plot"},"ticker":{"id":"cfaa325a-75b2-4e9a-9fd8-11d325fe0846","type":"CategoricalTicker"}},"id":"8a3960ad-283d-4c00-be90-b566bcfb2f09","type":"CategoricalAxis"},{"attributes":{"dimension":1,"plot":{"id":"166f5b4c-cc09-419a-b0af-6364c7f66df4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1ab43c8-87d2-43e0-afe7-a83960385866","type":"BasicTicker"}},"id":"1ee06010-51ac-4a01-9559-370f3dbd6b64","type":"Grid"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"a65d7c60-7734-4d6f-af54-9dd031df36a6","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"166f5b4c-cc09-419a-b0af-6364c7f66df4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1ab43c8-87d2-43e0-afe7-a83960385866","type":"BasicTicker"}},"id":"d56ab41e-2e41-4b82-aeca-a043473b9974","type":"LinearAxis"},{"attributes":{"children":[{"id":"166f5b4c-cc09-419a-b0af-6364c7f66df4","subtype":"Figure","type":"Plot"}]},"id":"534468ce-e533-4f00-a970-f2c0c9c3733c","type":"Row"},{"attributes":{"items":[{"id":"c92e9e37-0f22-4e75-861f-039eb5bc00a4","type":"LegendItem"}],"location":"top_left","plot":{"id":"166f5b4c-cc09-419a-b0af-6364c7f66df4","subtype":"Figure","type":"Plot"}},"id":"9aacf4d1-371f-431c-95f7-9393f95e6390","type":"Legend"},{"attributes":{"tools":[{"id":"8dccde94-892c-4bea-8c7d-fc4c5926d31f","type":"HoverTool"}]},"id":"8c1d56a5-6a0e-4244-9f04-be6d143fcb9b","type":"ProxyToolbar"},{"attributes":{"toolbar":{"id":"8c1d56a5-6a0e-4244-9f04-be6d143fcb9b","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"152c527e-759e-4775-abb0-0c3381a3f3b8","type":"ToolbarBox"},{"attributes":{},"id":"cfaa325a-75b2-4e9a-9fd8-11d325fe0846","type":"CategoricalTicker"},{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"1b426609-9a14-444d-a1b7-b039d0e1b92e","type":"FactorRange"},{"attributes":{"bottom":{" ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"4cf8a970-d88b-480d-896d-9571bbdf7f23":{"roots":{"references":[{"attributes":{"callback":null,"start":0},"id":"e372ff93-d17b-4927-91fe-e8c3739d70a3","type":"DataRange1d"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["Frequency","@top{0.00}"],["Interval","@left - @right"]]},"id":"780456d4-e583-41fd-b047-77094ec64b52","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"780456d4-e583-41fd-b047-77094ec64b52","type":"HoverTool"}]},"id":"9cc2b149-8ec6-4406-ae3c-2c250d508dbd","type":"Toolbar"},{"attributes":{"toolbar":{"id":"43b2a9d0-aadb-49f2-ae28-05b9dac5c5c5","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"22a7d916-d332-44e8-97b7-2b594836b7ba","type":"ToolbarBox"},{"attributes":{"data_source":{"id":"15419c02-0e56-4e2d-8177-c461ce3428f6","type":"ColumnDataSource"},"glyph":{"id":"5ac0047c-29d6-4335-9ff7-a780d9044e8e","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c8ffdac5-e07b-4dc0-9561-850e617997c8","type":"Quad"},"selection_glyph":null,"view":{"id":"6fe71d34-c7d4-469b-aa43-3fadb6b1ed2f","type":"CDSView"}},"id":"1454b2f4-bf51-4921-87ad-ed7ebd50ffc4","type":"GlyphRenderer"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"fe487061-eb2f-4bd1-a2f7-3c257ed0b709","type":"BasicTickFormatter"},"plot":{"id":"ea16ce02-db02-4d92-9aa4-506e666b7b6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"32ce79b5-42f2-4749-9847-63f6cb8e8b73","type":"BasicTicker"}},"id":"b13b1d5d-65b1-4516-8d02-b8db9d89f276","type":"LinearAxis"},{"attributes":{"children":[{"id":"243e17b4-2a39-4a03-bd04-e7153a3b3768","type":"Row"}]},"id":"1c41c760-7145-41d2-859b-4588647428d3","type":"Column"},{"attributes":{},"id":"b8f73671-9583-4c68-84da-b5527bc03642","type":"UnionRenderers"},{"attributes":{"dimension":1,"plot":{"id":"ea16ce02-db02-4d92-9aa4-506e666b7b6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"32ce79b5-42f2-4749-9847-63f6cb8e8b73","type":"BasicTicker"}},"id":"fdb5a52e-59b2-4205-a73f-10c063ddb2dc","type":"Grid"},{"attributes":{"callback":null},"id":"c4c0ce12-ea9c-4636-9db6-6a63f1aa809b","type":"DataRange1d"},{"attributes":{},"id":"cf5a6262-d69d-466e-be18-c403a875f117","type":"Selection"},{"attributes":{},"id":"fe487061-eb2f-4bd1-a2f7-3c257ed0b709","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"22a7d916-d332-44e8-97b7-2b594836b7ba","type":"ToolbarBox"},{"id":"1c41c760-7145-41d2-859b-4588647428d3","type":"Column"}]},"id":"ca0ec89c-1e5f-4bba-ae5b-1fd8bdd80e57","type":"Column"},{"attributes":{"tools":[{"id":"780456d4-e583-41fd-b047-77094ec64b52","type":"HoverTool"}]},"id":"43b2a9d0-aadb-49f2-ae28-05b9dac5c5c5","type":"ProxyToolbar"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"5ac0047c-29d6-4335-9ff7-a780d9044e8e","type":"Quad"},{"attributes":{"callback":null,"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}},"selected":{"id":"cf5a6262-d69d-466e-be18-c403a875f117","type":"Selection"},"selection_policy":{"id":"b8f73671-9583-4c68-84da-b5527bc03642","type":"UnionRenderers"}},"id":"15419c02-0e56-4e2d-8177-c461ce3428f6","type":"ColumnDataSource"},{"attributes":{},"id":"196c439e-bc2e-4f67-8042-25c839164596","type":"BasicTicker"},{"attributes":{},"id":"a2b8726f-0031-4153-a80b-78c39f4d4139","type":"LinearScale"},{"attributes":{"children":[{"id":"ea16ce02-db02-4d92-9aa4-506e ...
#           var render_items = [{"docid":"4cf8a970-d88b-480d-896d-9571bbdf7f23","roots":{"ca0ec89c-1e5f-4bba-ae5b-1fd8bdd80e57":"406cd562-d06b-4b0b-b7d5-e99dd55ba4f6"}}];
#           root.Bokeh.

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"cc488b0f-5c26-41e8-8592-0cac3e28dd8e":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4224219-f391-4162-ad16-5263c47ec5d5","type":"Circle"},{"attributes":{"callback":null,"data":{"x":[4],"y":[2]},"selected":{"id":"18490eb6-1126-4697-a403-7c2d0ebdf513","type":"Selection"},"selection_policy":{"id":"85933deb-f910-4a50-942f-f67767dfc1a3","type":"UnionRenderers"}},"id":"8f4d04bd-5658-4d49-8f8a-4cda65380389","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ed6c13b-c964-45a5-a3f2-2437ab8696b3","type":"Circle"},{"attributes":{"data_source":{"id":"1809eb32-424e-429c-91ad-d74739f1b895","type":"ColumnDataSource"},"glyph":{"id":"9c0b4bb3-314b-4125-aebc-fc3bf3c355c0","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2162dfbb-b7f6-46b3-9baf-656130de72ae","type":"Circle"},"selection_glyph":null,"view":{"id":"8028e93d-4075-4378-9703-d74f6aee17be","type":"CDSView"}},"id":"7ff59e72-e973-4f76-9ba7-605aa6e32376","type":"GlyphRenderer"},{"attributes":{},"id":"e88731d8-d368-4d70-a25d-057f7d8e572c","type":"Selection"},{"attributes":{},"id":"2b94e68b-b8a2-4f5d-8257-4f2a2a7d65cd","type":"UnionRenderers"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#FDC427"},"line_color":{"value":"#FDC427"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e6397e8-1090-46a8-8b33-aec918aa6bfd","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#C5407D"},"line_color":{"value":"#C5407D"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"8138b436-25fe-4db0-9aa9-2b7ad817d86f","type":"Circle"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"3a26c15f-5dc6-4819-97d8-7bcb5b8bf626","subtype":"Figure","type":"Plot"},"ticker":{"id":"e6ec622a-ac8a-4ab8-95e2-7043d59e8c5a","type":"BasicTicker"}},"id":"72824626-2c22-478e-ab39-6c36c570d9dc","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c10a320-d2d9-4a3d-8ec2-60e9dfa804de","type":"Circle"},{"attributes":{"label":{"value":"FRA"},"renderers":[{"id":"7058a6da-f200-489c-ad1b-588128625c92","type":"GlyphRenderer"}]},"id":"0103fba0-7a6a-4a2b-a266-d2f78f419fd9","type":"LegendItem"},{"attributes":{"source":{"id":"74bcf191-6c06-4170-864c-e4ec2356b7e0","type":"ColumnDataSource"}},"id":"96ced8c0-28e7-4017-91f4-6c2272987cdb","type":"CDSView"},{"attributes":{"data_source":{"id":"6e9354cf-3cb3-4b7e-86e5-bee1df6da369","type":"ColumnDataSource"},"glyph":{"id":"4ca015f7-ea4c-4d5a-93c8-38cfb70bc8db","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"133e57d1-5358-4518-9697-84bc9cc2fcef","type":"Circle"},"selection_glyph":null,"view":{"id":"bc07db09-0b85-40a1-ae5d-b680cbc55a07","type":"CDSView"}},"id":"2ddebd09-015d-4523-b987-c5ef50023c48","type":"GlyphRenderer"},{"attributes":{},"id":"532983e6-0104-4370-b57b-b9bbec6ec798","type":"UnionRenderers"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"17eb7631-4745-46d6-a1e3-97c14d3204c2","type":"HoverTool"}]},"id":"6977565e-02b5-4bd7-90a5-ddfc2fcbbe55","type":"Toolbar"},{"attributes":{},"id":"d1647762-8367-4195-b8ac-1db0b0451381","type":"LinearScale"},{"attributes":{},"id":"4ccfbf28-6d60-4f69-b6ff-1d920ce23cf1","type":"UnionRenderers"},{"attributes":{"callback":null,"data":{"x":[1],"y":[1]},"selected":{"id":"d29952e1-ef97-4e3e-ae4d-e895327006a4","type" ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"ea44204d-57e5-49d2-871f-6e560351f03d":{"roots":{"references":[{"attributes":{"data_source":{"id":"384b2d68-7541-4c35-8eee-b712eafa778a","type":"ColumnDataSource"},"glyph":{"id":"aac74dd3-18ce-468d-9c65-388f2c1dda46","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b3f20a1a-b7d8-4f8a-8921-179ee99f2214","type":"Line"},"selection_glyph":null,"view":{"id":"d11749e5-41df-4257-b4fe-135b3bbdab63","type":"CDSView"}},"id":"58638517-d350-4d08-958d-f19771c5ce28","type":"GlyphRenderer"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"58638517-d350-4d08-958d-f19771c5ce28","type":"GlyphRenderer"}]},"id":"7ceb0bf5-9a10-471e-9bea-bf7f3c72fd7f","type":"LegendItem"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"b3f20a1a-b7d8-4f8a-8921-179ee99f2214","type":"Line"},{"attributes":{"callback":null},"id":"e3c09777-12b9-44be-8c86-5fc67382fed9","type":"DataRange1d"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["medals.silver","@x"],["medals.gold","@y{0.00}"],["x","$x"],["y","$y"]]},"id":"60e2210d-9ab8-4a7f-8480-6094c56b2821","type":"HoverTool"},{"attributes":{"children":[{"id":"3e877009-f113-4b0a-86f6-b1b9eb3eb632","subtype":"Figure","type":"Plot"}]},"id":"12d4adf1-140d-4766-a79f-23f37bbd6fc7","type":"Row"},{"attributes":{"children":[{"id":"12d4adf1-140d-4766-a79f-23f37bbd6fc7","type":"Row"}]},"id":"e6cf5708-302e-4b73-8bda-b754e55943a6","type":"Column"},{"attributes":{"children":[{"id":"f41d1b56-d9cb-4ae4-bde3-c16e33a99831","type":"ToolbarBox"},{"id":"e6cf5708-302e-4b73-8bda-b754e55943a6","type":"Column"}]},"id":"b7320d28-827a-4c2f-bef7-e9da84c97a6a","type":"Column"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"60e2210d-9ab8-4a7f-8480-6094c56b2821","type":"HoverTool"}]},"id":"16ebaeb4-4d8e-41bf-9ba9-d4a93f198356","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"3e877009-f113-4b0a-86f6-b1b9eb3eb632","subtype":"Figure","type":"Plot"},"ticker":{"id":"ceced38d-63b8-4fe0-b989-f2cec66ebe5e","type":"BasicTicker"}},"id":"a70bdaeb-fc26-4bff-8700-1993da56deb0","type":"Grid"},{"attributes":{"callback":null,"data":{"x":[0,1,2,3,4,5,6,8],"y":[11,4,6,15,15,2,8,10]},"selected":{"id":"6c483a47-a530-4b88-8e9d-6f534cf95209","type":"Selection"},"selection_policy":{"id":"4047b1a8-d390-4ab5-9971-d4e6854b351a","type":"UnionRenderers"}},"id":"384b2d68-7541-4c35-8eee-b712eafa778a","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"7ceb0bf5-9a10-471e-9bea-bf7f3c72fd7f","type":"LegendItem"}],"location":"top_left","plot":{"id":"3e877009-f113-4b0a-86f6-b1b9eb3eb632","subtype":"Figure","type":"Plot"}},"id":"fbc8c650-f759-47c5-8be1-b8d4b7d52a38","type":"Legend"},{"attributes":{},"id":"750d901a-fb95-4002-8bfc-acb968a9085f","type":"BasicTickFormatter"},{"attributes":{},"id":"2ec546fe-3ce9-4311-8063-06596c5b20d3","type":"LinearScale"},{"attributes":{"axis_label":"medals.gold","formatter":{"id":"750d901a-fb95-4002-8bfc-acb968a9085f","type":"BasicTickFormatter"},"plot":{"id":"3e877009-f113-4b0a-86f6-b1b9eb3eb632","subtype":"Figure","type":"Plot"},"ticker":{"id":"ceced38d-63b8-4fe0-b989-f2cec66ebe5e","type":"BasicTicker"}},"id":"ea782a5e-7700-48df-a4dc-bf6297c714dd","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"73a6b2d9-8921-49c5-a29f-00ddcc2e40a0","type":"BoxAnnotation"},{"attributes":{},"id":"ac1b67be-517d-4ad0-8a71-e82f2218a9a4","type":"BasicTicker"},{"attributes":{},"id":"ceced38d-63b8-4fe0-b989-f2cec66ebe5e","type":"BasicTicker"},{"attributes":{},"id":"4047b1a8-d390-4ab5-9971-d4e6854b351a","type":"UnionRenderers"}, ...
#           var render_items = [{"docid":"ea44204d-57e5-49d2-871f-6e560351f03d","roots":{"b7320d28-827a-4c2f-bef7-e9da84c97a6a":"aa81dbbd-66a4-4d1d-b92e-db95ed2add49"}}];
#           root.Bokeh.embed.embed_items(docs_json, render_items);
#
#           }
#           if (root.Bokeh !== undefined) {
#             embed_document(root);
#           } else {
#             var attempts = 0;
#             var timer = setInterval(function(root) {
#               if (root.Bokeh !== undef

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"47ce3c3f-c847-4864-8853-55c4d286616b":{"roots":{"references":[{"attributes":{"bottom":{"expr":{"id":"6427b96b-5fbc-4528-8acb-d9c71c803ff9","type":"Stack"}},"fill_color":{"value":"#2ca02c"},"line_color":{"value":"#2ca02c"},"top":{"expr":{"id":"e6d80e2b-fa8a-45c9-b30b-d67ee2ba4f7f","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"17d9bb4c-7f5c-4931-84ac-61caba577f53","type":"VBar"},{"attributes":{"axis_label":"medals.bronze,medals.silver,medals.gold","formatter":{"id":"2841d607-2e7c-483e-88a7-e0584b2525b7","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"f42c0475-b765-4051-aa05-ac375e6c092d","subtype":"Figure","type":"Plot"},"ticker":{"id":"069a2d83-8e3f-4ff1-901f-0739093409a3","type":"BasicTicker"}},"id":"b23beea6-0f61-412e-844b-669eaf48d7bb","type":"LinearAxis"},{"attributes":{},"id":"2841d607-2e7c-483e-88a7-e0584b2525b7","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"1bd07a34-a610-430a-8b98-c548826a01b6","type":"ColumnDataSource"},"glyph":{"id":"6573e8e7-bb3b-451b-a400-a0ab3ca9a764","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"medals.bronze","nonselection_glyph":{"id":"5688c2c7-7065-4590-9517-d2b73a183362","type":"VBar"},"selection_glyph":null,"view":{"id":"7dac30ab-7ef1-4b74-830b-b0a8c85dcd7b","type":"CDSView"}},"id":"33a44146-833b-46e4-ac01-b9321a15276e","type":"GlyphRenderer"},{"attributes":{"toolbar":{"id":"6e4da835-e03b-4d3e-8338-3ff7f4d82a3b","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"ef62baf8-2d0b-4bc7-955b-cd47397d5c67","type":"ToolbarBox"},{"attributes":{"axis_label":"name","formatter":{"id":"231aad42-71ef-4ebd-964b-179e97cfdf5b","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"plot":{"id":"f42c0475-b765-4051-aa05-ac375e6c092d","subtype":"Figure","type":"Plot"},"ticker":{"id":"83157707-9e75-4d2d-8b71-f7fced2f2c92","type":"CategoricalTicker"}},"id":"933c4806-a6ab-4de1-8768-8c5485c8ea99","type":"CategoricalAxis"},{"attributes":{"source":{"id":"1bd07a34-a610-430a-8b98-c548826a01b6","type":"ColumnDataSource"}},"id":"7dac30ab-7ef1-4b74-830b-b0a8c85dcd7b","type":"CDSView"},{"attributes":{},"id":"d261fcaf-4612-44c6-b0e4-6f42e65ed71a","type":"Selection"},{"attributes":{"children":[{"id":"f42c0475-b765-4051-aa05-ac375e6c092d","subtype":"Figure","type":"Plot"}]},"id":"689fbdd4-f1fa-4fe3-982b-097b1b6f3632","type":"Row"},{"attributes":{"fields":["medals.bronze"]},"id":"5d067fa5-1452-4fce-8107-34ea71f1bd19","type":"Stack"},{"attributes":{"label":{"value":"medals.silver"},"renderers":[{"id":"4268a7ae-7e02-440b-b778-24881ee57bc0","type":"GlyphRenderer"}]},"id":"6f10fc55-036d-4ee3-92c6-bbdf81a30a10","type":"LegendItem"},{"attributes":{"tools":[{"id":"3e86523d-635d-4b8d-b615-f3d81556959f","type":"HoverTool"}]},"id":"6e4da835-e03b-4d3e-8338-3ff7f4d82a3b","type":"ProxyToolbar"},{"attributes":{"fields":["medals.bronze","medals.silver"]},"id":"d7850738-9076-44d5-93de-8bf7be26b307","type":"Stack"},{"attributes":{"callback":null,"data":{"medals.bronze":[1,1,1,4,1,0,2,0,5,4,1,4,2,1,1,2,8,7,0,7,0,4,2,1,1,10],"medals.gold":[0,2,5,4,3,0,1,0,3,8,1,0,1,0,2,0,6,8,4,6,1,2,2,6,0,6],"medals.silver":[2,6,0,8,2,1,3,3,2,3,0,2,4,0,1,1,6,4,0,8,0,1,5,3,0,4],"pd_stacked_col":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"]},"selected":{"id":"d261fcaf-4612-44c6-b0e4-6f42e65ed71a","type":"Selection"},"selection_policy":{"id":"f58528b7-63d0-4a62-9105-580eaf30baed","type":"UnionRenderers"}},"id":"1bd07a34-a610-430a-8b98-c548826a01b6","type":"ColumnDataSource"},{"attributes":{},"id":"f58528b7-63d0-4a62-9105-580eaf30baed","type":"UnionRenderers"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"f42c0475-b765-4051-aa05-ac375e6c0 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
