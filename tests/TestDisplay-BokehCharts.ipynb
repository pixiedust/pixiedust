# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.6</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureb6bb292c" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       color: #337ab7;
#       font-family: monospace;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #2e6da4;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-b6bb292c panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-b6bb292c" data-parent="#df-table-wrapper-b6bb292c">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-b6bb292c" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-b6bb292c" data-parent="#df-table-wrapper-b6bb292c">Untitled Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-b6bb292c" class="panel-collapse collapse in">
#         <div class="panel-body">
#           <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header" style="width: 765px;">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell" style="width: 69px;">abbr</div>
#
#                 <div class="fixed-cell" style="width: 147px;">medals.bronze</div>
#
#                 <div class="fixed-cell" style="width: 130px;">medals.gold</div>
#
#                 <div class="fixed-cell" style="width: 147px;">medals.silver</div>
#
#                 <div class="fixed-cell" style="width: 138px;">medals.total</div>
#
#                 <div class="fixed-cell" style="width: 134px;">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"a39a1684-5e96-4122-99a7-996baa63f867":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}}},"id":"f157a5e1-8b4a-49c3-b1d2-05a448e9c31f","type":"ColumnDataSource"},{"attributes":{},"id":"4ca89b5d-c028-444c-af22-c384908c9100","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2e3cf43e-a549-4c1e-be26-863e01a349cc","type":"BoxAnnotation"},{"attributes":{},"id":"0505828a-ac40-4c98-8ac9-dbb6c57c3668","type":"BasicTicker"},{"attributes":{"children":[{"id":"f96d0534-d138-45f1-bb78-5bd4dc93bdc2","type":"ToolbarBox"},{"id":"adc86581-d634-4ac6-9490-04cd0741593d","type":"Column"}]},"id":"09c6cfbc-be35-468a-beb0-6059aa5a5718","type":"Column"},{"attributes":{"children":[{"id":"a19e4903-b769-4a56-9eba-ee482c4ae25c","type":"Row"}]},"id":"adc86581-d634-4ac6-9490-04cd0741593d","type":"Column"},{"attributes":{"callback":null},"id":"98a5a188-a495-4688-95d0-1fb7201809ee","type":"DataRange1d"},{"attributes":{},"id":"f9a15678-8cb0-460e-b54a-fc3967533870","type":"ResetTool"},{"attributes":{},"id":"c5afd0d3-ccde-418b-b3ea-39ee0c328ec4","type":"SaveTool"},{"attributes":{"below":[{"id":"ee8b7d18-a0d3-44b5-a429-0a6e5ddc141a","type":"LinearAxis"}],"left":[{"id":"a9147efc-6fe2-4f47-adcd-aa2aa7bf5e42","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"ee8b7d18-a0d3-44b5-a429-0a6e5ddc141a","type":"LinearAxis"},{"id":"99666f98-750a-4464-badb-49f8f3b2d0de","type":"Grid"},{"id":"a9147efc-6fe2-4f47-adcd-aa2aa7bf5e42","type":"LinearAxis"},{"id":"5d29e22c-4ca8-41a5-b24e-01dc1daf1801","type":"Grid"},{"id":"2e3cf43e-a549-4c1e-be26-863e01a349cc","type":"BoxAnnotation"},{"id":"7bcbb95a-db3a-451f-88d0-6b1bd1d0d3b7","type":"GlyphRenderer"}],"title":{"id":"cac3fe9e-5ade-4cea-a717-2da1d8707eb9","type":"Title"},"toolbar":{"id":"81f10020-ca10-4d3a-b738-bc3a825917c8","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"98a5a188-a495-4688-95d0-1fb7201809ee","type":"DataRange1d"},"x_scale":{"id":"f550b01c-0e6c-4e73-9497-3befb0369df7","type":"LinearScale"},"y_range":{"id":"9e40fce4-ce46-454f-a816-6cbe43450c2a","type":"DataRange1d"},"y_scale":{"id":"f0375292-759f-4237-bcd7-50ade85daa35","type":"LinearScale"}},"id":"3f56da30-6189-40f9-8cb2-782a5d30ce16","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"f157a5e1-8b4a-49c3-b1d2-05a448e9c31f","type":"ColumnDataSource"},"glyph":{"id":"0231f4ea-fe7a-4cbc-9836-5a0ed6a9718d","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9242c675-7bb1-46f1-8fe0-274d602e5771","type":"Quad"},"selection_glyph":null,"view":{"id":"82423f39-1d98-48fa-9b1b-3a91e07d6df6","type":"CDSView"}},"id":"7bcbb95a-db3a-451f-88d0-6b1bd1d0d3b7","type":"GlyphRenderer"},{"attributes":{},"id":"f550b01c-0e6c-4e73-9497-3befb0369df7","type":"LinearScale"},{"attributes":{},"id":"f2e8e18d-e85b-44a8-8d1e-23c74b7201f7","type":"BasicTickFormatter"},{"attributes":{},"id":"68b9cb88-f201-4606-af02-cc27e2145d3a","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"68b9cb88-f201-4606-af02-cc27e2145d3a","type":"PanTool"},{"id":"4ca89b5d-c028-444c-af22-c384908c9100","ty ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"3ba4ed91-b034-4219-8597-5813f36c9e2d":{"roots":{"references":[{"attributes":{"label":{"value":"NLD"},"renderers":[{"id":"6804f0b1-6012-42ee-b0f5-880c1482c6d6","type":"GlyphRenderer"}]},"id":"738c7a39-2276-42fa-90be-342c75b5e0e3","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#8807A5"},"line_color":{"value":"#8807A5"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"d69246c4-276b-4ca9-9407-f06324de45ce","type":"Circle"},{"attributes":{"label":{"value":"SVK"},"renderers":[{"id":"73d313c3-c149-4861-aaec-74dd556de31e","type":"GlyphRenderer"}]},"id":"e93d546c-3be2-4b70-bb9b-bc341a4f3e0c","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7ce6180-1fcc-4102-af78-065e8e8f17ea","type":"Circle"},{"attributes":{"source":{"id":"f7c96a2f-990f-459e-9b6d-c98a4ec23653","type":"ColumnDataSource"}},"id":"b445fc7d-db5e-4ee3-a8d4-ca7c08a40985","type":"CDSView"},{"attributes":{"label":{"value":"CZE"},"renderers":[{"id":"8ac545d8-b4a8-45e8-a14c-5923dc8557c1","type":"GlyphRenderer"}]},"id":"cc120a9b-98c1-416a-81df-896bb5e4a637","type":"LegendItem"},{"attributes":{"source":{"id":"77bcc4fe-cd14-428f-a0b2-aa6fbfce3f59","type":"ColumnDataSource"}},"id":"319081ac-9b2c-42dd-8353-326fd1a42858","type":"CDSView"},{"attributes":{"label":{"value":"FIN"},"renderers":[{"id":"1918db63-9ceb-40f9-91f0-f4cee9cb6ac9","type":"GlyphRenderer"}]},"id":"a15ba553-5348-4e34-a942-b9bfe8482269","type":"LegendItem"},{"attributes":{"label":{"value":"AUT"},"renderers":[{"id":"54ee66b4-44d0-484f-b359-8dacc716d3d6","type":"GlyphRenderer"}]},"id":"9b67f62b-a9bc-4ab1-a8b1-36bdb1af46b3","type":"LegendItem"},{"attributes":{"source":{"id":"9a8dfa49-a72f-4d36-9f7e-2407e5ae0140","type":"ColumnDataSource"}},"id":"3c53253b-21b9-4176-9efb-7bd15fa5b64b","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"bc3d7cee-9eeb-40f8-98e2-a40ee2a7ac5d","type":"Circle"},{"attributes":{"source":{"id":"4782fb6f-5df4-42a7-a309-9b0d8003b8ee","type":"ColumnDataSource"}},"id":"26a004b8-a1bb-4506-a600-61ceeba83405","type":"CDSView"},{"attributes":{"data_source":{"id":"d3fcf62c-fb53-4194-8992-5fe725dc3dff","type":"ColumnDataSource"},"glyph":{"id":"58a90968-d96f-4a5a-8bac-2c27a146dbcf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0c7a9d4a-fd53-4c62-bda5-7804389774f0","type":"Circle"},"selection_glyph":null,"view":{"id":"bf106553-978c-4f5b-ab71-086ead9b4564","type":"CDSView"}},"id":"bed849fd-0569-4d89-bd78-ba4d4d346074","type":"GlyphRenderer"},{"attributes":{"label":{"value":"JPN"},"renderers":[{"id":"8dd38626-75eb-4364-b189-c4aa7bbaa214","type":"GlyphRenderer"}]},"id":"4a886537-3ec5-443a-a622-aff9c0edf827","type":"LegendItem"},{"attributes":{"data_source":{"id":"c8f1761f-7efe-4e15-b8a0-60caf0efb710","type":"ColumnDataSource"},"glyph":{"id":"4fad56de-31ba-4c89-950b-50a566a669b2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"84119743-d4b3-4d63-9dc8-7d73c29a5925","type":"Circle"},"selection_glyph":null,"view":{"id":"0e8a07f2-3483-4f8d-9fc2-37ba4cdc833a","type":"CDSView"}},"id":"d8cb2780-4be9-467f-963f-f1597d9c9374","type":"GlyphRenderer"},{"attributes":{"source":{"id":"7efc4517-e10a-42b4-9633-c7178f62683b","type":"ColumnDataSource"}},"id":"5c94d5a7-b541-48b1-b194-cb675bb23b28","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#B02A8F"},"line_color":{"value":"#B02A8F"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d5d7b95-a198-4152-a557-31a4df8469b2","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"], ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"1eb02d32-53a7-4750-9974-56963d5ba48d":{"roots":{"references":[{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"81a3f98b-fbb1-49a7-9f01-ee2dd709fe92","type":"Line"},{"attributes":{},"id":"b6e30dd1-b8b6-40db-9163-3fe0ce2d7fcd","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6,8],"y":[11,4,6,15,15,2,8,10]}},"id":"de4b8689-83b9-4641-a8cb-a56e476f7773","type":"ColumnDataSource"},{"attributes":{},"id":"406ff331-2615-433c-a80f-26ccee31967a","type":"BasicTicker"},{"attributes":{},"id":"b5122c88-291e-42f5-bb34-f386b02ef951","type":"PanTool"},{"attributes":{"items":[{"id":"47a7bb89-7188-461a-afe2-6cad8a4178b8","type":"LegendItem"}],"location":"top_left","plot":{"id":"f2730c59-c4be-4c60-b67b-50f52b8c7d9f","subtype":"Figure","type":"Plot"}},"id":"ad167be8-4665-4a31-83df-203d62f38c3e","type":"Legend"},{"attributes":{},"id":"3cb6c4b6-20c5-4e3f-9a9b-4d5798a68e9e","type":"WheelZoomTool"},{"attributes":{},"id":"0690ba34-499b-4b15-9865-64d28408fc98","type":"HelpTool"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"c6fcd396-cf86-4e8d-99a6-6e225028b6b8","type":"Line"},{"attributes":{},"id":"b27dc7a9-93bf-454d-b73e-48956829ec8d","type":"LinearScale"},{"attributes":{"axis_label":"medals.silver","formatter":{"id":"1991ce9d-d3f1-4e75-9b32-33378665079b","type":"BasicTickFormatter"},"plot":{"id":"f2730c59-c4be-4c60-b67b-50f52b8c7d9f","subtype":"Figure","type":"Plot"},"ticker":{"id":"88ec0a31-44db-469d-a064-9c903497391c","type":"BasicTicker"}},"id":"7d31d2c4-7fae-40b4-8879-6d0856cc7853","type":"LinearAxis"},{"attributes":{"callback":null},"id":"3e4b7523-8eab-4e7e-9d69-1d08788625b6","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b5122c88-291e-42f5-bb34-f386b02ef951","type":"PanTool"},{"id":"3cb6c4b6-20c5-4e3f-9a9b-4d5798a68e9e","type":"WheelZoomTool"},{"id":"22c67432-7c87-4233-b169-125bce53754d","type":"BoxZoomTool"},{"id":"9737e7d5-28cf-4293-9ac8-d43e1c671ee2","type":"SaveTool"},{"id":"b6e30dd1-b8b6-40db-9163-3fe0ce2d7fcd","type":"ResetTool"},{"id":"0690ba34-499b-4b15-9865-64d28408fc98","type":"HelpTool"}]},"id":"8464af15-3b37-4e40-a005-e26f49bc5af1","type":"Toolbar"},{"attributes":{},"id":"9737e7d5-28cf-4293-9ac8-d43e1c671ee2","type":"SaveTool"},{"attributes":{"callback":null},"id":"90017dbb-21c3-49e0-be2e-9d923c76128b","type":"DataRange1d"},{"attributes":{},"id":"47512495-d2b9-466d-9ab3-664ee11856b7","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"f2730c59-c4be-4c60-b67b-50f52b8c7d9f","subtype":"Figure","type":"Plot"}]},"id":"de4fab52-18d4-44fc-9e54-9573079ba8de","type":"Row"},{"attributes":{"children":[{"id":"de4fab52-18d4-44fc-9e54-9573079ba8de","type":"Row"}]},"id":"72ffce60-efc0-4b7b-aea6-998c64200111","type":"Column"},{"attributes":{},"id":"88ec0a31-44db-469d-a064-9c903497391c","type":"BasicTicker"},{"attributes":{"children":[{"id":"124be72d-e704-4729-96b9-9b07e86882dd","type":"ToolbarBox"},{"id":"72ffce60-efc0-4b7b-aea6-998c64200111","type":"Column"}]},"id":"65341ea3-c0a1-47e3-8af9-68f14f18c9d4","type":"Column"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"155115c9-6906-40c4-bda1-2f225cb199f9","type":"BoxAnnotation"},{"attributes":{"axis_label":"medals.gold","formatter":{"id":"47512495-d2b9-466d-9ab3-664ee11856b7","type":"BasicTickFormatter"},"plot":{"id":"f2730c59-c4be-4c60-b67b-50f52b8c7d9f","subtype":"Figure","type":"Plot"},"ticker":{"id":"406ff331-2615-433c-a80f-26ccee31967a","type":"BasicTicker"}},"id":"bb9752bd-db8d-4d0e-a52b-fc8555c3dae8","type":"LinearAxis"},{"attr ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             var el = document.createElement('div')
#                             el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"b7adc682-9cca-4b46-a9fe-d65509049b35":{"roots":{"references":[{"attributes":{"source":{"id":"c7a01b46-3fb2-4a18-917f-d5d52d69faa3","type":"ColumnDataSource"}},"id":"302774c1-fbc7-4fe9-8ef8-c07ad427ac61","type":"CDSView"},{"attributes":{"source":{"id":"c7a01b46-3fb2-4a18-917f-d5d52d69faa3","type":"ColumnDataSource"}},"id":"f210684e-9e63-4698-a774-e29625bae54f","type":"CDSView"},{"attributes":{"label":{"value":"medals.bronze"},"renderers":[{"id":"b3a7853b-8bfe-47f4-8dc3-f65ca5fbd080","type":"GlyphRenderer"}]},"id":"1741fddb-7202-4161-8f07-c73fe0dfdc6c","type":"LegendItem"},{"attributes":{"callback":null,"start":0},"id":"06c08627-a460-4ea9-aa21-14dd60cc85e7","type":"DataRange1d"},{"attributes":{},"id":"003568f1-ecab-47a6-8443-4e1c6d8366e3","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"37e20727-cc34-4a6a-8b13-dc891a6b44f4","type":"BoxAnnotation"},{"attributes":{"fields":["medals.bronze","medals.silver","medals.gold"]},"id":"8d86ecdf-1e86-4336-8b45-4e8069d3907a","type":"Stack"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"003568f1-ecab-47a6-8443-4e1c6d8366e3","type":"PanTool"},{"id":"6e61380f-7514-4e4b-a054-819d01690456","type":"WheelZoomTool"},{"id":"7c56fe4d-8fba-4d91-85df-b09e5e821be9","type":"BoxZoomTool"},{"id":"898c0799-f76d-4a2f-8a72-d4bb8ade3e13","type":"SaveTool"},{"id":"49cf5302-4143-458c-b155-100794bf7d7f","type":"ResetTool"},{"id":"764c02fb-61ed-4d64-8fbe-ddb777ede47f","type":"HelpTool"}]},"id":"bed8d9d6-cc01-4967-86cb-8e530aba5025","type":"Toolbar"},{"attributes":{"toolbar":{"id":"45b0712c-6f14-4f72-b0e0-e749645c6720","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"8975525d-08d3-4f95-93c6-fcaa42f97a61","type":"ToolbarBox"},{"attributes":{"bottom":{"expr":{"id":"c9ba67ad-befa-495c-9455-cf356f50f9ac","type":"Stack"}},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"a2e770d5-3eee-4ea0-82e0-784bce5d6fbb","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"d9bb8759-dac6-4414-9820-bb82eb7d45ee","type":"VBar"},{"attributes":{"fields":["medals.bronze"]},"id":"0ca8c84a-8489-4945-b932-ed7870d137d0","type":"Stack"},{"attributes":{"below":[{"id":"a5cc4bf8-8a32-4d9d-b43e-0dbd73d9a85a","type":"CategoricalAxis"}],"left":[{"id":"f4859545-578f-4346-ae7e-29cbd414c2f6","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":495,"plot_width":803,"renderers":[{"id":"a5cc4bf8-8a32-4d9d-b43e-0dbd73d9a85a","type":"CategoricalAxis"},{"id":"19b092ee-8cf0-46c6-ae35-c01721645591","type":"Grid"},{"id":"f4859545-578f-4346-ae7e-29cbd414c2f6","type":"LinearAxis"},{"id":"5398244a-5879-4404-b4f9-6c66f041ff97","type":"Grid"},{"id":"37e20727-cc34-4a6a-8b13-dc891a6b44f4","type":"BoxAnnotation"},{"id":"84f9822a-a6a5-4fc2-83d8-4590c0430565","type":"Legend"},{"id":"b3a7853b-8bfe-47f4-8dc3-f65ca5fbd080","type":"GlyphRenderer"},{"id":"aa2f32b2-3074-46a0-9956-7f4d062b47ea","type":"GlyphRenderer"},{"id":"28bfa210-c786-48c7-a200-b091749771e2","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"bed8d9d6-cc01-4967-86cb-8e530aba5025","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"dadaa792-1bab-4ea7-b0eb-0ab986abd43f","type":"FactorRange"},"x_scale":{"id":"69146f86-b646-42d7-ae1c-abc5072711ff","type":"CategoricalScale"},"y_range":{"id":"06c08627-a460-4ea9-aa21-14dd60cc85e7","type":"DataRange1d"},"y_scale":{"id":"c67cc331-e743-4bc4-9c8f-8bcd062f9692","type":"LinearScale"}},"id":"edec8829-039f-4006-b09f-46450443bc41","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"medals.bronze,medals.silver,medals.gold","formatter":{"id":"03147046-6f73-42b7-b98f-e492b5a53645", ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       color: #337ab7;
#       font-family: monospace;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #2e6da4;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Untitled Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td>
#
#                   <td>15</td>
#
#                   <td>Germany</td>
#
#                 </tr>

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
