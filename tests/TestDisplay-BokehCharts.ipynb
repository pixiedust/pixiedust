# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.12</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.1.12, Latest is 1.1.11</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure858bc423" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-858bc423")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"7feb8a96-de8a-40b1-a3af-56962297e01c":{"roots":{"references":[{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"57879d00-41bf-45ae-a9a2-71ba05015d2b","type":"FactorRange"},{"attributes":{"tools":[{"id":"579bc18b-9b5a-43df-8beb-9332cf8fb197","type":"PanTool"},{"id":"f4b5a524-1d89-4268-80a1-d01dbe3a93bd","type":"WheelZoomTool"},{"id":"3bdbe677-c1a3-47af-a4af-cf35524e15d5","type":"BoxZoomTool"},{"id":"ab9a6f2d-6c4a-454a-932c-b18079752a17","type":"SaveTool"},{"id":"6622e375-a100-4467-8f0a-8be012d11fda","type":"ResetTool"},{"id":"655af91a-0950-4828-83b5-4e56df1a7060","type":"HelpTool"},{"id":"a043271f-694f-4c2c-bcf9-36bd2e0f452a","type":"HoverTool"}]},"id":"20de27ad-298b-4631-bf96-8d53f2945ea1","type":"ProxyToolbar"},{"attributes":{"children":[{"id":"a513c8e8-a391-4d5e-a24d-dfc8cd6807ca","type":"ToolbarBox"},{"id":"5714ef82-9953-4c16-a35a-4620a02c7acb","type":"Column"}]},"id":"40a8e428-cc44-4503-ac77-a0ca8314faf0","type":"Column"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"84a50af4-f6a9-4f7d-810d-d8e9bd570047","type":"BoxAnnotation"},{"attributes":{"label":{"value":"medals.total"},"renderers":[{"id":"93043d89-0be1-4def-91bd-9944628dd6f9","type":"GlyphRenderer"}]},"id":"c8df9309-4c74-4c6c-b4b4-24e2ae61e5ec","type":"LegendItem"},{"attributes":{},"id":"f4b5a524-1d89-4268-80a1-d01dbe3a93bd","type":"WheelZoomTool"},{"attributes":{"fields":[]},"id":"d86c8252-d59a-4683-bca1-f9a552e5803d","type":"Stack"},{"attributes":{"dimension":1,"plot":{"id":"9f5a82bd-249d-47d6-9bb4-4c8160fa9b7a","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3ac206e-6ad6-40b5-acf6-c9bd12719c09","type":"BasicTicker"}},"id":"d29e3ed3-725e-41be-80cd-e15f02b651fc","type":"Grid"},{"attributes":{"callback":null,"data":{"medals.total":[3,9,6,16,6,1,6,3,10,15,2,6,7,1,4,3,20,19,4,21,1,7,9,10,1,20],"pd_stacked_col":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"]},"selected":{"id":"11ffb987-844f-4cce-8eff-2a9bccae37ab","type":"Selection"},"selection_policy":{"id":"bfc7d692-7878-4f4a-8d0d-9860277bb15f","type":"UnionRenderers"}},"id":"c1da8a33-2f7f-4128-aec9-277b06e88b99","type":"ColumnDataSource"},{"attributes":{"bottom":{"expr":{"id":"d86c8252-d59a-4683-bca1-f9a552e5803d","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"28d68220-9bec-41b9-be81-1769e42d1177","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"2defd9b4-41c2-4edf-876d-67a6ff7c9afe","type":"VBar"},{"attributes":{"axis_label":"name","formatter":{"id":"ca943425-344b-4a58-b762-37494dda4f32","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"plot":{"id":"9f5a82bd-249d-47d6-9bb4-4c8160fa9b7a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c63a13f8-62a6-4ded-b6b2-cb2e955d9d0c","type":"CategoricalTicker"}},"id":"f1ea7371-51ef-4932-a867-3e6363348a24","type":"CategoricalAxis"},{"attributes":{"items":[{"id":"c8df9309-4c74-4c6c-b4b4-24e2ae61e5ec","type":"LegendItem"}],"location":"top_left","plot":{"id":"9f5a82bd-249d-47d6-9bb4-4c8160fa9b7a","subtype":"Figure","type":"Plot"}},"id":"2953e15e-1a3a-4cf8 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"cce8ee03-c2b6-4505-8b77-fcec12623ea3":{"roots":{"references":[{"attributes":{"callback":null},"id":"02b15b1e-6153-42de-8e70-74386ffdf1f3","type":"DataRange1d"},{"attributes":{},"id":"0d19d6de-7997-4e36-a6ec-ea80d08566f9","type":"LinearScale"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"cc377042-061c-4c71-a4d2-95791bd7c1b7","type":"Quad"},{"attributes":{},"id":"ec006e68-426f-481c-9e87-123ce7f251eb","type":"UnionRenderers"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"7cbf7512-af41-4ba8-9923-6f629623f20a","type":"PanTool"},{"id":"1929ac12-7548-4165-8734-5ee834d1e2a9","type":"WheelZoomTool"},{"id":"374f07ca-1c02-4301-80ad-5926b482203d","type":"BoxZoomTool"},{"id":"8578cc6f-464c-46ac-a6e3-bebdfb8a7e30","type":"SaveTool"},{"id":"83d7f3e3-d3f5-4d54-b7c1-139968c9a28c","type":"ResetTool"},{"id":"ab75cfb3-8d94-4e72-962a-8c256d8cd93f","type":"HelpTool"},{"id":"9693cba7-a368-48a3-b8ae-ec66be5c2681","type":"HoverTool"}]},"id":"9accbbf1-0fbd-44a0-8fc0-deaa52ead59f","type":"Toolbar"},{"attributes":{},"id":"df17564e-af7d-4aea-84a9-8c9157df6773","type":"BasicTicker"},{"attributes":{},"id":"8975548a-89ee-434d-a1ba-0f80940b9396","type":"Selection"},{"attributes":{},"id":"2934824b-b503-4f06-b607-df313c782d49","type":"BasicTickFormatter"},{"attributes":{},"id":"f9ad3e77-e3a9-482f-a25f-2d2ff7c7d0b9","type":"LinearScale"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"2934824b-b503-4f06-b607-df313c782d49","type":"BasicTickFormatter"},"plot":{"id":"c901c383-f128-4444-9020-1de505b7c133","subtype":"Figure","type":"Plot"},"ticker":{"id":"dc32c2d0-ee65-477e-a8df-c04811bc487c","type":"BasicTicker"}},"id":"eb30cf93-54ae-4ca8-965a-d13089a01e5f","type":"LinearAxis"},{"attributes":{},"id":"1929ac12-7548-4165-8734-5ee834d1e2a9","type":"WheelZoomTool"},{"attributes":{},"id":"83d7f3e3-d3f5-4d54-b7c1-139968c9a28c","type":"ResetTool"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"9b596f04-a4bb-4984-aedb-5886eff1bb5a","type":"BasicTickFormatter"},"plot":{"id":"c901c383-f128-4444-9020-1de505b7c133","subtype":"Figure","type":"Plot"},"ticker":{"id":"df17564e-af7d-4aea-84a9-8c9157df6773","type":"BasicTicker"}},"id":"240d8ec1-b277-43a9-8490-daeec8f61a15","type":"LinearAxis"},{"attributes":{"children":[{"id":"c901c383-f128-4444-9020-1de505b7c133","subtype":"Figure","type":"Plot"}]},"id":"e8241715-270c-45ec-90c1-1fb97ddc0548","type":"Row"},{"attributes":{"plot":{"id":"c901c383-f128-4444-9020-1de505b7c133","subtype":"Figure","type":"Plot"},"ticker":{"id":"df17564e-af7d-4aea-84a9-8c9157df6773","type":"BasicTicker"}},"id":"4e55fbf8-e04d-4d5b-a83c-2dc33ab1b0f3","type":"Grid"},{"attributes":{"below":[{"id":"240d8ec1-b277-43a9-8490-daeec8f61a15","type":"LinearAxis"}],"left":[{"id":"eb30cf93-54ae-4ca8-965a-d13089a01e5f","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"240d8ec1-b277-43a9-8490-daeec8f61a15","type":"LinearAxis"},{"id":"4e55fbf8-e04d-4d5b-a83c-2dc33ab1b0f3","type":"Grid"},{"id":"eb30cf93-54ae-4ca8-965a-d13089a01e5f","type":"LinearAxis"},{"id":"7434abf3-20ae-4796-a719-a785a7733a27","type":"Grid"},{"id":"8e9797a2-52b3-4e04-b8e9-1dfa8f67212e","type":"BoxAnnotation"},{"id":"e10ad8af-617c-4d89-a048-d931216f5dcf","type":"GlyphRenderer"}],"title":{"id":"f08f814d-7efb-4dec-ab16-2307318f4599","type":"Title"},"toolbar":{"id":"9accbbf1-0fbd-44a0-8fc0-deaa52ead59f","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"02b15b1e-6153-42de-8e70-74386ffdf1f3","type":"DataRange1d"},"x_scale":{"id":"0d19d6de-7997-4e36-a6ec-ea80d08566f9","type":"LinearScale"},"y_range":{"id":"4ea3404f-81f7-49c5-ba62-fc48a7a62e2e","type":"DataRange1d"},"y_scale":{"id":"f9ad3e77-e3a9-482f-a25f-2d2ff7c7d0b9","type":"LinearScale"}},"id":"c901c383-f128-4444-9020-1de505b7c133","subtype":"Fig ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"07baff34-2bd2-4ca4-aadf-2d395a63f136":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#E87059"},"line_color":{"value":"#E87059"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce6dfc62-ff16-42dd-807b-894e1860ab83","type":"Circle"},{"attributes":{},"id":"1e3d6971-49af-4c54-be72-9f81ad8810ce","type":"UnionRenderers"},{"attributes":{"source":{"id":"6c7b7567-988f-4eea-8327-8ea294f654e2","type":"ColumnDataSource"}},"id":"f4f3d04d-8c0e-4079-8293-27750c3cf086","type":"CDSView"},{"attributes":{"data_source":{"id":"08c59f93-cf2d-464d-ba16-5b9e95b0d430","type":"ColumnDataSource"},"glyph":{"id":"acc0f9ea-eb80-4347-95bb-ff69d0833c77","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"79a7ace7-b36c-4105-b88f-aafa0055eeb3","type":"Circle"},"selection_glyph":null,"view":{"id":"599ba2ae-4649-4c46-9d54-d6f12f06a8e9","type":"CDSView"}},"id":"d46751b5-d73e-4fdb-bd78-a03b98056606","type":"GlyphRenderer"},{"attributes":{"callback":null,"data":{"x":[19],"y":[8]},"selected":{"id":"c1cccf7f-0c01-4aa0-a152-3077e30ce350","type":"Selection"},"selection_policy":{"id":"3b95cf32-869a-4e60-847e-e475732376ea","type":"UnionRenderers"}},"id":"6c7b7567-988f-4eea-8327-8ea294f654e2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#8807A5"},"line_color":{"value":"#8807A5"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"86eb91ac-85d2-44db-ba37-d1d892d3e808","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#B02A8F"},"line_color":{"value":"#B02A8F"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1716abe-76cf-464d-834a-0f1c6b987ac9","type":"Circle"},{"attributes":{"source":{"id":"6256d246-8bf5-4088-a9d8-354c727ea807","type":"ColumnDataSource"}},"id":"36371e67-613f-4553-8780-c0516ce85367","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#6A00A7"},"line_color":{"value":"#6A00A7"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"68ea0c3f-3257-4225-b762-efa673a1cb1a","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"feef7380-87c1-477e-b38e-df3c85533136","type":"Circle"},{"attributes":{"callback":null,"data":{"x":[3],"y":[0]},"selected":{"id":"1de2b984-471c-4042-aa2b-854ec0d347b7","type":"Selection"},"selection_policy":{"id":"f3576efe-dad4-44a1-b4aa-b93c47ea0bfd","type":"UnionRenderers"}},"id":"78e30393-1f44-4fd1-aea7-72dafc0f3e8d","type":"ColumnDataSource"},{"attributes":{"label":{"value":"CAN"},"renderers":[{"id":"85e7f319-82ae-4b4e-8c96-c13c9eb67b27","type":"GlyphRenderer"}]},"id":"5a01333e-33f0-4036-b794-eb6c7cf782fc","type":"LegendItem"},{"attributes":{},"id":"65e7034c-04f6-424b-a33c-102e968eb423","type":"Selection"},{"attributes":{"source":{"id":"93bf848e-6537-4d7a-ba68-2c79b242f806","type":"ColumnDataSource"}},"id":"99893e44-31cc-461e-8f88-ea0275ba0797","type":"CDSView"},{"attributes":{},"id":"5994d505-3afd-42f6-88b6-d07005e3a7f7","type":"Selection"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#49029F"},"line_color":{"value":"#49029F"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"28c7a8b2-ce90-4d28-a216-86664e5fdf1b","type":"Circle"},{"attributes":{"label":{"value":"CHE"},"renderers":[{"id":"23c70b26-6438-4d2f-b070-5a452dbb9a2d","type":"GlyphRenderer"}]},"id":"120978f5-5035-40c7-820f-f24098d1d964","type":"LegendItem"},{"attributes":{"callback":null,"data":{"x":[7],"y":[1]},"selected":{"id":"9235fb38-ca0e-4690-aca6-4a3d59ab12fb","type":"Selection"},"selection_policy":{"id":"f08ede87-2281-46c5-8d84-3f642b73fb7b","type":"UnionRenderers"}},"id":"4dda706d-fc3f-4ba0-8c26-9b2f5d17a360","type":"ColumnDataSour ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"e5e7eda4-e95c-4d31-aac7-34317d5b6506":{"roots":{"references":[{"attributes":{"callback":null,"data":{"x":[0,1,2,3,4,5,6,8],"y":[11,4,6,15,15,2,8,10]},"selected":{"id":"87c89f8e-675e-47c8-a01d-c420f0d7a56c","type":"Selection"},"selection_policy":{"id":"1505c87f-b176-46ad-9cdd-4a4eea94f0a2","type":"UnionRenderers"}},"id":"ab7bdc12-facd-4dd2-ae29-e08020ec3da7","type":"ColumnDataSource"},{"attributes":{},"id":"123ba118-cfae-4bdc-ae25-2032ecafaec5","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2875eb8d-8f22-434f-972e-3761c07801d3","type":"BoxAnnotation"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"37cef42a-6d39-4b24-a4e7-f026152c0b48","type":"GlyphRenderer"}]},"id":"c5607dd4-0da2-4769-9eac-b4c16e689a1c","type":"LegendItem"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"9d8b0a9a-1ac9-42e0-bfde-f5dc88384300","type":"Line"},{"attributes":{},"id":"6ab853f8-6619-4998-965b-740033bd8dab","type":"HelpTool"},{"attributes":{"callback":null},"id":"324fb80c-d445-4bef-914e-0f390f7ebd44","type":"DataRange1d"},{"attributes":{"axis_label":"medals.gold","formatter":{"id":"e317d20b-4cb0-431d-a803-c43cbe2ad8cd","type":"BasicTickFormatter"},"plot":{"id":"3a5e5f7f-5961-4f11-826f-908ffdc9a8b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"5daffd9d-022a-4ac0-8bbf-4e1370aa2e6c","type":"BasicTicker"}},"id":"a98e9683-83e7-4400-aa56-e6c529b75e74","type":"LinearAxis"},{"attributes":{},"id":"1505c87f-b176-46ad-9cdd-4a4eea94f0a2","type":"UnionRenderers"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"b170e3e7-9b1e-40dd-9432-3f4fa7f79b29","type":"PanTool"},{"id":"44a6b770-f6c4-4820-ab8d-1e81f198cbb4","type":"WheelZoomTool"},{"id":"25dfd75c-8327-4067-9eaa-755eea4e4312","type":"BoxZoomTool"},{"id":"5611467c-1f4c-4f75-b41a-42e1dc46a19a","type":"SaveTool"},{"id":"bfe235bd-cc8f-49fc-9b1f-a0a912b90480","type":"ResetTool"},{"id":"6ab853f8-6619-4998-965b-740033bd8dab","type":"HelpTool"},{"id":"7707cb6f-f645-4c85-b7fc-4ddc88ff22f3","type":"HoverTool"}]},"id":"1546da68-d560-440b-bff3-94a9a879510c","type":"Toolbar"},{"attributes":{"axis_label":"medals.silver","formatter":{"id":"3d898469-ac54-4551-8254-beb9b86cd09a","type":"BasicTickFormatter"},"plot":{"id":"3a5e5f7f-5961-4f11-826f-908ffdc9a8b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"123ba118-cfae-4bdc-ae25-2032ecafaec5","type":"BasicTicker"}},"id":"ca782f08-0cf6-41db-bcbd-00499d355ee6","type":"LinearAxis"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"6a8c9cfd-c5e9-484c-9ac9-c5ebf1d2a4d8","type":"Line"},{"attributes":{"below":[{"id":"ca782f08-0cf6-41db-bcbd-00499d355ee6","type":"LinearAxis"}],"left":[{"id":"a98e9683-83e7-4400-aa56-e6c529b75e74","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"ca782f08-0cf6-41db-bcbd-00499d355ee6","type":"LinearAxis"},{"id":"19907ef6-8cac-40e3-85f3-9b3f49a8dc36","type":"Grid"},{"id":"a98e9683-83e7-4400-aa56-e6c529b75e74","type":"LinearAxis"},{"id":"b0201ca1-b956-480e-884c-9d9c02234c38","type":"Grid"},{"id":"2875eb8d-8f22-434f-972e-3761c07801d3","type":"BoxAnnotation"},{"id":"7314dfc1-883c-4906-a11e-e8480c02c2fa","type":"Legend"},{"id":"37cef42a-6d39-4b24-a4e7-f026152c0b48","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"1546da68-d560-440b-bff3-94a9a879510c","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"db001679-dda0-4844-9615-e9f6001a4de7","type":"DataRange1d"},"x_scale":{"id":"7e82d17b-2839-4078-ad32-cf4d6e23ceb5","type":"LinearScale"},"y_range":{"id":"324fb80c-d445-4bef-914e- ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"2e96fd02-ecc4-421d-b319-96b9fbc86348":{"roots":{"references":[{"attributes":{"fields":[]},"id":"c898b5ba-cbf6-4b3c-83f2-f297f6205328","type":"Stack"},{"attributes":{"source":{"id":"eedeb3e5-ba3b-4b51-b99e-e13c0bd07c54","type":"ColumnDataSource"}},"id":"16127b38-b21e-4e8a-886b-6716d13a3df2","type":"CDSView"},{"attributes":{"fields":["medals.bronze","medals.silver","medals.gold"]},"id":"eda7a862-291e-438f-b3e2-310574ac0ba8","type":"Stack"},{"attributes":{},"id":"e3df0dbc-3dee-485b-a08b-f28d5d1abb01","type":"SaveTool"},{"attributes":{"overlay":{"id":"279aab67-bfc0-43ff-bd57-45945e7a6e9d","type":"BoxAnnotation"}},"id":"9aa9cfa0-3c49-4b72-9e0b-a2f38e226d96","type":"BoxZoomTool"},{"attributes":{},"id":"ec962203-53ec-4b2d-8806-355554b4f8d0","type":"BasicTickFormatter"},{"attributes":{},"id":"70443daa-1405-4a67-8dc7-8bbecf70a12b","type":"BasicTicker"},{"attributes":{"children":[{"id":"d634aaac-88cd-47c6-9532-2e32ea5f1f5d","type":"ToolbarBox"},{"id":"c35e6296-b220-46f7-960f-75b592f2da0c","type":"Column"}]},"id":"da2eb8da-55c8-4320-a273-5a612715e22d","type":"Column"},{"attributes":{},"id":"edc76f2e-b1eb-40ed-8687-ef2f8137ef53","type":"CategoricalTickFormatter"},{"attributes":{"source":{"id":"eedeb3e5-ba3b-4b51-b99e-e13c0bd07c54","type":"ColumnDataSource"}},"id":"855112ae-2056-4069-99cb-c78d32fa2603","type":"CDSView"},{"attributes":{"tools":[{"id":"b5c4cf1c-c35e-4df8-b6b8-eb2654ecb6dd","type":"PanTool"},{"id":"67cf2198-77a9-471a-bfd2-8cb0b660ac3e","type":"WheelZoomTool"},{"id":"9aa9cfa0-3c49-4b72-9e0b-a2f38e226d96","type":"BoxZoomTool"},{"id":"e3df0dbc-3dee-485b-a08b-f28d5d1abb01","type":"SaveTool"},{"id":"87b7b848-e719-42c4-ab42-4dadc06008b7","type":"ResetTool"},{"id":"635e2ef0-8149-40c2-9d90-581a8a9a1b1f","type":"HelpTool"},{"id":"67081ac9-058b-4314-b193-86003f919fe9","type":"HoverTool"}]},"id":"a4b0ba3e-55c1-4c65-a9c7-8089500de8dd","type":"ProxyToolbar"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["medals.silver","@medals.silver{0.00}"],["name","@pd_stacked_col{0.00}"],["medals.gold","@medals.gold{0.00}"],["medals.bronze","@medals.bronze{0.00}"]]},"id":"67081ac9-058b-4314-b193-86003f919fe9","type":"HoverTool"},{"attributes":{"children":[{"id":"bc1eb3d4-a948-4f27-a56b-335b734759df","type":"Row"}]},"id":"c35e6296-b220-46f7-960f-75b592f2da0c","type":"Column"},{"attributes":{},"id":"b5c4cf1c-c35e-4df8-b6b8-eb2654ecb6dd","type":"PanTool"},{"attributes":{"callback":null,"data":{"medals.bronze":[1,1,1,4,1,0,2,0,5,4,1,4,2,1,1,2,8,7,0,7,0,4,2,1,1,10],"medals.gold":[0,2,5,4,3,0,1,0,3,8,1,0,1,0,2,0,6,8,4,6,1,2,2,6,0,6],"medals.silver":[2,6,0,8,2,1,3,3,2,3,0,2,4,0,1,1,6,4,0,8,0,1,5,3,0,4],"pd_stacked_col":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"]},"selected":{"id":"641b0b22-ae90-485f-90b7-d69fade686b5","type":"Selection"},"selection_policy":{"id":"a1df088f-e4ee-46d6-ba8f-8b60074a847c","type":"UnionRenderers"}},"id":"eedeb3e5-ba3b-4b51-b99e-e13c0bd07c54","type":"ColumnDataSource"},{"attributes":{},"id":"87b7b848-e719-42c4-ab42-4dadc06008b7","type":"ResetTool"},{"attributes":{},"id":"67cf2198-77a9-471a-bfd2-8cb0b660ac3e","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"279aab67-bfc0-43ff-bd57-45945e7a6e9d","type":"BoxAnnotation"},{"attributes":{"bottom":{"expr":{"id":"afa84cf7-24b8-4948-9f4a-36b2961e9178","type":"Stack"}},"fill_color":{"value":"#ff7f0e"},"line_color":{"value":"#ff7f0e"},"top":{"expr":{"id":"fa00cf26-3fa6-4b29-856d-723b4f0f802a","type":"Stack"}},"widt ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
