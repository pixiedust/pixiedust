# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.0.3</span>
#         </div>

# %%
from bokeh.sampledata.olympics2014 import data
from bokeh.charts.utils import df_from_json

# utilize utility to make it easy to get json/dict data converted to a dataframe
df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['total'] > 0]
df = df.sort_values("total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  bronze  gold  silver  total           name
# 65  RUS       7     6       8     21   Russian Fed.
# 81  USA      10     6       4     20  United States
# 54  NLD       8     6       6     20    Netherlands
# 56  NOR       7     8       4     19         Norway
# 13  CAN       4     4       8     16         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFiguree412849d" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#
#     <div class="bk-root">
#         <div class="bk-plot-layout bk-layout-fixed" id="modelid_ef49eef5-11da-4f0c-8f01-e71503a243c3" style="width: 798px; height: 596px;"><div class="bk-toolbar-wrapper bk-layout-null" id="modelid_7538f8bd-4e21-4bc2-bc5a-8d51594b11a6" style="left: 768px; top: 5px; width: 30px; height: 591px;"><div class="bk-toolbar-right bk-toolbar-sticky"><a href="http://bokeh.pydata.org/" target="_blank" class="bk-logo bk-logo-small"></a><div class="bk-button-bar"><div class="bk-button-bar-list" type="pan"><div class="bk-toolbar-button bk-active"><div class="bk-btn-icon bk-tool-icon-pan"></div><span class="bk-tip">Pan</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-box-zoom"></div><span class="bk-tip">Box Zoom</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-resize"></div><span class="bk-tip">Resize</span></div></div><div class="bk-button-bar-list" type="scroll"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-wheel-zoom"></div><span class="bk-tip">Wheel Zoom</span></div></div><div class="bk-button-bar-list" type="pinch"></div><div class="bk-button-bar-list" type="tap"></div><div class="bk-button-bar-list" type="press"></div><div class="bk-button-bar-list" type="rotate"></div><div class="bk-button-bar-list" type="actions"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-save"></div><span class="bk-tip">Save</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-reset"></div><span class="bk-tip">Reset</span></div></div><div class="bk-button-bar-list" type="inspectors"></div><div class="bk-button-bar-list" type="help"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-help"></div><span class="bk-tip">Click the question mark to learn more about Bokeh plot tools.</span></div></div></div></div></div><div class="bk-plot-wrapper" style="position: absolute; left: 0px; top: 0px; width: 798px; height: 596px;"><div class="bk-canvas-wrapper" style="touch-action: none; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); width: 798px; height: 596px; cursor: default;"><div class="bk-canvas-events"></div><div class="bk-canvas-overlays"><div class="bk-shading" style="display: none;"></div></div><canvas class="bk-canvas" width="718.1999809741974" height="536.3999857902527" style="width: 798px; height: 596px;"></canvas><div class="bk-resize-popup" style="display: none;"></div></div></div></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c879bc75-f66f-4938-88ac-e4200ff0cafc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c879bc75-f66f-4938-88ac-e4200ff0cafc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c879bc75-f66f-4938-88ac-e4200ff0cafc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4cd58a77-9760-4c32-8388-5f3deceb3af4":{"roots":{"references":[{"attributes":{"data_source":{"id":"4094cc4f-d1ea-4b20-8c3d-db922d1f62e3","type":"ColumnDataSource"},"glyph":{"id":"6c5c1fc9-7cd4-4247-b9fe-05870ad46f1b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"012e2d9c-9580-4996-a537-91cf368db264","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":5.5},"id":"ba8ad522-a9ea-4db6-a759-00e1c6615ef0","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0997e8fe-b66c-4175-82f2-ea9e19d8bf8c","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ef49eef5-11da-4f0c-8f01-e71503a243c3","subtype":"Chart","type":"Plot"}},"id":"e0ff6cca-29ac-4f79-b97c-2ac28a28b009","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"469a4ca1-1523-471c-93f1-daa18fb5c8df","type":"Rect"},{"attributes":{},"id":"4dcfbe58-af02-4590-88f0-11788a1d91da","type":"BasicTicker"},{"attributes":{"data_source":{"id":"92c902ca-e360-426a-9418-0e0bb7f75a89","type":"ColumnDataSource"},"glyph":{"id":"a5eb8b3b-d969-4195-ae53-bde165289d23","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0de7e7eb-8dea-4d21-a879

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='total',valueFields='total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4862f2ca-1534-4dcb-960c-b0af83b66daf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4862f2ca-1534-4dcb-960c-b0af83b66daf");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4862f2ca-1534-4dcb-960c-b0af83b66daf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4862f2ca-1534-4dcb-960c-b0af83b66daf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0368d3f4-7415-4b18-9bd3-437629ee923a":{"roots":{"references":[{"attributes":{"data_source":{"id":"cf99db12-5f8a-496a-9a83-a993605c33b1","type":"ColumnDataSource"},"glyph":{"id":"00d24cbb-f3a7-490d-8bed-39dec8c39174","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e2f75e9d-28ec-4391-88e8-5845ae3b7383","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bd429067-4835-4d60-a601-2441e7aa8cd1","type":"Rect"},{"attributes":{"data_source":{"id":"16ad7c2f-bdde-4cbe-9633-5fdbf8f195de","type":"ColumnDataSource"},"glyph":{"id":"13e9d643-3cfd-4fc3-991a-a0871a9d3364","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b150bc21-3706-4def-92a9-07a04610493a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(9.000000, 11.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(9.000000, 11.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["10.0"],"y":[2.0]}},"id":"7c1329a1-2076-477e-8adf-0b697bea2f4c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8a58a006-f309-4e30-8068-a3675b689442","type":"ColumnDataSource"},"glyph":{"id":"b116113b-a002-42fc-81c4-7ec3149c2346","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"53b63875-3b33-4fd5-b896-d430352fd610","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b0ba8964-9bd3-476a-abc1-65224a0509a8","type":"ColumnDataSource"},"glyph":{"id":"adb8fcf2-aeba-4cef-abf5-55a7b0607852","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"63e67ac8-38aa-40ed-adbb-f93c67030af8","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":5.5},"id":"758dd6eb-fd6b-4168-b31b-68619e8580c6","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(17.000000, 19.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(17.000000, 19.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["18.0"],"y":[0.0]}},"id":"27e1d3f1-6522-434a-8c6e-48eeba9fd58c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(3.000000, 5.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"label":["(3.000000, 5.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["4.0"],"y":[2.5]}},"id":"8a58a006-f309-4e30-8068-a3675b689442","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"e062e355-4b9f-4d39-adcf-a978247a2fdb","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"29590c6a-2b64-438c-b00a-5a70170856a7","type":"Rect"},{"attributes":{},"id":"487677bb-0292-4f59-a997-9ef833efbac6","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"adb8fcf2-aeba-4cef-abf5-55a7b0607852","type":"Rect"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"040b3728-a78d-44ad-b361-6cc6ce1e41d7","type":"BasicTickFormatter"},"plot":{"id":"547105a5-899d-4f66-a789-6c6902833094","subtype":"Chart","type":"Plot"},"ticker":{"id":"c47e4c38-2618-439d-abf1-4f6d801e590f","type":"BasicTicker"}},"id":"c24b6d7e-5692-4cbf-9d14-f3f5c4e6dd6e","type":"LinearAxis"},{"attributes":{"ca ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='total',valueFields='gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c4686153-ff01-4373-8c99-749673bb5b77"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c4686153-ff01-4373-8c99-749673bb5b77");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c4686153-ff01-4373-8c99-749673bb5b77");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c4686153-ff01-4373-8c99-749673bb5b77' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d2dcc8bd-8fba-4325-aa53-f057370cb123":{"roots":{"references":[{"attributes":{"label":{"value":"UKR"},"renderers":[{"id":"ed93db45-dac9-41a0-bb87-18694994c1ea","type":"GlyphRenderer"}]},"id":"ade09e29-7050-4f66-9312-d4ba42cbdbbf","type":"LegendItem"},{"attributes":{"plot":{"id":"4dbfd7bf-e81b-42f1-828e-fc0ae489853b","subtype":"Chart","type":"Plot"}},"id":"14e8ff0e-90f0-4a48-ac4d-62db1d0ad071","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{
{"id":"ae704819-5f98-488a-bc8a-364c51ab8312","type":"GlyphRenderer"},{"id":"eb387ae9-fe8d-462d-aa7c-7f30281f42fc","type":"GlyphRenderer"},{"id":"20503afb-2904-48ec-ae38-60786bc7db1b","type":"GlyphRenderer"},{"id":"ed93db45-dac9-41a0-bb87-18694994c1ea","type":"GlyphRenderer"},{"id":"8490345e-e524-419e-8cfa-cff71c1ae325","type":"GlyphRenderer"},{"id":"dc3d73bb-13b0-4dae-97b3-a649a515c82c","type":"Legend"},{"id":"8bca27d8-22bb-4f94-a2f8-09c5391e0175","type":"LinearAxis"},{"id":"154080bc-9ca3-4e2f-9079-909fd2680f89","type":"LinearAxis"},{"id":"3998b281-e523-454b-9ee1-115dc6fe7e2c","type":"Grid"},{"id":"5384aff4-f5bf-463f-9600-aa92638e3f5e","type":"Grid"}],"title":{"id":"ead8455f-6fe5-4305-8ecf-a5aa90b2a7c3","type":"Title"},"tool_events":{"id":" ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='abbr',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1b6ec9eb-67d7-49de-baa6-6e02ead57397"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1b6ec9eb-67d7-49de-baa6-6e02ead57397");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1b6ec9eb-67d7-49de-baa6-6e02ead57397");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1b6ec9eb-67d7-49de-baa6-6e02ead57397' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"34e83965-3db9-4728-a066-91e8e4a1a705":{"roots":{"references":[{"attributes":{"data_source":{"id":"e14bed0c-e95f-4781-b081-6a2a713caa58","type":"ColumnDataSource"},"glyph":{"id":"b6aff879-ae71-411d-9359-b4e9f92571ac","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"615678f7-6a6c-4fc8-ba9e-ee87b7496956","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":["AUS","AUT","BLR","CAN","CHE","CHN","CZE","DEU","FIN","FRA","GBR","HRV","ITA","JPN","KAZ","KOR","LVA","NLD","NOR","POL","RUS","SVK","SVN","SWE","UKR","USA"],"y_values":[2,6,0,8,3,2,3,3,3,2,0,1,2,4,0,1,1,6,4,0,8,0,1,5,0,4]}},"id":"e14bed0c-e95f-4781-b081-6a2a713caa58","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"a3237f90-1d6d-464b-b670-dc231bb27115","type":"ToolbarBox"},{"id":"898a4e04-c528-4b0f-a040-675152049007","type":"Column"}]},"id":"60e51ec1-6d78-4378-bc71-22b4c94d0ba5","type":"Column"},{"attributes":{"below":[{"id":"64969173-c165-4ced-9ccc-8e1861328b37","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"87028a79-3787-4f1f-86b7-27c332a376ad","type":"LinearAxis"}],"plot_height":298,"plot_width":399,"renderers":[{"id":"7c85b986-3281-4a8d-99e6-53406662a944","type":"BoxAnnotation"},{"id":"615678f7-6a6c-4fc8-ba9e-ee87b7496956","type":"GlyphRenderer"},{"id":"3ed93660-2b1f-456a-9a54-d895924aa5e9","type":"Legend"},{"id":"64969173-c165-4ced-9ccc-8e1861328b37","type":"CategoricalAxis"},{"id":"87028a79-3787-4f1f-86b7-27c332a376ad","type":"LinearAxis"},{"id":"ae71d532-a76a-413e-a25b-2b9fdb60cd25","type":"Grid"},{"id":"fb079a8e-18da-49a3-b41b-6b27a31ad1d4","type":"Grid"}],"title":{"id":"4794d989-b657-4b27-9d54-3269a2f3d87f","type":"Title"},"tool_events":{"id":"a21f6805-c5dc-4a74-994a-d288b87c33e4","type":"ToolEvents"},"toolbar":{"id":"8d590850-e055-43f3-a1cf-9cd35db62a7c","type":"Toolbar"},"toolbar_location":null,"x_mapper_type":"auto","x_range":{"id":"0880db4f-ff72-4e23-8ad5-667194410847","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"29caca75-796d-4d4a-be4f-9a5056b1f746","type":"Range1d"}},"id":"365762b0-7fc3-49b7-975d-cefe85e1db36","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"silver","formatter":{"id":"5fe003a2-6489-43af-97cd-b6034a5006c2","type":"BasicTickFormatter"},"plot":{"id":"365762b0-7fc3-49b7-975d-cefe85e1db36","subtype":"Chart","type":"Plot"},"ticker":{"id":"89ea4d55-d433-4cd9-8ffa-94c08f997fb5","type":"BasicTicker"}},"id":"87028a79-3787-4f1f-86b7-27c332a376ad","type":"LinearAxis"},{"attributes":{"plot":{"id":"365762b0-7fc3-49b7-975d-cefe85e1db36","subtype":"Chart","type":"Plot"}},"id":"366aa8b6-3ce3-4ecf-a4d8-8f44ecbb8d11","type":"SaveTool"},{"attributes":{"line_color":{"value":"#000080"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2f64fdfc-7f1f-4e08-9230-4e0fa827b7ba","type":"Line"},{"attributes":{"callback":null,"end":8.8,"start":-0.8},"id":"29caca75-796d-4d4a-be4f-9a5056b1f746","type":"Range1d"},{"attributes":{},"id":"67a20f5d-b861-4673-b7db-7e1659aad0ae","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"d6def745-5762-4192-a733-8724387f7330","subtype":"Chart","type":"Plot"}]},"id":"802b4854-32ec-45e2-a06c-1e655fca491a","type":"Row"},{"attributes":{},"id":"8c5daf09-20de-4283-b5e3-53846ddb8a51","type":"ToolEvents"},{"attributes":{},"id":"73ce7bb1-4560-4434-a6e4-e44864de93fe","type":"CategoricalTicker"},{"attributes":{"callback":null,"factors":["AUS","AUT","BLR","CAN","CHE","CHN","CZE","DEU","FIN","FRA","GBR","HRV","ITA","JPN","KAZ","KOR","LVA","NLD","NOR","POL","RUS","SVK","SVN","SWE","UKR","USA"]},"id":"7adf3f1d-bd29-4116-9756-cb73deedf430","type":"FactorRange"},{"attributes":{"plot":{"id":"d6def745-5762-4192-a733-8724387f7330","subtype":"Chart","type":"Plot"}},"id":"9ca26e7d-3ca2-4f48-a3dd-4c531d9977f8","type":"PanTool" ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","co ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#               <div class="fixed-cell">abbr</div>
#
#               <div class="fixed-cell">bronze</div>
#
#               <div class="fixed-cell">gold</div>
#
#               <div class="fixed-cell">silver</div>
#
#               <div class="fixed-cell">total</div>
#
#               <div class="fixed-cell">name</div>
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#                 <th><div>abbr</div></th>
#
#                 <th><div>bronze</div></th>
#
#                 <th><div>gold</div></th>
#
#                 <th><div>silver</div></th>
#
#                 <th><div>total</div></th>
#
#                 <th><div>name</div></th>
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#                 <td>RUS</td>
#
#                 <td>7</td>
#
#                 <td>6</td>
#
#                 <td>8</td>
#
#                 <td>21</td>
#
#                 <td>Russian Fed.</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>USA</td>
#
#                 <td>10</td>
#
#                 <td>6</td>
#
#                 <td>4</td>
#
#                 <td>20</td>
#
#                 <td>United States</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NLD</td>
#
#                 <td>8</td>
#
#                 <td>6</td>
#
#                 <td>6</td>
#
#                 <td>20</td>
#
#                 <td>Netherlands</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NOR</td>
#
#                 <td>7</td>
#
#                 <td>8</td>
#
#                 <td>4</td>
#
#                 <td>19</td>
#
#                 <td>Norway</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CAN</td>
#
#                 <td>4</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>16</td>
#
#                 <td>Canada</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>DEU</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>3</td>
#
#                 <td>15</td>
#
#                 <td>Germany</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CHE</td>
#
#                 <td>1</td>
#
#                 <td>6</td>
#
#                 <td>3</td>
#
#                 <td>10</td>
#
#                 <td>Switzerland</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>FRA</td>
#
#                 <td>5</td>
#
#                 <td>3</td>
