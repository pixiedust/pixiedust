# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.0.3</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.0.3, Latest is 1.0.2</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %%
from bokeh.sampledata.olympics2014 import data
from bokeh.charts.utils import df_from_json

# utilize utility to make it easy to get json/dict data converted to a dataframe
df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['total'] > 0]
df = df.sort_values("total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  bronze  gold  silver  total           name
# 65  RUS       7     6       8     21   Russian Fed.
# 81  USA      10     6       4     20  United States
# 54  NLD       8     6       6     20    Netherlands
# 56  NOR       7     8       4     19         Norway
# 13  CAN       4     4       8     16         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureeb3e5eb2" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#
#     <div class="bk-root">
#         <div class="bk-plot-layout bk-layout-fixed" id="modelid_d62bb794-e45d-423d-b80a-f9e7b57d38df" style="width: 798px; height: 596px;"><div class="bk-toolbar-wrapper bk-layout-null" id="modelid_ec80fc17-c798-486a-b760-e3fd2688f4ae" style="left: 768px; top: 5px; width: 30px; height: 591px;"><div class="bk-toolbar-right bk-toolbar-sticky"><a href="http://bokeh.pydata.org/" target="_blank" class="bk-logo bk-logo-small"></a><div class="bk-button-bar"><div class="bk-button-bar-list" type="pan"><div class="bk-toolbar-button bk-active"><div class="bk-btn-icon bk-tool-icon-pan"></div><span class="bk-tip">Pan</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-box-zoom"></div><span class="bk-tip">Box Zoom</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-resize"></div><span class="bk-tip">Resize</span></div></div><div class="bk-button-bar-list" type="scroll"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-wheel-zoom"></div><span class="bk-tip">Wheel Zoom</span></div></div><div class="bk-button-bar-list" type="pinch"></div><div class="bk-button-bar-list" type="tap"></div><div class="bk-button-bar-list" type="press"></div><div class="bk-button-bar-list" type="rotate"></div><div class="bk-button-bar-list" type="actions"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-save"></div><span class="bk-tip">Save</span></div><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-reset"></div><span class="bk-tip">Reset</span></div></div><div class="bk-button-bar-list" type="inspectors"></div><div class="bk-button-bar-list" type="help"><div class="bk-toolbar-button"><div class="bk-btn-icon bk-tool-icon-help"></div><span class="bk-tip">Click the question mark to learn more about Bokeh plot tools.</span></div></div></div></div></div><div class="bk-plot-wrapper" style="position: absolute; left: 0px; top: 0px; width: 798px; height: 596px;"><div class="bk-canvas-wrapper" style="touch-action: none; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); width: 798px; height: 596px;"><div class="bk-canvas-events"></div><div class="bk-canvas-overlays"><div class="bk-shading" style="display: none;"></div></div><canvas class="bk-canvas" width="718.1999809741974" height="536.3999857902527" style="width: 798px; height: 596px;"></canvas><div class="bk-resize-popup" style="display: none;"></div></div></div></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ce9e1df9-6da3-41a8-a6b7-10e5b8272350").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ce9e1df9-6da3-41a8-a6b7-10e5b8272350");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ce9e1df9-6da3-41a8-a6b7-10e5b8272350' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c85741cb-60cc-4d55-9ae2-b9420915ab72":{"roots":{"references":[{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"d62bb794-e45d-423d-b80a-f9e7b57d38df","subtype":"Chart","type":"Plot"},"ticker":{"id":"21a5d586-abe1-4090-8460-c05b74a3a1e0","type":"BasicTicker"}},"id":"ec53aa83-f57c-41a9-bccd-e0b0b565682d","type":"Grid"},{"attributes":{"data_source":{"id":"6646def9-b2c9-464e-8c38-31a58866473e","type":"ColumnDataSource"},"glyph":{"id":"dc93dab4-d292-4617-9a0a-788e3880edf0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3f8218cd-5ce4-456e-b421-6f4dc1d254c5","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"d62bb794-e45d-423d-b80a-f9e7b57d38df","subtype":"Chart","type":"Plot"}},"id":"3698adc0-2771-4417-97ef-5154aa97356b","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2385f9e2-f568-4688-af20-17860118bccd","type":"Rect"},{"attributes":{"plot":{"id":"d62bb794-e45d-423d-b80a-f9e7b57d38df","subtype":"Chart","type":"Plot"}},"id":"71fcda62-6f1b-4b06-a8de-231171a64d6f","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(15.000000, 17.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(15.000000, 17.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["16.0"],"y":[1.0]}},"id":"923f060a-914a-43be-

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='total',valueFields='total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5803cb8a-9fc1-43b1-8a3c-6ea2d541f6c2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5803cb8a-9fc1-43b1-8a3c-6ea2d541f6c2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5803cb8a-9fc1-43b1-8a3c-6ea2d541f6c2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5803cb8a-9fc1-43b1-8a3c-6ea2d541f6c2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"89b7c665-9883-4d69-bac6-294e3cd05998":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.000000, 7.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(5.000000, 7.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["6.0"],"y":[2.0]}},"id":"fcdbef6c-9d59-43a5-ba75-f885126d5a1e","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":5.5},"id":"fc5e17dd-6ca5-4c1e-b129-4664adb8f940","type":"Range1d"},{"attributes":{},"id":"8e44f0bf-3b7a-4fd1-bb53-4e4bd6649aa9","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ce2a824b-6452-4093-93d9-a09808ab4477","type":"BoxAnnotation"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"7c94d6af-d6ab-4fa5-82f9-f3a2943d2d32","subtype":"Chart","type":"Plot"},"ticker":{"id":"5f797207-4efb-43de-a03a-ec5934d0ef1f","type":"BasicTicker"}},"id":"67b67cf4-c070-4514-820f-e269b2349477","type":"Grid"},{"attributes":{"plot":{"id":"7c94d6af-d6ab-4fa5-82f9-f3a2943d2d32","subtype":"Chart","type":"Plot"}},"id":"f6cce537-c7f2-4247-a441-07178fd2f077","type":"HelpTool"},{"attributes":{},"id":"5f797207-4efb-43de-a03a-ec5934d0ef1f","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8933f4ed-52c8-4b6f-8052-59b297e9817e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae3e19a7-5c66-44ac-b443-6c507f14df38","type":"Rect"},{"attributes":{"data_source":{"id":"a4e50007-f121-4ace-a120-d5de3fc59432","type":"ColumnDataSource"},"glyph":{"id":"d2add9ec-4345-4440-8311-fa223e1ff65b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d2ab7a1b-10c1-432d-acf9-ce4db452dc75","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(13.000000, 15.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(13.000000, 15.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["14.0"],"y":[0.0]}},"id":"a1f4e7c3-8810-4c5b-ace9-2eed33308f8b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f5791825-7ab5-484d-b32f-858825a9fbbe","type":"ColumnDataSource"},"glyph":{"id":"a82832ff-e6dd-48c7-b720-4ffbfa6ea61f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7aeff1cd-ecb4-4e16-86b2-7c7125b82b74","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2add9ec-4345-4440-8311-fa223e1ff65b","type":"Rect"},{"attributes":{"plot":{"id":"7c94d6af-d6ab-4fa5-82f9-f3a2943d2d32","subtype":"Chart","type":"Plot"}},"id":"ee12b4c5-8061-4806-afb2-69a0538de5ec","type":"WheelZoomTool"},{"attributes":{"location":"top_left","plot":{"id":"7c94d6af-d6ab-4fa5-82f9-f3a2943d2d32","subtype":"Chart","type":"Plot"}},"id":"a015d1aa-be94-44c3-b49d-cb14a11cebd2","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"985f8910-b9be-442b-a12f-5c6e582a9c ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='total',valueFields='gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a68474c1-d3d1-43a8-963d-12efa6b3c42b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a68474c1-d3d1-43a8-963d-12efa6b3c42b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a68474c1-d3d1-43a8-963d-12efa6b3c42b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a68474c1-d3d1-43a8-963d-12efa6b3c42b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"48cd9cad-ba17-4d6b-ae44-0c9af4cba4dc":{"roots":{"references":[{"attributes":{"label":{"value":"NLD"},"renderers":[{"id":"d4a5e050-93e2-4bce-af83-b2cf78417cbb","type":"GlyphRenderer"}]},"id":"13947660-0858-4f8f-91b8-724441a413f4","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"abbr":["NLD"],"chart_index":[{"abbr":"NLD"}],"x_values":[20],"y_values":[6]}},"id":"dbc3b685-85da-4059-baf4-46740d3d931b","type":"ColumnDataSource"},{"attributes":{"label":{"value":"GBR"},"renderers":[{"id":"64c0aca9-c740-4297-9f7d-766b105f7834","type":"GlyphRenderer"}]},"id":"e580f26e-61ed-4689-bdc5-75fdd9093f01","type":"LegendItem"},{"attributes":{"label":{"value":"KOR"},"renderers":[{"id":"af6074fc-5cbf-440a-8d64-b825f3f566f7","type":"GlyphRenderer"}]},"id":"d79ed98d-b354-4829-a0df-377d2f542194","type":"LegendItem"},{"attributes":{},"id":"88e747f6-ef37-45b0-a884-4cd479ce7f43","type":"ToolEvents"},{"attributes":{"data_source":{"id":"a1e56baa-41a5-4619-9dd0-678cc8b9365d","type":"ColumnDataSource"},"glyph":{"id":"e1160e87-61ef-4e17-8ce6-a100d845462d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9bc15669-ebe4-4710-9516-eb1fa8423f04","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ea6713f8-dccc-42a0-a5c7-9abe15691bf3","subtype":"Chart","type":"Plot"}},"id":"30fa4c1c-634d-4ad1-a641-b52b18c67077","type":"ResizeTool"},{"attributes":{},"id":"9d442430-1e80-40ad-a178-fd2896d8828f","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"16a9b430-0e8f-4083-988a-4e2820310efe","type":"PanTool"},{"id":"fee2b53a-f521-4372-820d-eda0a5c38359","type":"WheelZoomTool"},{"id":"4b330923-7911-4ea9-870a-1f317c7fa224","type":"BoxZoomTool"},{"id":"0e5b4244-d476-49e2-b155-e3a478088b25","type":"SaveTool"},{"id":"a6dcbf5d-a73c-44b2-8815-8da669d5572f","type":"ResetTool"},{"id":"e9e3ec95-ffd9-4886-bebb-83c7d11aa98c","type":"HelpTool"},{"id":"30fa4c1c-634d-4ad1-a641-b52b18c67077","type":"ResizeTool"}]},"id":"ec78203f-7983-4eaf-a1b5-bad5e73c7d8a","type":"Toolbar"},{"attributes":{"label":{"value":"FRA"},"renderers":[{"id":"e435ddcb-95bd-4435-a3fb-cf767ffa1eb2","type":"GlyphRenderer"}]},"id":"90c8a924-2eb8-4651-afbb-f03a7e3be824","type":"LegendItem"},{"attributes":{"callback":null,"end":8.8,"start":-0.8},"id":"ef9d56a2-944e-43e9-840d-3a4161aa1a6d","type":"Range1d"},{"attributes":{"label":{"value":"POL"},"renderers":[{"id":"739f650b-0150-4412-abad-403480eea999","type":"GlyphRenderer"}]},"id":"713d5bea-6eac-417b-8c24-54e90adda891","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"386ea253-d48c-421d-bc87-e0922a246ab7","type":"Circle"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"abbr":["CZE"],"chart_index":[{"abbr":"CZE"}],"x_values":[6],"y_values":[1]}},"id":"c5bbf0ee-b726-4e41-9c49-f62625677579","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"abbr":["SVN"],"chart_index":[{"abbr":"SVN"}],"x_values":[7],"y_values":[2]}},"id":"83acce0b-7247-48f8-9254-3902930d7211","type":"ColumnDataSource"},{"attributes":{"label":{"value":"HRV"},"renderers":[{"id":"32998238-9a05-4c29-ac57-2e84a9fcfdcd","type":"GlyphRenderer"}]},"id":"e284f1ac-4478-4eb0-951f-46d401ac1985","type":"LegendItem"},{"attributes":{"label":{"value":"SWE"},"renderers":[{"id":"df9770a1-20aa-45be-8cd5-1bcbe51b0087","type":"GlyphRenderer"}]},"id":"4c6c7e09-ec45-478b-beb6-1d2d76daad1a","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"11596577-aa65-4a6d-8c48-d2f2978855d7","type":"Circle"},{"attributes":{"label":{" ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='abbr',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c840d9a7-576f-4581-bf6a-b9612b2fdd83"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c840d9a7-576f-4581-bf6a-b9612b2fdd83").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c840d9a7-576f-4581-bf6a-b9612b2fdd83");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c840d9a7-576f-4581-bf6a-b9612b2fdd83' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d05bb4c6-0981-42c6-a2d3-59cdfc4a3258":{"roots":{"references":[{"attributes":{"children":[{"id":"a3e5afb8-e733-454b-a273-ac6da6ed66d2","subtype":"Chart","type":"Plot"},{"id":"43aa652c-7749-4e1b-a260-1713ab986b5f","subtype":"Chart","type":"Plot"}]},"id":"47eba646-8904-4777-8f0a-9b5a2463adfc","type":"Row"},{"attributes":{"axis_label":"silver","formatter":{"id":"ba9b4e78-9d3d-4a6b-8e14-95e67b4d3662","type":"BasicTickFormatter"},"plot":{"id":"43aa652c-7749-4e1b-a260-1713ab986b5f","subtype":"Chart","type":"Plot"},"ticker":{"id":"921a7316-1878-4d60-9a0b-9c62fcac84f8","type":"BasicTicker"}},"id":"88aeecbd-28c2-4f3f-b4bf-be9f23ed7424","type":"LinearAxis"},{"attributes":{"plot":{"id":"43aa652c-7749-4e1b-a260-1713ab986b5f","subtype":"Chart","type":"Plot"}},"id":"38c56a25-8653-4ba5-9042-a268a35dd63c","type":"WheelZoomTool"},{"attributes":{"children":[{"id":"9c626d2d-9287-47fb-b395-05917ca65d32","type":"ToolbarBox"},{"id":"7d014634-9589-4579-a727-a48147f01115","type":"Column"}]},"id":"245b48ec-cfc2-42dc-8fe6-26ececbe4f79","type":"Column"},{"attributes":{"callback":null,"end":11.0,"start":-1.0},"id":"2d193900-1598-483c-9cfb-44b2f52253b2","type":"Range1d"},{"attributes":{"plot":{"id":"a3e5afb8-e733-454b-a273-ac6da6ed66d2","subtype":"Chart","type":"Plot"}},"id":"037f08b4-96d4-40ae-9578-e125aaf843c8","type":"WheelZoomTool"},{"attributes":{"axis_label":"abbr","formatter":{"id":"5bbbfd84-2c63-4326-a31a-478f75aedd02","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"a3e5afb8-e733-454b-a273-ac6da6ed66d2","subtype":"Chart","type":"Plot"},"ticker":{"id":"ae08b2d6-6555-4cd8-a0c0-873004203de8","type":"CategoricalTicker"}},"id":"42fb7ba7-d704-4ad2-a218-f39ae363810d","type":"CategoricalAxis"},{"attributes":{},"id":"569bf420-e9dd-40d5-b7e1-6f232b16ff63","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"abbr","formatter":{"id":"30b138cd-b442-4bc0-8b89-10e51ff1b035","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"dacf56b4-24a7-4d62-ab91-56554ec95084","subtype":"Chart","type":"Plot"},"ticker":{"id":"82ce94c4-64e1-4bce-a1de-d47f7564fc3e","type":"CategoricalTicker"}},"id":"247f7df8-a131-4cfb-9aaa-7e03800505ff","type":"CategoricalAxis"},{"attributes":{},"id":"dec0b93a-f234-439e-9a96-8f4e24025e39","type":"BasicTicker"},{"attributes":{"axis_label":"bronze","formatter":{"id":"baa6c8ca-f08a-4d8b-bfeb-764efc6d552f","type":"BasicTickFormatter"},"plot":{"id":"a3e5afb8-e733-454b-a273-ac6da6ed66d2","subtype":"Chart","type":"Plot"},"ticker":{"id":"938aa204-59c7-464b-97fc-449c9066cdab","type":"BasicTicker"}},"id":"5b9fb09e-3712-496a-ba1e-aa4b624e46a7","type":"LinearAxis"},{"attributes":{},"id":"ba9b4e78-9d3d-4a6b-8e14-95e67b4d3662","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a3e5afb8-e733-454b-a273-ac6da6ed66d2","subtype":"Chart","type":"Plot"}},"id":"966d3d53-bc01-49df-ae12-4625600141bf","type":"HelpTool"},{"attributes":{},"id":"f5c4bbdf-e462-4b13-90da-2142f57beb3e","type":"ToolEvents"},{"attributes":{"location":"top_left","plot":{"id":"a3e5afb8-e733-454b-a273-ac6da6ed66d2","subtype":"Chart","type":"Plot"}},"id":"394198e7-3c52-4a47-8c65-d3c0bbcc466f","type":"Legend"},{"attributes":{"plot":{"id":"dacf56b4-24a7-4d62-ab91-56554ec95084","subtype":"Chart","type":"Plot"}},"id":"6ce81920-c40e-4f98-994c-17bca8ca84fc","type":"PanTool"},{"attributes":{"axis_label":"gold","formatter":{"id":"55eaea6d-4b6f-4c20-9558-350b7c1fe172","type":"BasicTickFormatter"},"plot":{"id":"dacf56b4-24a7-4d62-ab91-56554ec95084","subtype":"Chart","type":"Plot"},"ticker":{"id":"dec0b93a-f234-439e-9a96-8f4e24025e39","type":"BasicTicker"}},"id":"5cc5df1a-aa43-4cf8-a6a4-02738c2ee5e4","type":"LinearAxis"},{"attributes":{"plot":{"id":"dacf56b4-24a7-4d62-ab91-56554ec95084","subtype":"Chart","type":"Plot"}},"id":"1766c9a0-8f7b-4dfb-8157-cf013986a4fd","type":"SaveTool"},{"attributes":{"data_source":{"id":"65c97738-88f4-427f-b967-d882b2e7103a","type":"ColumnDataSourc ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='bronze,silver,gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#
#
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d587bbb-e084-4f2d-aa7e-ca9c7d70f88e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0d587bbb-e084-4f2d-aa7e-ca9c7d70f88e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d587bbb-e084-4f2d-aa7e-ca9c7d70f88e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d587bbb-e084-4f2d-aa7e-ca9c7d70f88e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"49a2aec0-c9cc-4d7d-ae16-f976dfee2d31":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bronze_silver_gold":["gold"],"chart_index":[{"bronze_silver_gold":"gold","name":"Australia"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[0.0],"label":[{"bronze_silver_gold":"gold","name":"Australia"}],"line_alpha":[1.0],"line_color":["white"],"name":["Australia"],"width":[0.8],"x":["Australia"],"y":[3.0]}},"id":"12619d89-1d3e-4ff5-9dbf-b7a8c45e85e0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bronze_silver_gold":["gold"],"chart_index":[{"bronze_silver_gold":"gold","name":"Ukraine"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[0.0],"label":[{"bronze_silver_gold":"gold","name":"Ukraine"}],"line_alpha":[1.0],"line_color":["white"],"name":["Ukraine"],"width":[0.8],"x":["Ukraine"],"y":[1.0]}},"id":"08bd1d58-4c6f-403a-93d5-8be48f579c57","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"69e66e86-3c2d-4fbc-8fda-c07ebb78bf88","type":"ColumnDataSource"},"glyph":{"id":"698b5c00-0c67-4d47-86ff-fcd18702e356","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1f55d8cf-ab66-42b4-a9c1-2632742419cf","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30445cf9-d3b8-4f7b-a429-cd2039f08b43","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bronze_silver_gold":["bronze"],"chart_index":[{"bronze_silver_gold":"bronze","name":"Kazakhstan"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"bronze_silver_gold":"bronze","name":"Kazakhstan"}],"line_alpha":[1.0],"line_color":["white"],"name":["Kazakhstan"],"width":[0.8],"x":["Kazakhstan"],"y":[0.5]}},"id":"4d5e959a-8bfa-4bc2-becd-f4fb234a3fe2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e8dff52d-0eb0-49e8-8767-054d73bc4d7b","type":"Rect"},{"attributes":{"data_source":{"id":"aa2813a6-3aaa-40ad-b9c6-010b7a40ec41","type":"ColumnDataSource"},"glyph":{"id":"6413919f-bb72-4f3b-b349-586153e9f988","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"737e4bf5-bcfe-4fbb-b2f3-d4a67f381fb9","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ed19f54-0f0d-45fa-93a3-708587e28b4f","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bronze_silver_gold":["gold"],"chart_index":[{"bronze_silver_gold":"gold","name":"Korea"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[2.0],"label":[{"bronze_silver_gold":"gold","name":"Korea"}],"line_alpha":[1.0],"line_color":["white"],"name":["Korea"],"width":[0.8],"x":["Korea"],"y":[3.0]}},"id":"7af4562e-969b-4881-9cb3-77c4ac12528f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"97b20d02-b33d-493c-9f29-21b5791b95d6","type":"Rect"},{"attributes":{"data_source":{ ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#               <div class="fixed-cell">abbr</div>
#
#               <div class="fixed-cell">bronze</div>
#
#               <div class="fixed-cell">gold</div>
#
#               <div class="fixed-cell">silver</div>
#
#               <div class="fixed-cell">total</div>
#
#               <div class="fixed-cell">name</div>
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#                 <th><div>abbr</div></th>
#
#                 <th><div>bronze</div></th>
#
#                 <th><div>gold</div></th>
#
#                 <th><div>silver</div></th>
#
#                 <th><div>total</div></th>
#
#                 <th><div>name</div></th>
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#                 <td>RUS</td>
#
#                 <td>7</td>
#
#                 <td>6</td>
#
#                 <td>8</td>
#
#                 <td>21</td>
#
#                 <td>Russian Fed.</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>USA</td>
#
#                 <td>10</td>
#
#                 <td>6</td>
#
#                 <td>4</td>
#
#                 <td>20</td>
#
#                 <td>United States</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NLD</td>
#
#                 <td>8</td>
#
#                 <td>6</td>
#
#                 <td>6</td>
#
#                 <td>20</td>
#
#                 <td>Netherlands</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>NOR</td>
#
#                 <td>7</td>
#
#                 <td>8</td>
#
#                 <td>4</td>
#
#                 <td>19</td>
#
#                 <td>Norway</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CAN</td>
#
#                 <td>4</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>16</td>
#
#                 <td>Canada</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>DEU</td>
#
#                 <td>4</td>
#
#                 <td>8</td>
#
#                 <td>3</td>
#
#                 <td>15</td>
#
#                 <td>Germany</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>CHE</td>
#
#                 <td>1</td>
#
#                 <td>6</td>
#
#                 <td>3</td>
#
#                 <td>10</td>
#
#                 <td>Switzerland</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>FRA</td>
#
#                 <td>5</td>
#
#                 <td>3</td>
