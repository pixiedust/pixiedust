# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.3</span>
#         </div>
# /Users/jbarbosa/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: bokeh.util.notebook was deprecated in Bokeh 0.12.10 and will be removed, use bokeh.io.notebook instead.
#   warn(message)

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-0085963b panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-0085963b" data-parent="#df-table-wrapper-0085963b">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-0085963b" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-0085963b" data-parent="#df-table-wrapper-0085963b">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-0085963b" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">abbr</div>
#
#
#
#               <div class="fixed-cell">medals.bronze</div>
#
#
#
#               <div class="fixed-cell">medals.gold</div>
#
#
#
#               <div class="fixed-cell">medals.silver</div>
#
#
#
#               <div class="fixed-cell">medals.total</div>
#
#
#
#               <div class="fixed-cell">name</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>abbr</div></th>
#
#
#
#                 <th><div>medals.bronze</div></th>
#
#
#
#                 <th><div>medals.gold</div></th>
#
#
#
#                 <th><div>medals.silver</div></th>
#
#
#
#                 <th><div>medals.total</div></th>
#
#
#
#                 <th><div>name</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>RUS</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>21</td>
#
#
#
#                 <td>Russian Fed.</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>USA</td>
#
#
#
#                 <td>10</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>4</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>United States</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NLD</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>Netherlands</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NOR</td>

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#e2e20452-4fea-4db9-867e-3bcaf05a4dfb").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"33331cf2-6914-4706-abbe-0e5eec012c34":{"roots":{"references":[{"attributes":{"callback":null,"start":0},"id":"c290cebb-a101-40de-8cce-6979d25a379f","type":"DataRange1d"},{"attributes":{},"id":"ceffb869-091d-4a6b-9cf9-3a97570c1849","type":"BasicTicker"},{"attributes":{"overlay":{"id":"1d05dc19-8e20-460d-8c46-3395ccbd2339","type":"BoxAnnotation"}},"id":"5abc8cef-f958-4f5a-bb9a-4a5dedb750ce","type":"BoxZoomTool"},{"attributes":{"source":{"id":"ce20a56f-dc2f-4d41-9c77-eedc9b7db65e","type":"ColumnDataSource"}},"id":"4044c69f-ec31-4d43-bc24-b3f475217110","type":"CDSView"},{"attributes":{},"id":"3619cf9b-d2e6-4fbf-92f8-f804a92e934c","type":"WheelZoomTool"},{"attributes":{},"id":"a370a394-cc02-404b-8e59-9200d74a0a44","type":"SaveTool"},{"attributes":{},"id":"0413c80c-d819-4791-8ba3-7a180665f518","type":"BasicTickFormatter"},{"attributes":{"tools":[{"id":"0d65048e-8d68-4a41-9712-1427ec7af216","type":"PanTool"},{"id":"3619cf9b-d2e6-4fbf-92f8-f804a92e934c","type":"WheelZoomTool"},{"id":"5abc8cef-f958-4f5a-bb9a-4a5dedb750ce","type":"BoxZoomTool"},{"id":"a370a394-cc02-404b-8e59-9200d74a0a44","type":"SaveTool"},{"id":"0339d9ed-1f59-4ee0-ada1-b2c6fd7cd77c","type":"ResetTool"},{"id":"f6edd206-f34d-44cb-8966-35aea3e9efb5","type":"HelpTool"}]},"id":"1ef96e5a-2287-480b-88fe-9cfb88afa955","type":"ProxyToolbar"},{"attributes":{},"id":"797339a7-4efd-43cd-b6d2-f3a90f964958","type":"BasicTickFormatter"},{"attributes":{"toolbar":{"id":"1ef96e5a-2287-480b-88fe-9cfb88afa955","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"7472585a-3a9e-487f-99ba-3cfa7f0cbb26","type":"ToolbarBox"},{"attributes":{"data_source":{"id":"ce20a56f-dc2f-4d41-9c77-eedc9b7db65e","type":"ColumnDataSource"},"glyph":{"id":"9e4d47f7-3b4b-4c25-821d-e706367484d9","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"03a72d29-2500-4c6a-9a84-f195a571c1d0","type":"Quad"},"selection_glyph":null,"view":{"id":"4044c69f-ec31-4d43-bc24-b3f475217110","type":"CDSView"}},"id":"25dc766e-b23a-4993-89c1-e03d64c0b32b","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"7472585a-3a9e-487f-99ba-3cfa7f0cbb26","type":"ToolbarBox"},{"id":"337e61ca-4129-47db-954d-a8ef410d87d7","type":"Column"}]},"id":"92c9ff0b-6917-4e05-9829-7d695c759552","type":"Column"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"9e4d47f7-3b4b-4c25-821d-e706367484d9","type":"Quad"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0d65048e-8d68-4a41-9712-1427ec7af216","type":"PanTool"},{"id":"3619cf9b-d2e6-4fbf

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#c9dbba56-ed46-4e12-bacc-156d6172d1e7").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"a3d2f050-85e6-410c-989d-cd323e8f65b4":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#7901A8"},"line_color":{"value":"#7901A8"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"b3008305-e743-4747-8300-70fb329457d9","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#380499"},"line_color":{"value":"#380499"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5a18e4c2-f93d-45dc-8b1a-d332de3386b6","type":"Circle"},{"attributes":{"label":{"value":"CAN"},"renderers":[{"id":"5f9b9637-f6ef-4885-9bc0-c23835173350","type":"GlyphRenderer"}]},"id":"c6a802c9-6476-4d28-b3ba-5a3bd5170624","type":"LegendItem"},{"attributes":{"data_source":{"id":"a0d2b8b6-e2d4-4436-8e45-09ce178a6421","type":"ColumnDataSource"},"glyph":{"id":"dddcea6e-eb89-4711-bab2-1d572078fb75","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d0dbaf7e-eff6-4988-a47f-b06f300b16d5","type":"Circle"},"selection_glyph":null,"view":{"id":"ff08fd62-1429-4bc3-bc10-2182636cd5b3","type":"CDSView"}},"id":"bf727a98-966b-4f8e-b3bc-9a273fc60a2f","type":"GlyphRenderer"},{"attributes":{},"id":"ceccd01c-ffc3-4f8b-b5da-b831cceee348","type":"SaveTool"},{"attributes":{"source":{"id":"1a981cf6-95a2-40cc-9fa4-4bc89205af07","type":"ColumnDataSource"}},"id":"25045810-568e-4f4b-8a66-73e2c07481fb","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#9612A0"},"line_color":{"value":"#9612A0"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c07978e-dcc4-40e5-ac2d-03bc0d380be8","type":"Circle"},{"attributes":{"source":{"id":"dfa67886-5166-45da-b9a2-e202aaeed2dc","type":"ColumnDataSource"}},"id":"5667b71b-6bfb-4fb0-b7d4-7a2cc7917017","type":"CDSView"},{"attributes":{"data_source":{"id":"1a981cf6-95a2-40cc-9fa4-4bc89205af07","type":"ColumnDataSource"},"glyph":{"id":"1b988730-bf36-424b-83f9-18a7d4c60008","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"30e034c9-53c1-4533-81fd-bba4124a4617","type":"Circle"},"selection_glyph":null,"view":{"id":"25045810-568e-4f4b-8a66-73e2c07481fb","type":"CDSView"}},"id":"0959b28c-fa29-4fd2-b60a-e55f0b8a18dd","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[7],"y":[2]}},"id":"dfa67886-5166-45da-b9a2-e202aaeed2dc","type":"ColumnDataSource"},{"attributes":{"source":{"id":"c63d2217-3323-4648-8165-c014399fb750","type":"ColumnDataSource"}},"id":"8ba48898-7bd9-4599-aaa3-03f67ec3e663","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#828ee055-c6ad-4fe4-af90-95bfbf015308").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"d8c22d36-8585-415e-8fc9-f39396e3291a":{"roots":{"references":[{"attributes":{},"id":"5a880c7f-305a-40f8-85ff-5bc9c370a42f","type":"SaveTool"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"919066cc-6b54-4fc0-89da-9ff981c4f8ce","type":"Line"},{"attributes":{},"id":"99332dff-8632-4811-8b49-0872007d583f","type":"BasicTickFormatter"},{"attributes":{},"id":"da659835-91d5-4c1a-b5b0-4011d1d545e4","type":"PanTool"},{"attributes":{"toolbar":{"id":"e51167fd-37f4-42d2-acf8-6938a47bfe1b","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"2bc713c4-04b0-41db-aa8e-c2664b49ee79","type":"ToolbarBox"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"c4b4dfc2-d19f-4270-b560-f58182cb8fb2","type":"Line"},{"attributes":{},"id":"26e36710-2757-4e93-80fa-b362e799be03","type":"BasicTicker"},{"attributes":{"below":[{"id":"60eac7b1-7c7f-426d-8114-a0c464f3a0dd","type":"LinearAxis"}],"left":[{"id":"b654c499-a266-49ff-a8f4-603317da7ae9","type":"LinearAxis"}],"plot_height":601,"plot_width":803,"renderers":[{"id":"60eac7b1-7c7f-426d-8114-a0c464f3a0dd","type":"LinearAxis"},{"id":"acb7973c-a3cb-436e-a0de-ab8eabfc34e3","type":"Grid"},{"id":"b654c499-a266-49ff-a8f4-603317da7ae9","type":"LinearAxis"},{"id":"1498ef49-b313-4326-be4d-a25b73b2a1e0","type":"Grid"},{"id":"aa116ccf-5b9d-4790-bb89-996baf0553ac","type":"BoxAnnotation"},{"id":"9e4f7d69-8f00-45d7-966b-6b67e74ef6fc","type":"Legend"},{"id":"0815ddc6-d7e4-44c4-af37-34da4d60788f","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"0b6300af-625c-4e62-89f1-0c18b61dc855","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"73606e76-94f2-49fa-ae4b-031ede475627","type":"DataRange1d"},"x_scale":{"id":"7ba6ff0e-1742-4ea7-a962-5f43d504e716","type":"LinearScale"},"y_range":{"id":"f7f560c6-524f-4e24-a3d0-3754f04a8348","type":"DataRange1d"},"y_scale":{"id":"36f4e747-1eb6-4e34-a1d4-0b1b4b93fd58","type":"LinearScale"}},"id":"e6735975-8eeb-4808-aeb7-90609e2b250c","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"0815ddc6-d7e4-44c4-af37-34da4d60788f","type":"GlyphRenderer"}]},"id":"1ea8e3a3-6b97-4ad6-97c0-b515cdcb306f","type":"LegendItem"},{"attributes":{"children":[{"id":"e6735975-8eeb-4808-aeb7-90609e2b250c","subtype":"Figure","type":"Plot"}]},"id":"d05a2948-4973-43f2-8be1-4acad401b1f7","type":"Row"},{"attributes":{"dimension":1,"plot":{"id":"e6735975-8eeb-4808-aeb7-90609e2b250c","subtype":"Figure","type":"Plot"},"ticker":{"id":"26e36710-2757-4e93-80fa-b362e799be03","type":"BasicTicker"}},"id":"1498ef49-b313-4326-be4d-a25b73b2a1e0","type":"Grid"},{"attributes":{"dat

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#      "<li>use INLINE resources instead, as so:</li>\n"+
#      "</ul>\n"+
#      "<code>\n"+
#      "from bokeh.resources import INLINE\n"+
#      "output_notebook(resources=INLINE)\n"+
#      "</code>\n"+
#      "</div>"}};
#
#   function display_loaded() {
#     var el = document.getElementById("");
#     if (el != null) {
#       el.textContent = "BokehJS is loading...";
#     }
#     if (root.Bokeh !== undefined) {
#       if (el != null) {
#         el.textContent = "BokehJS " + root.Bokeh.version + " successfully loaded.";
#       }
#     } else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(display_loaded, 100)
#     }
#   }
#
#
#   function run_callbacks() {
#     try {
#       root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#     }
#     finally {
#       delete root._bokeh_onload_callbacks
#     }
#     console.info("Bokeh: all callbacks have finished");
#   }
#
#   function load_libs(js_urls, callback) {
#     root._bokeh_onload_callbacks.push(callback);
#     if (root._bokeh_is_loading > 0) {
#       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#       return null;
#     }
#     if (js_urls == null || js_urls.length === 0) {
#       run_callbacks();
#       return null;
#     }
#     console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#     root._bokeh_is_loading = js_urls.length;
#     for (var i = 0; i < js_urls.length; i++) {
#       var url = js_urls[i];
#       var s = document.createElement('script');
#       s.src = url;
#       s.async = false;
#       s.onreadystatechange = s.onload = function() {
#         root._bokeh_is_loading--;
#         if (root._bokeh_is_loading === 0) {
#           console.log("Bokeh: all BokehJS libraries loaded");
#           run_callbacks()
#         }
#       };
#       s.onerror = function() {
#         console.warn("failed to load library " + url);
#       };
#       console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     }
#   };
#
#   var js_urls = ["https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.js", "https://cdn.pydata.org/bokeh/release/bokeh-gl-0.12.13.min.js"];
#
#   var inline_js = [
#     function(Bokeh) {
#       Bokeh.set_log_level("info");
#     },
#
#     function(Bokeh) {
#       Bokeh.$("#3f70a82f-d7d8-4c43-9728-95aa5abe92e0").text("BokehJS is loading...");
#     },
#     function(Bokeh) {
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.13.min.css");
#       console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#       Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-tables-0.12.13.min.css");
#     }
#   ];
#
#   function run_inline_js() {
#
#     if ((root.Bokeh !== undefined) || (force === true)) {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i].call(root, root.Bokeh);
#       }} else if (Date.now() < root._bokeh_timeout) {
#       setTimeout(run_inline_js, 100);
#     } else if (!root._bokeh_failed_load) {
#       console.log("Bokeh: BokehJS failed to load within specified timeout.");
#       root._bokeh_failed_load = true;
#     } else if (force !== true) {
#       var cell = $(document.getElementById("")).parents('.cell').data().cell;
#       cell.output_area.append_execute_result(NB_LOAD_WARNING)
#     }
#
#   }
#
#   if (root._bokeh_is_loading === 0) {
#     console.log("Bokeh: BokehJS loaded, going straight to plotting");
#     run_inline_js();
#   } else {
#     load_libs(js_urls, function() {
#       console.log("Bokeh: BokehJS plotting callback run at", now());
#       run_inline_js();
#     });
#   }
# }(window));
#                     }
#                     </script>
#
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"7c6e1a92-7945-429b-85c4-72f19960093b":{"roots":{"references":[{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"147eb46f-9307-4df5-a41c-48141aca48de","type":"FactorRange"},{"attributes":{"tools":[{"id":"5685b795-f99c-4be1-887f-bbfb90a7a67f","type":"PanTool"},{"id":"de7a77d2-a151-4f00-9601-e5284c542960","type":"WheelZoomTool"},{"id":"e7da4547-072b-4da8-9e03-aee3d7c04726","type":"BoxZoomTool"},{"id":"15634361-1db1-4d1c-940c-365f76e048ed","type":"SaveTool"},{"id":"dbd2951c-eebd-4a5e-aa3b-99df5e03a23a","type":"ResetTool"},{"id":"4ed10ca6-868d-4669-949d-8b7ba6263725","type":"HelpTool"}]},"id":"a47e3b85-c562-4c81-9ed1-fb33e3b1a031","type":"ProxyToolbar"},{"attributes":{},"id":"5685b795-f99c-4be1-887f-bbfb90a7a67f","type":"PanTool"},{"attributes":{"toolbar":{"id":"a47e3b85-c562-4c81-9ed1-fb33e3b1a031","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"ebb0184d-f88f-436e-b674-9ca36a1ee02b","type":"ToolbarBox"},{"attributes":{"data_source":{"id":"44731630-c178-4056-a676-cc5acf55884b","type":"ColumnDataSource"},"glyph":{"id":"ebafa3aa-34ad-4e83-9ca1-809c66c92ad6","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"de0088f9-eaef-4e32-a8cd-fedfaba7b68f","type":"VBar"},"selection_glyph":null,"view":{"id":"9a4b5a47-d80f-4fe1-b090-7946e665b879","type":"CDSView"}},"id":"22ce24d4-e2a5-4658-9e9f-a45b2f5bf071","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"44731630-c178-4056-a676-cc5acf55884b","type":"ColumnDataSource"},"glyph":{"id":"fcd2e29a-4b2e-40ba-9a27-ce69dafcc199","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0438796b-a221-4ff8-a609-f3e0e7e38ad1","type":"VBar"},"selection_glyph":null,"view":{"id":"308e8dfa-0da1-4798-9599-a81ff960e1d3","type":"CDSView"}},"id":"9a779f7c-78a2-4708-934d-c99504f8febb","type":"GlyphRenderer"},{"attributes":{"callback":null,"start":0},"id":"00acebc6-4a77-4fb4-be47-bc358566f081","type":"DataRange1d"},{"attributes":{"bottom":{"expr":{"id":"92eb9b90-0547-4782-a72d-08d532e21cde","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"a0944054-9588-43e2-bd4b-55700b1697c1","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"3f106b93-4262-4d2a-acbd-e813e1bb2150","type":"VBar"},{"attributes":{},"id":"e1f3dbc9-21dc-46e0-92ed-f63bc6

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-67940b82" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'abbr'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.bronze'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.gold'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.silver'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': u'medals.total'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': u'name'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-67940b82" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 26 of 26</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">abbr</div>
#
#
#
#               <div class="fixed-cell">medals.bronze</div>
#
#
#
#               <div class="fixed-cell">medals.gold</div>
#
#
#
#               <div class="fixed-cell">medals.silver</div>
#
#
#
#               <div class="fixed-cell">medals.total</div>
#
#
#
#               <div class="fixed-cell">name</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>abbr</div></th>
#
#
#
#                 <th><div>medals.bronze</div></th>
#
#
#
#                 <th><div>medals.gold</div></th>
#
#
#
#                 <th><div>medals.silver</div></th>
#
#
#
#                 <th><div>medals.total</div></th>
#
#
#
#                 <th><div>name</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>RUS</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>21</td>
#
#
#
#                 <td>Russian Fed.</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>USA</td>
#
#
#
#                 <td>10</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>4</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>United States</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NLD</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>6</td>
#
#
#
#                 <td>20</td>
#
#
#
#                 <td>Netherlands</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>NOR</td>
#
#
#
#                 <td>7</td>
#
#
#
#                 <td>8</td>
#
#
#
#                 <td>4</td>

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
