# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.7</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.1.7, Latest is 1.1.6</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure9bb4ee15" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-9bb4ee15 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-9bb4ee15" data-parent="#df-table-wrapper-9bb4ee15">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-9bb4ee15" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-9bb4ee15" data-parent="#df-table-wrapper-9bb4ee15"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-9bb4ee15" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header" style="width: 765px;">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell" style="width: 72px;">abbr</div>
#
#                 <div class="fixed-cell" style="width: 149px;">medals.bronze</div>
#
#                 <div class="fixed-cell" style="width: 130px;">medals.gold</div>
#
#                 <div class="fixed-cell" style="width: 138px;">medals.silver</div>
#
#                 <div class="fixed-cell" style="width: 131px;">medals.total</div>
#
#                 <div class="fixed-cell" style="width: 146px;">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norw

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"b54c7f22-c548-4150-9734-5a85e676f240":{"roots":{"references":[{"attributes":{"children":[{"id":"ec9f1ac5-29bd-4cce-bb86-5782a53313fb","subtype":"Figure","type":"Plot"}]},"id":"cc269c0e-3cd5-49df-ba94-cd2c72f90483","type":"Row"},{"attributes":{},"id":"3501bde4-2be6-4b94-affa-fe9a70a34d0b","type":"ResetTool"},{"attributes":{},"id":"707910a9-db4d-42bb-a948-026de698cc8a","type":"SaveTool"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"b4c21cf2-c1ce-4772-aceb-19fe1e531815","type":"Quad"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"0d8e471b-76c1-4ac6-9ff3-42189902b261","type":"BasicTickFormatter"},"plot":{"id":"ec9f1ac5-29bd-4cce-bb86-5782a53313fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e307f14-278a-4e9b-90a2-ca0cecc7c2b6","type":"BasicTicker"}},"id":"973c8643-a7f3-428b-a87c-1e14ec1931ab","type":"LinearAxis"},{"attributes":{"callback":null},"id":"1583dafb-6870-49a8-94e6-ca09bc372cac","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7fc5f563-5229-485b-b5b9-97ebba401547","type":"BoxAnnotation"},{"attributes":{"toolbar":{"id":"aab4ab59-0cbf-4d2b-bf04-2ee480a3452a","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"2047ef96-fc20-4a0c-a5d8-8a6ece466680","type":"ToolbarBox"},{"attributes":{"data_source":{"id":"8814d06c-d889-4afc-9f8e-990d78101334","type":"ColumnDataSource"},"glyph":{"id":"b4c21cf2-c1ce-4772-aceb-19fe1e531815","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fd097bc9-9943-4098-b0f1-3d48e62bdfd7","type":"Quad"},"selection_glyph":null,"view":{"id":"47d93860-0a34-4647-b813-6ddadb32f0a3","type":"CDSView"}},"id":"e3555cf3-9f56-4a30-bc86-3434cebe76fc","type":"GlyphRenderer"},{"attributes":{},"id":"918e0465-0301-4c7f-a04d-5f80d16358c0","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"2081a57f-aa02-4660-a4b5-782a47179656","type":"Title"},{"attributes":{"tools":[{"id":"a398770c-2536-45b1-9425-1297c7dd1814","type":"PanTool"},{"id":"918e0465-0301-4c7f-a04d-5f80d16358c0","type":"WheelZoomTool"},{"id":"21c00da5-da51-4cae-bfd6-cd164e9dd9ad","type":"BoxZoomTool"},{"id":"707910a9-db4d-42bb-a948-026de698cc8a","type":"SaveTool"},{"id":"3501bde4-2be6-4b94-affa-fe9a70a34d0b","type":"ResetTool"},{"id":"0da752c4-0b51-49e7-bdb0-c62556f1bb24","type":"HelpTool"}]},"id":"aab4ab59-0cbf-4d2b-bf04-2ee480a3452a","type":"ProxyToolbar"},{"attributes":{},"id":"0da752c4-0b51-49e7-bdb0-c62556f1bb24","type":"HelpTool"},{"attributes":{"below":[{"id":"973c8643-a7f3-428b-a87c-1e14ec1931ab","type":"LinearAxis"}],"left":[{"id":"cac5b44b-005d-43fd-b59c-9968fc8b0c73","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"973c8643-a7f3-428b-a87c-1e14ec1931ab","type":"LinearAxis"},{"id":"3e1c9871-0008-4497-a36e-7066395f2e75","type":"Grid"},{"id":"cac5b44b-005d-43fd-b59c-9968fc8b0c73","type":"LinearAxis"},{"id":"95221d51-9d56-46f6-9fd9-206ebcc53178","type":"Grid"},{"id":"7fc5f563-5229-485b-b5b9-97ebba401547","type":"BoxAnnotation"},{"id":"e3555cf3-9f56-4a30-bc86-3434cebe76fc","type":"GlyphRenderer"}],"title":{"id":"2081a57f-aa02-4660-a4b5-782a47179656","type":"Title"},"toolbar":{"id":"71143262-1bac-47f0-8f29-8fd3654bdacd","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"1583dafb-6870-49a8-94e6-ca09bc372cac","type":"DataRange1d"},"x_scale":{"id":"9e9c5572-c0b8-4f11-a456-800568efa9d6","type":"LinearScale"},"y_range":{"id":"2e096654-1bbf-4c99-b677-43be6b139523","type":"DataRange1d"},"y_scale":{"id":"de5a7794-41d4-4cfa-87fd-d531a2f26bfa","type":"LinearScale"}},"id":"ec9f1ac5-29bd-4cce-bb86-5782a53313fb ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='scatterPlot',rendererId='bokeh',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',color='abbr',nostore_cw='1098',nostore_bokeh='true',prefix='38576d55')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-38576d55")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"b75863a1-df17-421d-9db5-9e3c3a7636ca":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#B02A8F"},"line_color":{"value":"#B02A8F"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"897c07e3-4c47-45db-887f-072d0c07c674","type":"Circle"},{"attributes":{"axis_label":"medals.total","formatter":{"id":"7618c152-5b88-4a42-bf20-f1819414a2ae","type":"BasicTickFormatter"},"plot":{"id":"4af5f2e7-41b6-4bfa-9ccc-afb1e50cdde9","subtype":"Figure","type":"Plot"},"ticker":{"id":"8b488906-d0a9-4d48-9b8e-71c01b359822","type":"BasicTicker"}},"id":"6352b3dc-91db-4790-97b5-a4b355888cbf","type":"LinearAxis"},{"attributes":{"label":{"value":"BLR"},"renderers":[{"id":"dd6cacc3-2288-421a-86fb-93c577fd04d7","type":"GlyphRenderer"}]},"id":"25d6083a-1b10-454a-ae55-2cedaf9c9dc4","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa8c3df1-245e-4c4d-be4f-f752e147eaf9","type":"Circle"},{"attributes":{"data_source":{"id":"3dd34017-8a8e-41b2-9cf6-4124111e82a8","type":"ColumnDataSource"},"glyph":{"id":"bec88126-3234-4bcc-9f7a-d848335d1687","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6b5855f6-ca12-4072-85f8-adc49e16df7a","type":"Circle"},"selection_glyph":null,"view":{"id":"aa0c3fa3-16a4-4180-8b13-970c49cfc6b0","type":"CDSView"}},"id":"9a675e03-b505-4b14-9857-9a7cef429f50","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3],"y":[0]}},"id":"3f145e24-800d-41a8-8c5f-af658bec24bd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"8ca2a97f-7056-40b1-861a-901d32669546","type":"Circle"},{"attributes":{"source":{"id":"3c3a5d08-daf8-4288-a104-4739222276ee","type":"ColumnDataSource"}},"id":"f4d316b9-a8d8-4e11-a147-a3147bdef0e8","type":"CDSView"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[7],"y":[1]}},"id":"1e44c3af-3b0e-4c91-9a12-26f66352b219","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3c4b56e6-1915-4a15-a368-79ca78c38c95","type":"ColumnDataSource"},"glyph":{"id":"1f646ad8-ac79-4155-8b32-2041c8da1925","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bad36666-b2d7-4de2-825c-71ed108b7fd8","type":"Circle"},"selection_glyph":null,"view":{"id":"42773228-aae2-4e83-bc9e-89ab32584fd0","type":"CDSView"}},"id":"c4913560-9e5c-4a4f-aa9a-1e99f06060de","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"db0b15f7-e915-4588-bf11-7b9ce61923a6","type":"Circle"},{"attributes":{"label":{"value":"CHE"},"renderers":[{"id":"049d4c11-9782-4212-a651-a6c31c2ff262","type":"GlyphRenderer"}]},"id":"709e8d58-66c2-4543-b45f-e60497e0ff72","type":"LegendItem"},{"attributes":{"source":{"id":"79880347-ab40-4631-978b-bf302eb38953","type":"ColumnDataSource"}},"id":"ccedd484-8b8d-435a-a602-18b2097888b0","type":"CDSView"},{"attributes":{"source":{"id":"22174205-8c74-4160-9820-90c4445aae06","type":"ColumnDataSource"}},"id":"0e4bc3ef-ee6d-4a5a-948f-ec71cf5f7b77","type":"CDSView"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[15],"y":[8]}},"id":"1c75408a-1ddc-4709-a2b9-8399c151b5cb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#5901A4"},"line_color":{"value":"#5901A4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc89313a-70e8-41ee-8dd2-768e8c4c3e84","type":"Circle"},{"attributes":{"data_source":{"id":"1c75 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='lineChart',rendererId='bokeh',keyFields='medals.silver',nostore_figureOnly='true',valueFields='medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',nostore_cw='1098',nostore_bokeh='true',prefix='4725710e')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-4725710e")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"1bb3cb22-e76d-4c78-90ec-6f7208f68afe":{"roots":{"references":[{"attributes":{"below":[{"id":"58553f41-de52-4656-9911-c2b762229927","type":"LinearAxis"}],"left":[{"id":"ebdc022c-5487-4dfc-99d9-14d0dd21fa5c","type":"LinearAxis"}],"plot_height":495,"plot_width":803,"renderers":[{"id":"58553f41-de52-4656-9911-c2b762229927","type":"LinearAxis"},{"id":"46b427f9-ad1e-4a80-8d13-310bbb2973db","type":"Grid"},{"id":"ebdc022c-5487-4dfc-99d9-14d0dd21fa5c","type":"LinearAxis"},{"id":"44e207e5-3242-46a8-8619-587017efa0ae","type":"Grid"},{"id":"3872691e-b368-4489-ba2a-bffde0f49219","type":"BoxAnnotation"},{"id":"ca6b865c-ab37-4e68-80b7-b865fec19d9e","type":"Legend"},{"id":"e4a041ce-f19e-4438-bf35-5e3f4fabb115","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"952c5d19-a5f5-42c3-98ba-8cc6d329e8ec","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"11048d1a-8e08-4fd7-b341-b9885c8f8199","type":"DataRange1d"},"x_scale":{"id":"3f2eee86-5a3e-476c-b8be-15d0ba8ff80e","type":"LinearScale"},"y_range":{"id":"7f0c3147-b8a3-471d-ad2f-092da1778431","type":"DataRange1d"},"y_scale":{"id":"b4d8b026-83a5-4490-96a2-4bee4304deac","type":"LinearScale"}},"id":"07b7a786-61f4-43d8-ae7f-52a8aa076d57","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3872691e-b368-4489-ba2a-bffde0f49219","type":"BoxAnnotation"},{"attributes":{},"id":"0676511a-f9b2-4181-9860-eba8e4e2d6e7","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"179c4248-940f-4ac5-b9a6-af29cf5cab08","type":"PanTool"},{"id":"1729df45-81be-4f2b-988f-d265274e6c6c","type":"WheelZoomTool"},{"id":"6e811e23-51a8-4b77-9e94-cf5ce9f5d9de","type":"BoxZoomTool"},{"id":"db0b7daa-469f-44ef-802c-1992a1634f84","type":"SaveTool"},{"id":"0676511a-f9b2-4181-9860-eba8e4e2d6e7","type":"ResetTool"},{"id":"1f6c6b23-8ae5-4a3d-babf-dd27e2d553af","type":"HelpTool"}]},"id":"952c5d19-a5f5-42c3-98ba-8cc6d329e8ec","type":"Toolbar"},{"attributes":{"label":{"value":"medals.gold"},"renderers":[{"id":"e4a041ce-f19e-4438-bf35-5e3f4fabb115","type":"GlyphRenderer"}]},"id":"ae69af6e-a678-4961-ba7a-637e6adc686f","type":"LegendItem"},{"attributes":{"plot":{"id":"07b7a786-61f4-43d8-ae7f-52a8aa076d57","subtype":"Figure","type":"Plot"},"ticker":{"id":"90a36220-fae8-4c36-b6be-0d56350793b3","type":"BasicTicker"}},"id":"46b427f9-ad1e-4a80-8d13-310bbb2973db","type":"Grid"},{"attributes":{"tools":[{"id":"179c4248-940f-4ac5-b9a6-af29cf5cab08","type":"PanTool"},{"id":"1729df45-81be-4f2b-988f-d265274e6c6c","type":"WheelZoomTool"},{"id":"6e811e23-51a8-4b77-9e94-cf5ce9f5d9de","type":"BoxZoomTool"},{"id":"db0b7daa-469f-44ef-802c-1992a1634f84","type":"SaveTool"},{"id":"0676511a-f9b2-4181-9860-eba8e4e2d6e7","type":"ResetTool"},{"id":"1f6c6b23-8ae5-4a3d-babf-dd27e2d553af","type":"HelpTool"}]},"id":"b261e2e9-e027-4500-9d33-ac96c3a1e433","type":"ProxyToolbar"},{"attributes":{"dimension":1,"plot":{"id":"07b7a786-61f4-43d8-ae7f-52a8aa076d57","subtype":"Figure","type":"Plot"},"ticker":{"id":"705287fa-18b2-4386-b820-107a17763f42","type":"BasicTicker"}},"id":"44e207e5-3242-46a8-8619-587017efa0ae","type":"Grid"},{"attributes":{"axis_label":"medals.gold","formatter":{"id":"5d175949-e9bd-4a5b-91f1-c0f87869404c","type":"BasicTickFormatter"},"plot":{"id":"07b7a786-61f4-43d8-ae7f-52a8aa076d57","subtype":"Figure","type":"Plot"},"ticker":{"id":"705287fa-18b2-4386-b820-107a17763f42","type":"BasicTicker"}},"id":"ebdc022c-5487-4dfc-99d9-14d0dd21fa5c","type":"LinearAxis"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"72d99073-058c-4c6c-b7e2-0f7ca9d07e4f","type":"Line"},{"attributes":{"callback":null},"id ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"e3131278-251a-4539-87f1-d758915ab561":{"roots":{"references":[{"attributes":{"fields":["medals.bronze"]},"id":"77c2d536-88c5-4ddf-93ce-60a4208d7537","type":"Stack"},{"attributes":{"fields":["medals.bronze"]},"id":"fcedac9b-90bb-47ce-aefe-bec0e05cf9ce","type":"Stack"},{"attributes":{"fields":["medals.bronze","medals.silver","medals.gold"]},"id":"3a6675da-e541-440a-9728-f38605d873e9","type":"Stack"},{"attributes":{"data_source":{"id":"1d4046c7-c58f-46e0-a0bc-fafac88ede46","type":"ColumnDataSource"},"glyph":{"id":"8b04829a-f763-4a18-92e7-2f9dda374e2f","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"63651aa8-946e-4d24-8a64-6d77c4a9a60a","type":"VBar"},"selection_glyph":null,"view":{"id":"9641ad5f-d84d-4a0d-a31d-be312ad12c62","type":"CDSView"}},"id":"e0c720f5-c2f9-4fdd-b668-6323d0cdeac6","type":"GlyphRenderer"},{"attributes":{"callback":null,"start":0},"id":"3fd4cb95-856b-46cd-8cc1-5814b0522abd","type":"DataRange1d"},{"attributes":{"source":{"id":"1d4046c7-c58f-46e0-a0bc-fafac88ede46","type":"ColumnDataSource"}},"id":"121cc506-c093-4cb5-ab44-ea63fc327bfa","type":"CDSView"},{"attributes":{},"id":"e8994552-c169-4556-9652-f5e87aa71426","type":"CategoricalScale"},{"attributes":{"source":{"id":"1d4046c7-c58f-46e0-a0bc-fafac88ede46","type":"ColumnDataSource"}},"id":"5830e66b-be3c-4e16-8696-2fcf9b6cdca2","type":"CDSView"},{"attributes":{"source":{"id":"1d4046c7-c58f-46e0-a0bc-fafac88ede46","type":"ColumnDataSource"}},"id":"9641ad5f-d84d-4a0d-a31d-be312ad12c62","type":"CDSView"},{"attributes":{"dimension":1,"plot":{"id":"b888d62b-872d-4d18-abbd-5d210b03c93b","subtype":"Figure","type":"Plot"},"ticker":{"id":"be039539-fa1a-4eac-9d6d-865a1e3fb00e","type":"BasicTicker"}},"id":"b3c1c22e-f169-4080-b72d-523bb6b323ad","type":"Grid"},{"attributes":{"below":[{"id":"df0680c8-836c-4500-8eaa-36a59f728d95","type":"CategoricalAxis"}],"left":[{"id":"5752c2c8-b995-498d-926e-d480021bca52","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":495,"plot_width":803,"renderers":[{"id":"df0680c8-836c-4500-8eaa-36a59f728d95","type":"CategoricalAxis"},{"id":"8bde458e-a021-4d55-b540-43c1f60a36f2","type":"Grid"},{"id":"5752c2c8-b995-498d-926e-d480021bca52","type":"LinearAxis"},{"id":"b3c1c22e-f169-4080-b72d-523bb6b323ad","type":"Grid"},{"id":"e1ebacfe-93f9-4c63-afa9-4da5dbc6f188","type":"BoxAnnotation"},{"id":"2ba9dc4e-e2a0-47b2-8030-496a05a618b6","type":"Legend"},{"id":"0f1655c2-76f5-46b9-a29c-71b6e1a02ddd","type":"GlyphRenderer"},{"id":"e0c720f5-c2f9-4fdd-b668-6323d0cdeac6","type":"GlyphRenderer"},{"id":"cd68d0b4-fc03-4f67-ab9b-0c07d3eb7fb7","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"2e54efc2-e845-43dd-b4bd-3b07ef35041e","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"b01c0244-8e38-4c58-a79f-2465b0d3b873","type":"FactorRange"},"x_scale":{"id":"e8994552-c169-4556-9652-f5e87aa71426","type":"CategoricalScale"},"y_range":{"id":"3fd4cb95-856b-46cd-8cc1-5814b0522abd","type":"DataRange1d"},"y_scale":{"id":"a4dbfcc0-e612-4236-8bb6-041082ef0bcf","type":"LinearScale"}},"id":"b888d62b-872d-4d18-abbd-5d210b03c93b","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"factors":["Australia","Austria","Belarus","Canada","China","Croatia","Czech Republic","Finland","France","Germany","Great Britain","Italy","Japan","Kazakhstan","Korea","Latvia","Netherlands","Norway","Poland","Russian Fed.","Slovakia","Slovenia","Sweden","Switzerland","Ukraine","United States"],"range_padding":0.1},"id":"b01c0244-8e38-4c58-a79f-2465b0d3b873","type":"FactorRange"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e1ebacfe-93f9-4c63-afa9-4da5dbc6f188","type":"BoxAnnotation"},{"attributes":{},"id":"a370d528-71f9-4e67 ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td>

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
