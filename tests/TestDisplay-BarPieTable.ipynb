# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
# Table VERSION_TRACKER created successfully
# Table METRICS_TRACKER created successfully
#
# Share anonymous install statistics? (opt-out instructions)
#
# PixieDust will record metadata on its environment the next time the package is installed or updated. The data is anonymized and aggregated to help plan for future releases, and records only the following values:
#
# {
#    "data_sent": currentDate,
#    "runtime": "python",
#    "application_version": currentPixiedustVersion,
#    "space_id": nonIdentifyingUniqueId,
#    "config": {
#        "repository_id": "https://github.com/ibm-watson-data-lab/pixiedust",
#        "target_runtimes": ["Data Science Experience"],
#        "event_id": "web",
#        "event_organizer": "dev-journeys"
#    }
# }
# You can opt out by calling pixiedust.optOut() in a new cell.
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>
# Pixiedust runtime updated. Please restart kernel
# Table SPARK_PACKAGES created successfully
# Table USER_PREFERENCES created successfully
# Table service_connections created successfully
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.1.18, Latest is 1.1.17</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %%
data = [(2010, 'Camping Equipment', 3),
    (2010, 'Golf Equipment', 1),
    (2010, 'Mountaineering Equipment', 1),
    (2010, 'Outdoor Protection', 2),
    (2010, 'Personal Accessories', 2),
    (2011, 'Camping Equipment', 4),
    (2011, 'Golf Equipment', 5),
    (2011, 'Mountaineering Equipment',2),
    (2011, 'Outdoor Protection', 4),
    (2011, 'Personal Accessories', 2),
    (2012, 'Camping Equipment', 5),
    (2012, 'Golf Equipment', 5),
    (2012, 'Mountaineering Equipment', 3),
    (2012, 'Outdoor Protection', 5),
    (2012, 'Personal Accessories', 3),
    (2013, 'Camping Equipment', 8),
    (2013, 'Golf Equipment', 5),
    (2013, 'Mountaineering Equipment', 3),
    (2013, 'Outdoor Protection', 8),
    (2013, 'Personal Accessories', 4)]

columns = ["year","zone","unique_customers"]

# %%
#TARGET=SPARK
sqlContext = SQLContext(sc)
dd = sqlContext.createDataFrame( data, columns)
dd.count()
# Out:
# 20

# %%
#TARGET=PLAIN
import pandas
dd = pandas.DataFrame( data, columns=columns )

# %%
#SKIP_COMPARE_OUTPUT
display(dd, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureab3ed5a3" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#
#   <div class="df-table-wrapper df-table-wrapper-ab3ed5a3 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-ab3ed5a3" data-parent="#df-table-wrapper-ab3ed5a3">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-ab3ed5a3" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>year: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>zone: </strong> object</div>
#
#               <div class="df-schema-field"><strong>unique_customers: </strong> int64</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-ab3ed5a3" data-parent="#df-table-wrapper-ab3ed5a3"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-ab3ed5a3" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 20 of 20 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">year</div>
#
#                 <div class="fixed-cell">zone</div>
#
#                 <div class="fixed-cell">unique_customers</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>year</div></th>
#
#                   <th><div>zone</div></th>
#
#                   <th><div>unique_customers</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>2010</td>
#
#                   <td>Camping Equipment</td>
#
#                   <td>3</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2010</td>
#
#                   <td>Golf Equipment</td>
#
#                   <td>1</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2010</td>
#
#                   <td>Mountaineering Equipment</td>
#
#                   <td>1</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2010</td>
#
#                   <td>Outdoor Protection</td>
#
#                   <td>2</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2010</td>
#
#                   <td>Personal Accessories</td>
#
#                   <td>2</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2011</td>
#
#                   <td>Camping Equipment</td>
#
#                   <td>4</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2011</td>
#
#                   <td>Golf Equipment</td>
#
#                   <td>5</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2011</td>
#
#                   <td>Mountaineering Equipment</td>
#
#                   <td>2</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2011</td>
#
#                   <td>Outdoor Protection</td>
#
#                   <td>4</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>2011</td>
#
#                   <td>Personal Accessories</td

# %%
display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='pieChart',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='ae087e77')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.options.defaultOptions.DefaultOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_ae087e77">
#             <pd_event_handler pd_source="option_btn_ae087e77" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#rendererae087e77").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTMLae087e77');
#         if (n.length == 0 ){
#             n = $('#wrapperHTMLae087e77');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="2850507A33444756801B43A74E3E6A56".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#executionae087e77");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#executionae087e77").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#executionae087e77").length > 0 ){
#                     $("#executionae087e77").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDoneae087e77 != "undefined"){
#                     onDisplayDoneae087e77();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='pieChart',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='ae087e77')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){

# %%
display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='barChart',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='2e7ed979')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.options.defaultOptions.DefaultOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_2e7ed979">
#             <pd_event_handler pd_source="option_btn_2e7ed979" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#         <label class="field">Renderer:</label>
#         <select class="form-control" id="renderer2e7ed979" style="margin:0; display:inline-block; width:70%;">
#
#                 <option value="matplotlib" selected>matplotlib</option>
#
#                 <option value="bokeh" >bokeh</option>
#
#         </select>
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderer2e7ed979").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML2e7ed979');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML2e7ed979');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="2850507A33444756801B43A74E3E6A56".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution2e7ed979");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#execution2e7ed979").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#execution2e7ed979").length > 0 ){
#                     $("#execution2e7ed979").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDone2e7ed979 != "undefined"){
#                     onDisplayDone2e7ed979();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='barChart',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='2e7ed979')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});

# %%
import pandas
d = {'col1': [None, 2, 1, 7, 1], 'col2': [6, None, 5, 9, 3], 'col3': ['ice cream', 'cookies', None, 'cake', 'pie']}
pdf2 = pandas.DataFrame(data=d)
pdf2.shape[0]
# Out:
# 5

# %%
display(pdf2,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='All',org_params='nostore_pixiedust',prefix='4046ac43',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.renderers.table.tableOptions.TableOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_4046ac43">
#             <pd_event_handler pd_source="option_btn_4046ac43" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderer4046ac43").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML4046ac43');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML4046ac43');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="20499543AE4446FAA9707357577DE951".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution4046ac43");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#execution4046ac43").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#execution4046ac43").length > 0 ){
#                     $("#execution4046ac43").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDone4046ac43 != "undefined"){
#                     onDisplayDone4046ac43();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(pdf2,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='All',org_params='nostore_pixiedust',prefix='4046ac43',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){
#             var parts = n[i].split("=")
#             callbacks.options[parts[0].trim()] = parts[1].trim();

# %%
display(pdf2,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Missing values',org_params='nostore_pixiedust',prefix='446b0b5f',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.renderers.table.tableOptions.TableOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_446b0b5f">
#             <pd_event_handler pd_source="option_btn_446b0b5f" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderer446b0b5f").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML446b0b5f');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML446b0b5f');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="20499543AE4446FAA9707357577DE951".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution446b0b5f");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#execution446b0b5f").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#execution446b0b5f").length > 0 ){
#                     $("#execution446b0b5f").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDone446b0b5f != "undefined"){
#                     onDisplayDone446b0b5f();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(pdf2,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Missing values',org_params='nostore_pixiedust',prefix='446b0b5f',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){
#             var parts = n[i].split("=")
#             callbacks.options[parts[0].trim()] = parts[1].trim(

# %%
display(pdf2,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Not missing values',org_params='nostore_pixiedust',prefix='0923d868',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.renderers.table.tableOptions.TableOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_0923d868">
#             <pd_event_handler pd_source="option_btn_0923d868" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderer0923d868").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML0923d868');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML0923d868');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="20499543AE4446FAA9707357577DE951".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution0923d868");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#execution0923d868").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#execution0923d868").length > 0 ){
#                     $("#execution0923d868").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDone0923d868 != "undefined"){
#                     onDisplayDone0923d868();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(pdf2,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Not missing values',org_params='nostore_pixiedust',prefix='0923d868',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){
#             var parts = n[i].split("=")
#             callbacks.options[parts[0].trim()] = parts[1].t

# %%
#TARGET=SPARK
d = [(1, 3, 'pie'), (None, 6, 'ice cream'), (2, None, 'cookies'), (1, 5, None), (7, 9, 'cake')]
pdf = sqlContext.createDataFrame(d, ['col1', 'col2', 'col3'])
pdf.count()
# Out:
# 5

# %%
#TARGET=SPARK
display(pdf,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Not missing values',org_params='nostore_pixiedust',prefix='a148c8f6',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.renderers.table.tableOptions.TableOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_a148c8f6">
#             <pd_event_handler pd_source="option_btn_a148c8f6" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderera148c8f6").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTMLa148c8f6');
#         if (n.length == 0 ){
#             n = $('#wrapperHTMLa148c8f6');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="20499543AE4446FAA9707357577DE951".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#executiona148c8f6");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#executiona148c8f6").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#executiona148c8f6").length > 0 ){
#                     $("#executiona148c8f6").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDonea148c8f6 != "undefined"){
#                     onDisplayDonea148c8f6();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(pdf,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Not missing values',org_params='nostore_pixiedust',prefix='a148c8f6',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){
#             var parts = n[i].split("=")
#             callbacks.options[parts[0].trim()] = parts[1].tr

# %%
#TARGET=SPARK
display(pdf,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Missing values',org_params='nostore_pixiedust',prefix='a4c4be27',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.renderers.table.tableOptions.TableOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_a4c4be27">
#             <pd_event_handler pd_source="option_btn_a4c4be27" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderera4c4be27").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTMLa4c4be27');
#         if (n.length == 0 ){
#             n = $('#wrapperHTMLa4c4be27');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="20499543AE4446FAA9707357577DE951".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#executiona4c4be27");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#executiona4c4be27").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#executiona4c4be27").length > 0 ){
#                     $("#executiona4c4be27").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDonea4c4be27 != "undefined"){
#                     onDisplayDonea4c4be27();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(pdf,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',table_showrows='Missing values',org_params='nostore_pixiedust',prefix='a4c4be27',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){
#             var parts = n[i].split("=")
#             callbacks.options[parts[0].trim()] = parts[1].trim()

# %%
#TARGET=SPARK
display(pdf,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',org_params='nostore_pixiedust',prefix='49fe4045',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#
#         <button pd_app="pixiedust.display.chart.renderers.table.tableOptions.TableOptions"
#             class="btn btn-default no_loading_msg"
#             pd_options="runInDialog=true"
#             id="option_btn_49fe4045">
#             <pd_event_handler pd_source="option_btn_49fe4045" pd_script="ShellAccess[eventInfo['entity']].on_ok()"></pd_event_handler>
#             Options
#         </button>
#
#
#
#         <button pd_app="pixiedust.apps.gateway.share.ShareChartApp"
#                 pd_options="runInDialog=true;title=Share Chart"
#                 class="btn btn-default no_loading_msg">
#             Share
#         </button>
#     </div>
#
#     <div class="form-group col-sm-3">
#
#     </div>
#
# </div>
#
# <script>
#
#
# $("#renderer49fe4045").change(function(){
#     var rendererId = $(this).val();
#
#
#
#     !
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML49fe4045');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML49fe4045');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="20499543AE4446FAA9707357577DE951".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     //curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution49fe4045");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         if (pixiedust){
#                             if (callbacks.options && callbacks.options.nostore_delaysave){
#                                 setTimeout(function(){
#                                     pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                                 }, 1000);
#                             }else{
#                                 pixiedust.saveOutputInCell(curCell, content, html, msg_type);
#                             }
#                         }
#
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#execution49fe4045").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#execution49fe4045").length > 0 ){
#                     $("#execution49fe4045").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDone49fe4045 != "undefined"){
#                     onDisplayDone49fe4045();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNode: getTargetNode()});
#             }
#         }
#     }
#
#     if (IPython && IPython.notebook && IPython.notebook.session && IPython.notebook.session.kernel){
#         var command = "display(pdf,nostore_bokeh='false',cell_id='20499543AE4446FAA9707357577DE951',org_params='nostore_pixiedust',prefix='49fe4045',nostore_cw='1098',handlerId='tableView',nostore_vh='1050',nostore_pixiedust='true')".replace("cellId",cellId);
#         function addOptions(options, override=true){
#             function getStringRep(v) {
#                 return "'" + v + "'";
#             }
#             for (var key in (options||{})){
#                 var value = options[key];
#                 var hasValue = value != null && typeof value !== 'undefined' && value !== '';
#                 var replaceValue = hasValue ? (key+"=" + getStringRep(value) ) : "";
#                 var pattern = (hasValue?"":",")+"\\s*" + key + "\\s*=\\s*'(\\\\'|[^'])*'";
#                 var rpattern=new RegExp(pattern);
#                 var n = command.search(rpattern);
#                 if ( n >= 0 ){
#                     if (override){
#                         command = command.replace(rpattern, replaceValue);
#                     }
#                 }else if (hasValue){
#                     var n = command.lastIndexOf(")");
#                     command = [command.slice(0, n), (command[n-1]=="("? "":",") + replaceValue, command.slice(n)].join('')
#                 }
#             }
#         }
#         if(typeof cellMetadata != "undefined" && cellMetadata.displayParams){
#             addOptions(cellMetadata.displayParams);
#         }else if (curCell && curCell._metadata.pixiedust ){
#             addOptions(curCell._metadata.pixiedust.displayParams || {}, ('True'=='True') );
#         }
#         addOptions({});
#
#
#
#         addOptions({"rendererId": rendererId });
#
#
#
#         var pattern = "\\w*\\s*=\\s*'(\\\\'|[^'])*'";
#         var rpattern=new RegExp(pattern,"g");
#         var n = command.match(rpattern);
#
#         var org_params = {}
#         callbacks.options = callbacks.options || {};
#         for (var i=0; i<n.length;i++){
#             var parts = n[i].split("=")
#             callbacks.options[parts[0].trim()] = parts[1].trim();
#             if (parts[0].trim(
