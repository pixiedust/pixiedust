# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.0.6</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.0.6, Latest is 1.0.5</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %%
data = [(2010, 'Camping Equipment', 3),
    (2010, 'Golf Equipment', 1),
    (2010, 'Mountaineering Equipment', 1),
    (2010, 'Outdoor Protection', 2),
    (2010, 'Personal Accessories', 2),
    (2011, 'Camping Equipment', 4),
    (2011, 'Golf Equipment', 5),
    (2011, 'Mountaineering Equipment',2),
    (2011, 'Outdoor Protection', 4),
    (2011, 'Personal Accessories', 2),
    (2012, 'Camping Equipment', 5),
    (2012, 'Golf Equipment', 5),
    (2012, 'Mountaineering Equipment', 3),
    (2012, 'Outdoor Protection', 5),
    (2012, 'Personal Accessories', 3),
    (2013, 'Camping Equipment', 8),
    (2013, 'Golf Equipment', 5),
    (2013, 'Mountaineering Equipment', 3),
    (2013, 'Outdoor Protection', 8),
    (2013, 'Personal Accessories', 4)]

columns = ["year","zone","unique_customers"]

# %%
#TARGET=SPARK
dd = sqlContext.createDataFrame( data, columns)
dd.count()
# Out:
# 20

# %%
#TARGET=PLAIN
import pandas
dd = pandas.DataFrame( data, columns=columns )

# %%
#SKIP_COMPARE_OUTPUT
display(dd, no_gen_tests='true')
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;e6288c1c&quot;, &quot;command&quot;: &quot;display(dd, no_gen_tests=&apos;true&apos;,cell_id=&apos;A889190C3A1A40C6B472AD69A82377CB&apos;,nostore_pixiedust=&apos;true&apos;,showLegend=&apos;true&apos;,stacked=&apos;true&apos;,staticFigure=&apos;false&apos;,aggregation=&apos;SUM&apos;,rowCount=&apos;100&apos;,handlerId=&apos;dataframe&apos;,valueFields=&apos;unique_customers&apos;,rendererId=&apos;matplotlib&apos;,keyFields=&apos;zone&apos;,nostore_cw=&apos;1098&apos;,org_params=&apos;no_gen_tests,nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;options&quot;: {&quot;nostore_bokeh&quot;: &quot;false&quot;, &quot;showLegend&quot;: &quot;true&quot;, &quot;cell_id&quot;: &quot;A889190C3A1A40C6B472AD69A82377CB&quot;, &quot;stacked&quot;: &quot;true&quot;, &quot;org_params&quot;: &quot;no_gen_tests,nostore_pixiedust&quot;, &quot;staticFigure&quot;: &quot;false&quot;, &quot;aggregation&quot;: &quot;SUM&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;rowCount&quot;: &quot;100&quot;, &quot;handlerId&quot;: &quot;dataframe&quot;, &quot;valueFields&quot;: &quot;unique_customers&quot;, &quot;rendererId&quot;: &quot;matplotlib&quot;, &quot;no_gen_tests&quot;: &quot;true&quot;, &quot;keyFields&quot;: &quot;zone&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;showchrome&quot;: &quot;true&quot;}}">
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-e6288c1c" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#   <div id="pixiedust-output-wrapper-e6288c1c" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menue6288c1c-dataframe" title="DataFrame Table">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menue6288c1c-dataframe').on('click',
#
#
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTMLe6288c1c');
#         if (n.length == 0 ){
#             n = $('#wrapperHTMLe6288c1c');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="A889190C3A1A40C6B472AD69A82377CB".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#executione6288c1c");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#
#                         if(curCell&&curCell.output_area&&curCell.output_area.outputs){
#                             setTimeout(function(){
#                                 var data = JSON.parse(JSON.stringify(content.data));
#                                 if(!!data["text/html"])data["text/html"]=html;
#                                 function savedData(data){
#
#                                     var markup='<style type="text/css">.pd_warning{display:none;}</style>';
#                                     markup+='<div class="pd_warning"><em>Hey, there\'s something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>';
#                                     nodes = $.parseHTML(data["text/html"], null, true);
#                                     var s = $(nodes).wrap("<div>").parent().find(".pd_save").not(".pd_save .pd_save")
#                                     s.each(function(){
#                                         var found = false;
#                                         if ( $(this).attr("id") ){
#                                             var n = $("#" + $(this).attr("id"));
#                                             if (n.length>0){
#                                                 found=true;
#                                                 n.each(function(){
#                                                     $(this).addClass("is-viewer-good");
#                                                 });
#                                                 markup+=n.wrap("<div>").parent().html();
#                                             }
#                                         }else{
#                                             $(this).addClass("is-viewer-good");
#                                         }
#                                         if (!found){
#                                             markup+=$(this).parent().html();
#                                         }
#                                     });
#                                     data["text/html"] = markup;
#                                     return data;
#                                 }
#                                 curCell.output_area.outputs.push({"data": savedData(data),"metadata":content.metadata,"output_type":msg_type});
#                             },2000);
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-e6288c1c panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-e6288c1c" data-parent="#df-table-wrapper-e6288c1c">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-e6288c1c" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'year'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': 'zone'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'unique_customers'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-e6288c1c" data-parent="#df-table-wrapper-e6288c1c">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-e6288c1c" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 20 of 20</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">year</div>
#
#
#
#               <div class="fixed-cell">zone</div>
#
#
#
#               <div class="fixed-cell">unique_customers</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>year</div></th>
#
#
#
#                 <th><div>zone</div></th>
#
#
#
#                 <th><div>unique_customers</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Camping Equipment</td>
#
#
#
#                 <td>3</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Golf Equipment</td>
#
#
#
#                 <td>1</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Mountaineering Equipment</td>
#
#
#
#                 <td>1</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Outdoor Protection</td>
#
#
#
#                 <td>2</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Personal Accessories</td>
#
#
#
#                 <td>2</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Camping Equipment</td>
#
#
#
#                 <td>4</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Golf Equipment</td>
#
#
#
#                 <td>5</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Mountaineering Equipment</td>
#
#
#
#                 <td>2</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>

# %%
display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='pieChart',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='ae087e77')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#         <button id="mapOptionsae087e77" class="btn btn-default">Options</button>
#
#     </div>
#
#     <div class="form-group col-sm-3">
#         <label class="field">Renderer:</label>
#         <select class="form-control" id="rendererae087e77" style="margin:0; display:inline-block; width:70%;">
#
#                 <option value="matplotlib" selected>matplotlib</option>
#
#         </select>
#     </div>
#
# </div>
#
# <script>
# $("#mapOptionsae087e77").click(function(){
#
#     var global={}
#
# require(['base/js/dialog'],function(dialog){
#     var modal = dialog.modal;
#     var options = {
#         title: "Pixiedust: Pie Chart Options",
#         body: '<form id="chartOptionsae087e77"><style type="text/css">	.field-container {	}	.field-container ul {		overflow-y: auto;		border: 1px solid #ccc;		padding: 5px 0 0 0;		list-style-type: none;	}	.field-container label {		color: #008571;		font-weight: bold;	}	.field-container li {		margin: 0px 5px 5px 5px;		padding: 5px;		border: 1px solid #ccc;		border-radius: 5px;		background-color: #daffff;		width: auto;		min-width: 150px;	}	.field-remove {		color: #777;		font-size: 14px;		float: right;		margin: 0px;		cursor: pointer;	}	.field-remove:after {		content: "x";	}	.field-name {		font-weight: 600;	}	.field-type {    float: right;    font-style: italic;	}	.all-fields {		height: 300px;	}	.keys-fields > ul {		height: 147px;	}	.keys-fields .field-type,	.values-fields .field-type {		display: none;	}	.field-container .keys-fields > label:nth-child(2),	.field-container .values-fields > label:nth-child(2) {		display: none;	}	.field-container.field-drag .keys-fields:not(.field-drag-acceptable) > ul,	.field-container.field-drag .values-fields:not(.field-drag-acceptable) > ul {		opacity: 0.5;	}	.field-container.field-drag .keys-fields:not(.field-drag-acceptable) > label:first-child,	.field-container.field-drag .values-fields:not(.field-drag-acceptable) > label:first-child {		display: none;	}	.field-container.field-drag .keys-fields:not(.field-drag-acceptable) > label:nth-child(2),	.field-container.field-drag .values-fields:not(.field-drag-acceptable) > label:nth-child(2) {		color: #ff0000;		font-weight: 400;		display: inline-block;	}	.fields-link {		color: #337ab7;		cursor: pointer;    display: inline-block;    font-size: 0.95em;    font-weight: 300;    position: absolute;    right: 20px;    top: 3px;	}	.fields-link:hover {		color: #286090;		text-decoration: underline;	}	.all-fields.numeric-only > [data-field-type="string"] {    display: none;	}</style><div class="container col-sm-12">	<div class="row">		<div class="form-group col-sm-12" style="padding-right:10px;">			<label for="titleae087e77">Chart Title:</label>			<input type="text" class="form-control" id="titleae087e77" name="title" value="">		</div>	</div>	<div class="field-container row">		<div class="col-sm-6" style="padding: 0px 5px 0px 0px;">			<label>Fields:</label> <span class="fields-link">Show only numeric columns</span>			<input type="text" class="options-fields-search form-control input-sm" placeholder="Search/Filter Fields">			<ul id="allFieldsae087e77" class="all-fields">								<li id="fieldae087e77-f3" class="fieldae087e77" data-field="unique_customers" data-field-type="numeric">					<span class="field-name">unique_customers</span>					<span class="field-type">numeric</span>					<a class="fieldae087e77-remove"></a>				</li>								<li id="fieldae087e77-f1" class="fieldae087e77" data-field="year" data-field-type="numeric">					<span class="field-name">year</span>					<span class="field-type">numeric</span>					<a class="fieldae087e77-remove"></a>				</li>								<li id="fieldae087e77-f2" class="fieldae087e77" data-field="zone" data-field-type="string">					<span class="field-name">zone</span>					<span class="field-type">string</span>					<a class="fieldae087e77-remove"></a>				</li>							</ul>		</div>		<div class="col-sm-6" style="padding: 0px 0px 0px 5px;">						<div class="keys-fields">				<label>Keys: <i class="fa fa-question-circle" title="Controls the X-Axis of the chart. Rows will be grouped by Key columns. Columns may be numeric or string."></i></label>				<label>Keys: Only numeric or string columns are supported <i class="fa fa-warning"></i></label>				<ul id="keyFieldsae087e77">																							<li id="fieldae087e77-f2-keyFieldsae087e77" data-field="zone">zone<a class="fieldae087e77-remove field-remove"></a></li>																				</ul>			</div>						<div class="values-fields">				<label>Values: <i class="fa fa-question-circle" title="Controls the Y-Axis of the chart. Values must be numeric columns."></i></label>				<label>Values: Only numeric co ...
#         sanitize:false,
#         notebook: IPython.notebook,
#
#         keyboard_manager: IPython.notebook.keyboard_manager,
#         buttons: {
#
#             OK: {
#                 class : "btn-primary btn-ok",
#                 click: function() {
#
# (
#
#
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTMLae087e77');
#         if (n.length == 0 ){
#             n = $('#wrapperHTMLae087e77');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="2850507A33444756801B43A74E3E6A56".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#executionae087e77");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src

# %%
display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='barChart',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='2e7ed979')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#         <button id="mapOptions2e7ed979" class="btn btn-default">Options</button>
#
#     </div>
#
#     <div class="form-group col-sm-3">
#         <label class="field">Renderer:</label>
#         <select class="form-control" id="renderer2e7ed979" style="margin:0; display:inline-block; width:70%;">
#
#                 <option value="matplotlib" selected>matplotlib</option>
#
#                 <option value="bokeh" >bokeh</option>
#
#         </select>
#     </div>
#
# </div>
#
# <script>
# $("#mapOptions2e7ed979").click(function(){
#
#     var global={}
#
# require(['base/js/dialog'],function(dialog){
#     var modal = dialog.modal;
#     var options = {
#         title: "Pixiedust: Bar Chart Options",
#         body: '<form id="chartOptions2e7ed979"><style type="text/css">	.field-container {	}	.field-container ul {		overflow-y: auto;		border: 1px solid #ccc;		padding: 5px 0 0 0;		list-style-type: none;	}	.field-container label {		color: #008571;		font-weight: bold;	}	.field-container li {		margin: 0px 5px 5px 5px;		padding: 5px;		border: 1px solid #ccc;		border-radius: 5px;		background-color: #daffff;		width: auto;		min-width: 150px;	}	.field-remove {		color: #777;		font-size: 14px;		float: right;		margin: 0px;		cursor: pointer;	}	.field-remove:after {		content: "x";	}	.field-name {		font-weight: 600;	}	.field-type {    float: right;    font-style: italic;	}	.all-fields {		height: 300px;	}	.keys-fields > ul {		height: 147px;	}	.keys-fields .field-type,	.values-fields .field-type {		display: none;	}	.field-container .keys-fields > label:nth-child(2),	.field-container .values-fields > label:nth-child(2) {		display: none;	}	.field-container.field-drag .keys-fields:not(.field-drag-acceptable) > ul,	.field-container.field-drag .values-fields:not(.field-drag-acceptable) > ul {		opacity: 0.5;	}	.field-container.field-drag .keys-fields:not(.field-drag-acceptable) > label:first-child,	.field-container.field-drag .values-fields:not(.field-drag-acceptable) > label:first-child {		display: none;	}	.field-container.field-drag .keys-fields:not(.field-drag-acceptable) > label:nth-child(2),	.field-container.field-drag .values-fields:not(.field-drag-acceptable) > label:nth-child(2) {		color: #ff0000;		font-weight: 400;		display: inline-block;	}	.fields-link {		color: #337ab7;		cursor: pointer;    display: inline-block;    font-size: 0.95em;    font-weight: 300;    position: absolute;    right: 20px;    top: 3px;	}	.fields-link:hover {		color: #286090;		text-decoration: underline;	}	.all-fields.numeric-only > [data-field-type="string"] {    display: none;	}</style><div class="container col-sm-12">	<div class="row">		<div class="form-group col-sm-12" style="padding-right:10px;">			<label for="title2e7ed979">Chart Title:</label>			<input type="text" class="form-control" id="title2e7ed979" name="title" value="">		</div>	</div>	<div class="field-container row">		<div class="col-sm-6" style="padding: 0px 5px 0px 0px;">			<label>Fields:</label> <span class="fields-link">Show only numeric columns</span>			<input type="text" class="options-fields-search form-control input-sm" placeholder="Search/Filter Fields">			<ul id="allFields2e7ed979" class="all-fields">								<li id="field2e7ed979-f3" class="field2e7ed979" data-field="unique_customers" data-field-type="numeric">					<span class="field-name">unique_customers</span>					<span class="field-type">numeric</span>					<a class="field2e7ed979-remove"></a>				</li>								<li id="field2e7ed979-f1" class="field2e7ed979" data-field="year" data-field-type="numeric">					<span class="field-name">year</span>					<span class="field-type">numeric</span>					<a class="field2e7ed979-remove"></a>				</li>								<li id="field2e7ed979-f2" class="field2e7ed979" data-field="zone" data-field-type="string">					<span class="field-name">zone</span>					<span class="field-type">string</span>					<a class="field2e7ed979-remove"></a>				</li>							</ul>		</div>		<div class="col-sm-6" style="padding: 0px 0px 0px 5px;">						<div class="keys-fields">				<label>Keys: <i class="fa fa-question-circle" title="Controls the X-Axis of the chart. Rows will be grouped by Key columns. Columns may be numeric or string."></i></label>				<label>Keys: Only numeric or string columns are supported <i class="fa fa-warning"></i></label>				<ul id="keyFields2e7ed979">																							<li id="field2e7ed979-f2-keyFields2e7ed979" data-field="zone">zone<a class="field2e7ed979-remove field-remove"></a></li>																				</ul>			</div>						<div class="values-fields">				<label>Values: <i class="fa fa-question-circle" title="Controls the Y-Axis of the chart. Values must be numeric columns."></i></label>				<label>Values: Only numeric co ...
#         sanitize:false,
#         notebook: IPython.notebook,
#
#         keyboard_manager: IPython.notebook.keyboard_manager,
#         buttons: {
#
#             OK: {
#                 class : "btn-primary btn-ok",
#                 click: function() {
#
# (
#
#
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML2e7ed979');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML2e7ed979');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="2850507A33444756801B43A74E3E6A56".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution2e7ed979");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){

# %%
display(dd,cell_id='2850507A33444756801B43A74E3E6A56',no_gen_tests='true',showLegend='true',staticFigure='false',aggregation='SUM',rowCount='100',handlerId='dataframe',valueFields='unique_customers',rendererId='matplotlib',stacked='true',keyFields='zone',nostore_cw='1098',nostore_pixiedust='true',nostore_bokeh='false',prefix='09810fd8')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style>
#
# <div class="df-table-wrapper df-table-wrapper-09810fd8 panel-group pd_save">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-09810fd8" data-parent="#df-table-wrapper-09810fd8">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-09810fd8" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>Pandas DataFrame Row</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'year'}</div>
#
#             <div class="df-schema-field">{'type': dtype('O'), 'name': 'zone'}</div>
#
#             <div class="df-schema-field">{'type': dtype('int64'), 'name': 'unique_customers'}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-09810fd8" data-parent="#df-table-wrapper-09810fd8">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-09810fd8" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 20 of 20</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">year</div>
#
#
#
#               <div class="fixed-cell">zone</div>
#
#
#
#               <div class="fixed-cell">unique_customers</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>year</div></th>
#
#
#
#                 <th><div>zone</div></th>
#
#
#
#                 <th><div>unique_customers</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Camping Equipment</td>
#
#
#
#                 <td>3</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Golf Equipment</td>
#
#
#
#                 <td>1</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Mountaineering Equipment</td>
#
#
#
#                 <td>1</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Outdoor Protection</td>
#
#
#
#                 <td>2</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2010</td>
#
#
#
#                 <td>Personal Accessories</td>
#
#
#
#                 <td>2</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Camping Equipment</td>
#
#
#
#                 <td>4</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Golf Equipment</td>
#
#
#
#                 <td>5</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Mountaineering Equipment</td>
#
#
#
#                 <td>2</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>2011</td>
#
#
#
#                 <td>Outdoor Protection</td>
#
#
#
#                 <td>4</td>
#
#
#               </tr>
#
#               <tr>
