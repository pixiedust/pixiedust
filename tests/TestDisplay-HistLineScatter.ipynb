# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 0.83</span>
#         </div>

# %%
dd = sqlContext.createDataFrame([
 ("a", "Alice", 34, 60, 1),
 ("b", "Bob", 36, 70, 2),
 ("c", "Charlie", 30, 99, 6),
 ("d", "Hector", 75, 87, 9),
 ("a", "Alice", 34, 44, 12),
 ("b", "Bob", 36, 109, 33),
 ("c", "Charlie", 30, 56, 77),
 ("d", "Hector", 75, 99, 2),
 ("a", "Alice", 34, 68, 7),
 ("b", "Bob", 36, 156, 54),
 ("c", "Charlie", 30, 89, 23),
 ("d", "Hector", 75, 64, 88),
 ("a", "Alice", 34, 45, 44),
 ("b", "Bob", 36, 97, 33),
 ("c", "Charlie", 30, 85, 41),
 ("d", "Hector", 75, 79, 6),
 ("a", "Alice", 34, 63, 9),
 ("b", "Bob", 36, 100, 28),
 ("c", "Charlie", 30, 85, 12),
 ("d", "Hector", 75, 73, 9)
], ["id", "name", "age", "weight", "something"])

dd.count()
# Out:
# 20

# %%
#SKIP_COMPARE_OUTPUT
display(dd, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><div id="chartFigurec2125687" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#
# <style>
#
# </style>
#
# ...

# %%
display(dd,cell_id='14A976304DE94B0C88CA23EC795E69F6',handlerId='lineChart',keyFields='age',valueFields='weight',rowCount='100',mpld3='true',nostore_cw='1098',nostore_bokeh='false',prefix='91b8fed3')
# Out:
# <script>
# $("#mapOptions91b8fed3").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Line Chart Options",
# ...

# %%
display(dd,cell_id='14A976304DE94B0C88CA23EC795E69F6',handlerId='scatterPlot',keyFields='age',valueFields='weight',rowCount='100',mpld3='true',nostore_cw='1098',nostore_bokeh='false',prefix='5033c401')
# Out:
# <script>
# $("#mapOptions5033c401").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Scatter Plot Options",
# ...

# %%
display(dd,cell_id='14A976304DE94B0C88CA23EC795E69F6',handlerId='histogram',keyFields='age',valueFields='weight',rowCount='100',mpld3='true',nostore_cw='1098',nostore_bokeh='false',prefix='b40e34c7',rendererId='matplotlib')
# Out:
# <script>
# $("#mapOptionsb40e34c7").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Histogram Options",
# ...
