# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 0.84</span>
#         </div>

# %%
dd = sqlContext.createDataFrame([
 ("a", "Alice", 34, 60, 1),
 ("b", "Bob", 36, 70, 2),
 ("c", "Charlie", 30, 99, 6),
 ("d", "Hector", 75, 87, 9),
 ("a", "Alice", 34, 44, 12),
 ("b", "Bob", 36, 109, 33),
 ("c", "Charlie", 30, 56, 77),
 ("d", "Hector", 75, 99, 2),
 ("a", "Alice", 34, 68, 7),
 ("b", "Bob", 36, 156, 54),
 ("c", "Charlie", 30, 89, 23),
 ("d", "Hector", 75, 64, 88),
 ("a", "Alice", 34, 45, 44),
 ("b", "Bob", 36, 97, 33),
 ("c", "Charlie", 30, 85, 41),
 ("d", "Hector", 75, 79, 6),
 ("a", "Alice", 34, 63, 9),
 ("b", "Bob", 36, 100, 28),
 ("c", "Charlie", 30, 85, 12),
 ("d", "Hector", 75, 73, 9)
], ["id", "name", "age", "weight", "something"])

dd.count()
# Out:
# 20

# %%
#SKIP_COMPARE_OUTPUT
display(dd, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
# ...

# %%
display(dd,cell_id='DE784E4F8E4C453896CD93B8C607CCF2',rowCount='100',handlerId='histogram',valueFields='weight',no_gen_tests='true',keyFields='age',rendererId='matplotlib',mpld3='false',nostore_cw='1098',nostore_pixiedust='false',nostore_bokeh='true',prefix='af74c44c')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#         <button id="mapOptionsaf74c44c" class="btn btn-default">Options</button>
#
#     </div>
#
#     <div class="form-group col-sm-3">
#         <label class="field">Renderer:</label>
#         <select class="form-control" id="rendereraf74c44c" style="margin:0; display:inline-block; width:70%;">
#
#                 <option value="matplotlib" selected>matplotlib</option>
#
#                 <option value="bokeh" >bokeh</option>
#
#                 <option value="seaborn" >seaborn</option>
#
#         </select>
#     </div>
#
# </div>
#
# <script>
# $("#mapOptionsaf74c44c").click(function(){
#
#     var global={}
#
# require(['base/js/dialog'],function(dialog){
#     var modal = dialog.modal;
#     var options = {
#         title: "Pixiedust: Histogram Options",
# ...

# %%
display(dd,cell_id='DE784E4F8E4C453896CD93B8C607CCF2',rowCount='100',handlerId='lineChart',valueFields='weight',no_gen_tests='true',keyFields='age',rendererId='matplotlib',mpld3='false',nostore_cw='1098',nostore_pixiedust='false',nostore_bokeh='true',prefix='fc0e2182')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#         <button id="mapOptionsfc0e2182" class="btn btn-default">Options</button>
#
#     </div>
#
#     <div class="form-group col-sm-3">
#         <label class="field">Renderer:</label>
#         <select class="form-control" id="rendererfc0e2182" style="margin:0; display:inline-block; width:70%;">
#
#                 <option value="matplotlib" selected>matplotlib</option>
#
#                 <option value="bokeh" >bokeh</option>
#
#         </select>
#     </div>
#
# </div>
#
# <script>
# $("#mapOptionsfc0e2182").click(function(){
#
#     var global={}
#
# require(['base/js/dialog'],function(dialog){
#     var modal = dialog.modal;
#     var options = {
#         title: "Pixiedust: Line Chart Options",
# ...

# %%
display(dd,cell_id='DE784E4F8E4C453896CD93B8C607CCF2',rowCount='100',handlerId='scatterPlot',valueFields='weight',no_gen_tests='true',keyFields='age',rendererId='matplotlib',mpld3='false',nostore_cw='1098',nostore_pixiedust='false',nostore_bokeh='true',prefix='d878fd61')
# Out:
# <div class="row chart-button-group">
#     <div class="form-group col-sm-9" style="padding-right:10px;">
#         <button id="mapOptionsd878fd61" class="btn btn-default">Options</button>
#
#     </div>
#
#     <div class="form-group col-sm-3">
#         <label class="field">Renderer:</label>
#         <select class="form-control" id="rendererd878fd61" style="margin:0; display:inline-block; width:70%;">
#
#                 <option value="matplotlib" selected>matplotlib</option>
#
#                 <option value="bokeh" >bokeh</option>
#
#                 <option value="seaborn" >seaborn</option>
#
#         </select>
#     </div>
#
# </div>
#
# <script>
# $("#mapOptionsd878fd61").click(function(){
#
#     var global={}
#
# require(['base/js/dialog'],function(dialog){
#     var modal = dialog.modal;
#     var options = {
#         title: "Pixiedust: Scatter Plot Options",
# ...
