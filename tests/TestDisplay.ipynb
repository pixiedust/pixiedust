# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
# Pixiedust version 0.71

# %%
dd = sqlContext.createDataFrame([
 ("Alabama",        "AL", 4.859,  50744),
 ("Alaska",         "AK", 0.738,   571951),
 ("Arizona",        "AZ", 6.828,  113635),
 ("Arkansas",       "AR", 2.978,  52068),
 ("California",     "CA", 39.145, 155959),
 ("Colorado",       "CO", 5.457,  103718),
 ("Connecticut",    "CT", 3.59,  4845),
 ("Delaware",       "DE", 0.946,   1954),
 ("Florida",        "FL", 20.271, 53927),
 ("Georgia",        "GA", 10.215, 57906),
 ("Hawaii",         "HI", 1.432,  6423),
 ("Idaho",          "ID", 1.655,  82747),
 ("Illinois",       "IL", 12.86, 55584),
 ("Indiana",        "IN", 6.62,  35867),
 ("Iowa",           "IA", 3.124,  55869),
 ("Kansas",         "KS", 2.912,  81815),
 ("Kentucky",       "KY", 4.425,  39728),
 ("Louisiana",      "LA", 4.671,  43562),
 ("Maine",          "ME", 1.329,  30862),
 ("Maryland",       "MD", 6.006,  9774),
 ("Massachusetts",  "MA", 6.794,  7840),
 ("Michigan",       "MI", 9.923,  56804),
 ("Minnesota",      "MN", 5.49,  79610),
 ("Mississippi",    "MS", 2.992,  46907),
 ("Missouri",       "MO", 6.084,  68886),
 ("Montana",        "MT", 1.033,  145552),
 ("Nebraska",       "NE", 1.896,  76872),
 ("Nevada",         "NV", 2.891,  109826),
 ("New Hampshire",  "NH", 1.331,  8968),
 ("New Jersey",     "NJ", 8.958,  7417),
 ("New Mexico",     "NM", 2.085,  121356),
 ("New York",       "NY", 19.796, 47214),
 ("North Carolina", "NC", 10.043, 48711),
 ("North Dakota",   "ND", 0.757,   68976),
 ("Ohio",           "OH", 11.613, 40948),
 ("Oklahoma",       "OK", 3.911,  68667),
 ("Oregon",         "OR", 4.029,  95997),
 ("Pennsylvania",   "PA", 12.803, 44817),
 ("Rhode Island",   "RI", 1.056,  1045),
 ("South Carolina", "SC", 4.896,  30110),
 ("South Dakota",   "SD", 0.858,   75885),
 ("Tennessee",      "TN", 6.6,  41217),
 ("Texas",          "TX", 27.469, 261797),
 ("Utah",           "UT", 2.996,  82144),
 ("Vermont",        "VT", 0.626,   9250),
 ("Virginia",       "VA", 8.383,  39594),
 ("Washington",     "WA", 7.17,  66544),
 ("West Virginia",  "WV", 1.844,  24078),
 ("Wisconsin",      "WI", 5.771,  54310),
 ("Wyoming",        "WY", 0.586,   97100)
], ["State", "Abbreviation", "Population (in millions)", "Land Area (square miles)"])

dd.count()
# Out:
# 50

# %%
#SKIP_COMPARE_OUTPUT
display(dd, gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
# ...

# %%
display(dd,cell_id='846948EE44014AEE8C70D44877C344D0',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',handlerId='dataframe',valueFields='Population (in millions)',keyFields='Abbreviation',prefix='2521d64b')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
# ...

# %%
display(dd,cell_id='846948EE44014AEE8C70D44877C344D0',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',handlerId='pieChart',valueFields='Population (in millions)',keyFields='Abbreviation',prefix='2521d64b')
# Out:
# <script>
# $("#mapOptions2521d64b").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...

# %%
display(dd,cell_id='846948EE44014AEE8C70D44877C344D0',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',handlerId='barChart',valueFields='Population (in millions)',keyFields='Abbreviation',prefix='2521d64b')
# Out:
# <script>
# $("#mapOptions2521d64b").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...

# %%
display(dd,cell_id='846948EE44014AEE8C70D44877C344D0',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',handlerId='lineChart',valueFields='Population (in millions)',keyFields='Abbreviation',prefix='2521d64b')
# Out:
# <script>
# $("#mapOptions2521d64b").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...
