# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
# Pixiedust database opened successfully
# Pixiedust version 0.71

# %%
dd = sqlContext.createDataFrame(
  [(2010, 'Camping Equipment', 3),
    (2010, 'Golf Equipment', 1),
    (2010, 'Mountaineering Equipment', 1),
    (2010, 'Outdoor Protection', 2),
    (2010, 'Personal Accessories', 2),
    (2011, 'Camping Equipment', 4),
    (2011, 'Golf Equipment', 5),
    (2011, 'Mountaineering Equipment',2),
    (2011, 'Outdoor Protection', 4),
    (2011, 'Personal Accessories', 2),
    (2012, 'Camping Equipment', 5),
    (2012, 'Golf Equipment', 5),
    (2012, 'Mountaineering Equipment', 3),
    (2012, 'Outdoor Protection', 5),
    (2012, 'Personal Accessories', 3),
    (2013, 'Camping Equipment', 8),
    (2013, 'Golf Equipment', 5),
    (2013, 'Mountaineering Equipment', 3),
    (2013, 'Outdoor Protection', 8),
    (2013, 'Personal Accessories', 4)],
    ["year","zone","unique_customers"])

dd.count()
# Out:
# 20

# %%
#SKIP_COMPARE_OUTPUT
display(dd, gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
# ...

# %%
display(dd,cell_id='4590BFC317FA412F8B64519D062E837D',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',rowCount=100,handlerId='dataframe',valueFields='unique_customers',keyFields='zone',prefix='b97a979a')
# Out:
# <style type="text/css" class="pd_save">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
# ...

# %%
display(dd,cell_id='4590BFC317FA412F8B64519D062E837D',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',rowCount=100,handlerId='pieChart',valueFields='unique_customers',keyFields='zone',prefix='b97a979a')
# Out:
# <script>
# $("#mapOptionsb97a979a").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...

# %%
display(dd,cell_id='4590BFC317FA412F8B64519D062E837D',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',rowCount=100,handlerId='lineChart',valueFields='unique_customers',keyFields='zone',prefix='b97a979a')
# Out:
# <script>
# $("#mapOptionsb97a979a").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...

# %%
display(dd,cell_id='4590BFC317FA412F8B64519D062E837D',showLegend='true',stacked='true',staticFigure='false',aggregation='SUM',rowCount=100,handlerId='barChart',valueFields='unique_customers',keyFields='zone',prefix='b97a979a')
# Out:
# <script>
# $("#mapOptionsb97a979a").click(function(){
#
#     var globalNested={}
# require(['base/js/dialog'],function(dialog){
#         var modal = dialog.modal;
#         var options = {
#             title: "Pixiedust: Chart Options",
# ...
