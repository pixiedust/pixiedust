# %% [markdown]
# ### Loading data from Cloudant or CouchDB

# %% [markdown]
# You can load data from [CouchDB](https://couchdb.apache.org/) or a managed [Cloudant instance](https://console.ng.bluemix.net/catalog/services/cloudant-nosql-db/) using the [Cloudant Spark connector](https://github.com/cloudant-labs/spark-cloudant).

# %% [markdown]
# #### Prerequisites

# %% [markdown]
# Collect your database connection information: the database host, user name, password and source database.
#
#
# <div class="alert alert-block alert-info">If your Cloudant instance was provisioned in Bluemix you can find the connectivity information in the _Service Credentials_ tab.
# </div>
#
# Import PixieDust and enable the Apache Spark Job monitor

# %%
import pixiedust
pixiedust.enableJobMonitor()
# Out:
# <div id="pm_overallContainerecc917b8" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistieecc917b8" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNameecc917b8"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressecc917b8" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerecc917b8" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsecc917b8">
#     </ul>
#     <div class="tab-content" id="tabContentecc917b8">
#     </div>
# </div>
#
# <script>
# $("#twistieecc917b8").click(function(){
#     visible = $("#pm_containerecc917b8").is(':visible');
#     $("#pm_containerecc917b8").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %% [markdown]
# #### Configure database connectivity
#
# Customize this cell with your Cloudant/CouchDB connection information

# %%
# @hidden_cell
# Enter your Cloudant host name
host = '...'
# Enter your Cloudant user name
username = '...'
# Enter your Cloudant password
password = '...'
# Enter your source database name
database = '...'
# Out:
# <div id="pm_overallContainer68c5ba48" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie68c5ba48" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName68c5ba48"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress68c5ba48" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container68c5ba48" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors68c5ba48">
#     </ul>
#     <div class="tab-content" id="tabContent68c5ba48">
#     </div>
# </div>
#
# <script>
# $("#twistie68c5ba48").click(function(){
#     visible = $("#pm_container68c5ba48").is(':visible');
#     $("#pm_container68c5ba48").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %% [markdown]
# #### Load documents from the database
#
# Load the documents into an Apache Spark DataFrame.

# %%
# no changes are required to this cell
# obtain Spark SQL Context
sqlContext = SQLContext(sc)
# load data
cloudant_data = sqlContext.read.format("com.cloudant.spark").\
                                      option("cloudant.host", host).\
                                      option("cloudant.username", username).\
                                      option("cloudant.password", password).\
                                      load(database)
# Out:
# <div id="pm_overallContainera7baa49d" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiea7baa49d" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamea7baa49d"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressa7baa49d" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containera7baa49d" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsa7baa49d">
#     </ul>
#     <div class="tab-content" id="tabContenta7baa49d">
#     </div>
# </div>
#
# <script>
# $("#twistiea7baa49d").click(function(){
#     visible = $("#pm_containera7baa49d").is(':visible');
#     $("#pm_containera7baa49d").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
# Use connectorVersion=2.0.0, dbName=dsx_load_demo, indexName=null, viewName=null,jsonstore.rdd.partitions=10, jsonstore.rdd.maxInPartition=-1,jsonstore.rdd.minInPartition=10, jsonstore.rdd.requestTimeout=900000,bulkSize=200, schemaSampleSize=-1

# %% [markdown]
# #### Explore the loaded data using PixieDust
#
# Select the _DataFrame view_ to inspect the metadata and explore the data by choosing a chart type and chart options.

# %%
display(cloudant_data)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><div id="chartFigure8e329862" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# For information on how to load data from other sources refer to [these code snippets](https://apsportal.ibm.com/docs/content/analyze-data/python_load.html).
# </div>
