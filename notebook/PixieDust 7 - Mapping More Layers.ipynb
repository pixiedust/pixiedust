# %%
#!pip install -e /Users/rajrsingh/workspace/lib/pixiedust
import pixiedust
# import pandas as pd
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.0.6</span>
#         </div>

# %%
sftest = pixiedust.sampleData("https://data.sfgov.org/api/views/vv57-2fgy/rows.csv?accessType=DOWNLOAD")
# Out:
# Downloading 'https://data.sfgov.org/api/views/vv57-2fgy/rows.csv?accessType=DOWNLOAD' from https://data.sfgov.org/api/views/vv57-2fgy/rows.csv?accessType=DOWNLOAD
#                 <div>
#                     <span id="pm_labeld65a367b">Starting download...</span>
#                     <progress id="pm_progressd65a367b" max="100" value="0" style="width:200px"></progress>
#                 </div>
# Creating pySpark DataFrame for 'https://data.sfgov.org/api/views/vv57-2fgy/rows.csv?accessType=DOWNLOAD'. Please wait...
# Successfully created pySpark DataFrame for 'https://data.sfgov.org/api/views/vv57-2fgy/rows.csv?accessType=DOWNLOAD'

# %%
# !python -v
# Out:
# # installing zipimport hook
# import zipimport # builtin
# # installed zipimport hook
# # zipimport: found 77 names in /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip
# # /Users/rajrsingh/anaconda/lib/python2.7/site.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/site.py
# import site # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/site.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/os.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/os.py
# import os # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/os.pyc
# import errno # builtin
# import posix # builtin
# # /Users/rajrsingh/anaconda/lib/python2.7/posixpath.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/posixpath.py
# import posixpath # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/posixpath.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/stat.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/stat.py
# import stat # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/stat.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/genericpath.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/genericpath.py
# import genericpath # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/genericpath.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/warnings.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/warnings.py
# import warnings # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/warnings.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/linecache.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/linecache.py
# import linecache # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/linecache.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/types.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/types.py
# import types # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/types.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/UserDict.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/UserDict.py
# import UserDict # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/UserDict.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/_abcoll.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/_abcoll.py
# import _abcoll # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/_abcoll.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/abc.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/abc.py
# import abc # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/abc.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/_weakrefset.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/_weakrefset.py
# import _weakrefset # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/_weakrefset.pyc
# import _weakref # builtin
# # /Users/rajrsingh/anaconda/lib/python2.7/copy_reg.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/copy_reg.py
# import copy_reg # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/copy_reg.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/traceback.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/traceback.py
# import traceback # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/traceback.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/sysconfig.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/sysconfig.py
# import sysconfig # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/sysconfig.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/re.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/re.py
# import re # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/re.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/sre_compile.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/sre_compile.py
# import sre_compile # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/sre_compile.pyc
# import _sre # builtin
# # /Users/rajrsingh/anaconda/lib/python2.7/sre_parse.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/sre_parse.py
# import sre_parse # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/sre_parse.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/sre_constants.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/sre_constants.py
# import sre_constants # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/sre_constants.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_locale.so", 2);
# import _locale # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_locale.so
# # /Users/rajrsingh/anaconda/lib/python2.7/_sysconfigdata.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/_sysconfigdata.py
# import _sysconfigdata # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/_sysconfigdata.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/_osx_support.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/_osx_support.py
# import _osx_support # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/_osx_support.pyc
# # zipimport: found 13 names in /Users/rajrsingh/anaconda/lib/python2.7/site-packages/pathtools-0.1.2-py2.7.egg
# # zipimport: found 29 names in /Users/rajrsingh/anaconda/lib/python2.7/site-packages/argh-0.26.2-py2.7.egg
# # zipimport: found 25 names in /Users/rajrsingh/anaconda/lib/python2.7/site-packages/socketpool-0.5.3-py2.7.egg
# # zipimport: found 21 names in /Users/rajrsingh/anaconda/lib/python2.7/site-packages/http_parser-0.8.3-py2.7-macosx-10.6-x86_64.egg
# import encodings # directory /Users/rajrsingh/anaconda/lib/python2.7/encodings
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/__init__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/__init__.py
# import encodings # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/__init__.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/codecs.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/codecs.py
# import codecs # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/codecs.pyc
# import _codecs # builtin
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/aliases.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/aliases.py
# import encodings.aliases # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/aliases.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/utf_8.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/utf_8.py
# import encodings.utf_8 # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/utf_8.pyc
# Python 2.7.11 |Anaconda custom (x86_64)| (default, Dec  6 2015, 18:57:58)
# [GCC 4.2.1 (Apple Inc. build 5577)] on darwin
# Type "help", "copyright", "credits" or "license" for more information.
# Anaconda is brought to you by Continuum Analytics.
# Please check out: http://continuum.io/thanks and https://anaconda.org
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/readline.so", 2);
# import readline # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/readline.so
# # /Users/rajrsingh/anaconda/lib/python2.7/atexit.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/atexit.py
# import atexit # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/atexit.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/platform.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/platform.py
# import platform # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/platform.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/string.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/string.py
# import string # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/string.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/strop.so", 2);
# import strop # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/strop.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/zlib.so", 2);
# import zlib # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/zlib.so
# # zipimport: zlib available
# # /Users/rajrsingh/anaconda/lib/python2.7/__future__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/__future__.py
# import __future__ # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/__future__.pyc
# # zipimport: zlib available
# import py4j.version # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/version.py
# import py4j # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/__init__.py
# import pyspark # directory /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/__init__.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/__init__.py
# import pyspark # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/__init__.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/functools.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/functools.py
# import functools # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/functools.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_functools.so", 2);
# import _functools # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_functools.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/conf.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/conf.py
# import pyspark.conf # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/conf.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/context.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/context.py
# import pyspark.context # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/context.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/shutil.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/shutil.py
# import shutil # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/shutil.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/fnmatch.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/fnmatch.py
# import fnmatch # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/fnmatch.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/collections.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/collections.py
# import collections # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/collections.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_collections.so", 2);
# import _collections # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_collections.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/operator.so", 2);
# import operator # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/operator.so
# # /Users/rajrsingh/anaconda/lib/python2.7/keyword.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/keyword.py
# import keyword # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/keyword.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/heapq.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/heapq.py
# import heapq # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/heapq.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/itertools.so", 2);
# import itertools # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/itertools.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_heapq.so", 2);
# import _heapq # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_heapq.so
# import thread # builtin
# import pwd # builtin
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/grp.so", 2);
# import grp # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/grp.so
# # /Users/rajrsingh/anaconda/lib/python2.7/threading.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/threading.py
# import threading # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/threading.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/time.so", 2);
# import time # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/time.so
# # /Users/rajrsingh/anaconda/lib/python2.7/tempfile.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/tempfile.py
# import tempfile # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/tempfile.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/io.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/io.py
# import io # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/io.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_io.so", 2);
# import _io # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_io.so
# # /Users/rajrsingh/anaconda/lib/python2.7/random.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/random.py
# import random # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/random.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/math.so", 2);
# import math # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/math.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/binascii.so", 2);
# import binascii # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/binascii.so
# # /Users/rajrsingh/anaconda/lib/python2.7/hashlib.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/hashlib.py
# import hashlib # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/hashlib.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_hashlib.so", 2);
# import _hashlib # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_hashlib.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_random.so", 2);
# import _random # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_random.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/cStringIO.so", 2);
# import cStringIO # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/cStringIO.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/fcntl.so", 2);
# import fcntl # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/fcntl.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/accumulators.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/accumulators.py
# import pyspark.accumulators # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/accumulators.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/select.so", 2);
# import select # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/select.so
# # /Users/rajrsingh/anaconda/lib/python2.7/struct.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/struct.py
# import struct # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/struct.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_struct.so", 2);
# import _struct # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_struct.so
# # /Users/rajrsingh/anaconda/lib/python2.7/SocketServer.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/SocketServer.py
# import SocketServer # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/SocketServer.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/socket.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/socket.py
# import socket # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/socket.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_socket.so", 2);
# import _socket # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_socket.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_ssl.so", 2);
# import _ssl # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_ssl.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/cloudpickle.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/cloudpickle.py
# import pyspark.cloudpickle # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/cloudpickle.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/pickle.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/pickle.py
# import pickle # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/pickle.pyc
# import marshal # builtin
# # /Users/rajrsingh/anaconda/lib/python2.7/dis.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/dis.py
# import dis # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/dis.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/opcode.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/opcode.py
# import opcode # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/opcode.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/serializers.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/serializers.py
# import pyspark.serializers # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/serializers.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/cPickle.so", 2);
# import cPickle # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/cPickle.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/broadcast.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/broadcast.py
# import pyspark.broadcast # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/broadcast.pyc
# import gc # builtin
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/files.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/files.py
# import pyspark.files # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/files.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/java_gateway.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/java_gateway.py
# import pyspark.java_gateway # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/java_gateway.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/shlex.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/shlex.py
# import shlex # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/shlex.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/subprocess.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/subprocess.py
# import subprocess # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/subprocess.pyc
# # zipimport: zlib available
# import logging # directory /Users/rajrsingh/anaconda/lib/python2.7/logging
# # /Users/rajrsingh/anaconda/lib/python2.7/logging/__init__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/logging/__init__.py
# import logging # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/logging/__init__.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/weakref.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/weakref.py
# import weakref # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/weakref.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/pydoc.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/pydoc.py
# import pydoc # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/pydoc.pyc
# import imp # builtin
# # /Users/rajrsingh/anaconda/lib/python2.7/inspect.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/inspect.py
# import inspect # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/inspect.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/tokenize.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/tokenize.py
# import tokenize # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/tokenize.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/token.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/token.py
# import token # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/token.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/pkgutil.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/pkgutil.py
# import pkgutil # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/pkgutil.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/repr.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/repr.py
# import repr # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/repr.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/locale.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/locale.py
# import locale # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/locale.pyc
# # zipimport: zlib available
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/utf_32_be.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/utf_32_be.py
# import encodings.utf_32_be # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/utf_32_be.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/Queue.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/Queue.py
# import Queue # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/Queue.pyc
# import py4j.compat # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/compat.py
# # zipimport: zlib available
# import py4j.finalizer # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/finalizer.py
# # zipimport: zlib available
# # /Users/rajrsingh/anaconda/lib/python2.7/base64.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/base64.py
# import base64 # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/base64.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/decimal.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/decimal.py
# import decimal # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/decimal.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/numbers.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/numbers.py
# import numbers # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/numbers.pyc
# import py4j.protocol # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/protocol.py
# # zipimport: zlib available
# import py4j.signals # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/signals.py
# # zipimport: zlib available
# import py4j.java_collections # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/java_collections.py
# import py4j.java_gateway # loaded from Zip /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/java_gateway.py
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/storagelevel.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/storagelevel.py
# import pyspark.storagelevel # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/storagelevel.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/rdd.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/rdd.py
# import pyspark.rdd # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/rdd.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/copy.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/copy.py
# import copy # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/copy.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/bisect.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/bisect.py
# import bisect # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/bisect.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_bisect.so", 2);
# import _bisect # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_bisect.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/join.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/join.py
# import pyspark.join # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/join.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/resultiterable.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/resultiterable.py
# import pyspark.resultiterable # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/resultiterable.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/statcounter.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/statcounter.py
# import pyspark.statcounter # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/statcounter.pyc
# import numpy # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/__init__.py
# import numpy # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_globals.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_globals.py
# import numpy._globals # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_globals.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/__config__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/__config__.py
# import numpy.__config__ # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/__config__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/version.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/version.py
# import numpy.version # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/version.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_import_tools.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_import_tools.py
# import numpy._import_tools # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_import_tools.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/add_newdocs.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/add_newdocs.py
# import numpy.add_newdocs # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/add_newdocs.pyc
# import numpy.lib # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/__init__.py
# import numpy.lib # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/info.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/info.py
# import numpy.lib.info # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/info.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/type_check.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/type_check.py
# import numpy.lib.type_check # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/type_check.pyc
# import numpy.core # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/__init__.py
# import numpy.core # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/info.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/info.py
# import numpy.core.info # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/info.pyc
# dlopen("/Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/multiarray.so", 2);
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/datetime.so", 2);
# import datetime # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/datetime.so
# import numpy.core.multiarray # dynamically loaded from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/multiarray.so
# dlopen("/Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/umath.so", 2);
# import numpy.core.umath # dynamically loaded from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/umath.so
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/_internal.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/_internal.py
# import numpy.core._internal # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/_internal.pyc
# import numpy.compat # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/__init__.py
# import numpy.compat # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/_inspect.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/_inspect.py
# import numpy.compat._inspect # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/_inspect.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/py3k.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/py3k.py
# import numpy.compat.py3k # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/compat/py3k.pyc
# import ctypes # directory /Users/rajrsingh/anaconda/lib/python2.7/ctypes
# # /Users/rajrsingh/anaconda/lib/python2.7/ctypes/__init__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/ctypes/__init__.py
# import ctypes # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/ctypes/__init__.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_ctypes.so", 2);
# import _ctypes # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_ctypes.so
# # /Users/rajrsingh/anaconda/lib/python2.7/ctypes/_endian.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/ctypes/_endian.py
# import ctypes._endian # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/ctypes/_endian.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/numerictypes.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/numerictypes.py
# import numpy.core.numerictypes # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/numerictypes.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/numeric.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/numeric.py
# import numpy.core.numeric # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/numeric.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/arrayprint.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/arrayprint.py
# import numpy.core.arrayprint # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/arrayprint.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.py
# import numpy.core.fromnumeric # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/_methods.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/_methods.py
# import numpy.core._methods # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/_methods.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/defchararray.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/defchararray.py
# import numpy.core.defchararray # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/defchararray.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/records.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/records.py
# import numpy.core.records # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/records.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/memmap.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/memmap.py
# import numpy.core.memmap # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/memmap.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/function_base.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/function_base.py
# import numpy.core.function_base # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/function_base.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/machar.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/machar.py
# import numpy.core.machar # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/machar.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/getlimits.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/getlimits.py
# import numpy.core.getlimits # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/getlimits.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/shape_base.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/shape_base.py
# import numpy.core.shape_base # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/shape_base.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/einsumfunc.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/einsumfunc.py
# import numpy.core.einsumfunc # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/core/einsumfunc.pyc
# import numpy.testing # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/__init__.py
# import numpy.testing # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/__init__.pyc
# import unittest # directory /Users/rajrsingh/anaconda/lib/python2.7/unittest
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/__init__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/__init__.py
# import unittest # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/__init__.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/result.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/result.py
# import unittest.result # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/result.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/StringIO.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/StringIO.py
# import StringIO # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/StringIO.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/util.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/util.py
# import unittest.util # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/util.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/case.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/case.py
# import unittest.case # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/case.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/difflib.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/difflib.py
# import difflib # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/difflib.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/pprint.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/pprint.py
# import pprint # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/pprint.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/suite.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/suite.py
# import unittest.suite # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/suite.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/loader.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/loader.py
# import unittest.loader # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/loader.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/main.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/main.py
# import unittest.main # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/main.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/runner.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/runner.py
# import unittest.runner # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/runner.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/unittest/signals.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/unittest/signals.py
# import unittest.signals # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/unittest/signals.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/decorators.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/decorators.py
# import numpy.testing.decorators # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/decorators.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/utils.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/utils.py
# import numpy.testing.utils # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/utils.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/contextlib.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/contextlib.py
# import contextlib # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/contextlib.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/utils.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/utils.py
# import numpy.lib.utils # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/utils.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/nosetester.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/nosetester.py
# import numpy.testing.nosetester # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/testing/nosetester.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/ufunclike.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/ufunclike.py
# import numpy.lib.ufunclike # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/ufunclike.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/index_tricks.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/index_tricks.py
# import numpy.lib.index_tricks # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/index_tricks.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/function_base.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/function_base.py
# import numpy.lib.function_base # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/function_base.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/twodim_base.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/twodim_base.py
# import numpy.lib.twodim_base # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/twodim_base.pyc
# import numpy.matrixlib # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib/__init__.py
# import numpy.matrixlib # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.py
# import numpy.matrixlib.defmatrix # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/stride_tricks.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/stride_tricks.py
# import numpy.lib.stride_tricks # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/stride_tricks.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/nanfunctions.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/nanfunctions.py
# import numpy.lib.nanfunctions # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/nanfunctions.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/shape_base.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/shape_base.py
# import numpy.lib.shape_base # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/shape_base.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/scimath.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/scimath.py
# import numpy.lib.scimath # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/scimath.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/polynomial.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/polynomial.py
# import numpy.lib.polynomial # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/polynomial.pyc
# import numpy.linalg # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/__init__.py
# import numpy.linalg # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/info.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/info.py
# import numpy.linalg.info # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/info.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/linalg.py
# import numpy.linalg.linalg # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc
# dlopen("/Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/lapack_lite.so", 2);
# import numpy.linalg.lapack_lite # dynamically loaded from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/lapack_lite.so
# dlopen("/Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/_umath_linalg.so", 2);
# import numpy.linalg._umath_linalg # dynamically loaded from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/linalg/_umath_linalg.so
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arraysetops.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arraysetops.py
# import numpy.lib.arraysetops # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arraysetops.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/npyio.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/npyio.py
# import numpy.lib.npyio # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/npyio.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/format.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/format.py
# import numpy.lib.format # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/format.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_datasource.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_datasource.py
# import numpy.lib._datasource # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_datasource.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_iotools.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_iotools.py
# import numpy.lib._iotools # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_iotools.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/future_builtins.so", 2);
# import future_builtins # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/future_builtins.so
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/financial.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/financial.py
# import numpy.lib.financial # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/financial.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arrayterator.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arrayterator.py
# import numpy.lib.arrayterator # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arrayterator.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arraypad.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arraypad.py
# import numpy.lib.arraypad # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/arraypad.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_version.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_version.py
# import numpy.lib._version # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/lib/_version.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_distributor_init.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_distributor_init.py
# import numpy._distributor_init # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/_distributor_init.pyc
# import numpy.fft # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/__init__.py
# import numpy.fft # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/info.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/info.py
# import numpy.fft.info # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/info.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/fftpack.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/fftpack.py
# import numpy.fft.fftpack # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/fftpack.pyc
# dlopen("/Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/fftpack_lite.so", 2);
# import numpy.fft.fftpack_lite # dynamically loaded from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/fftpack_lite.so
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/helper.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/helper.py
# import numpy.fft.helper # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/fft/helper.pyc
# import numpy.polynomial # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/__init__.py
# ...
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/chebyshev.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/chebyshev.py
# import numpy.polynomial.chebyshev # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/chebyshev.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/legendre.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/legendre.py
# import numpy.polynomial.legendre # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/legendre.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/hermite.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/hermite.py
# import numpy.polynomial.hermite # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/hermite.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/hermite_e.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/hermite_e.py
# import numpy.polynomial.hermite_e # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/hermite_e.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/laguerre.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/laguerre.py
# import numpy.polynomial.laguerre # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/polynomial/laguerre.pyc
# import numpy.random # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/__init__.py
# import numpy.random # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/info.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/info.py
# import numpy.random.info # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/info.pyc
# dlopen("/Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/mtrand.so", 2);
# import numpy.random.mtrand # dynamically loaded from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/random/mtrand.so
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ctypeslib.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ctypeslib.py
# import numpy.ctypeslib # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ctypeslib.pyc
# import numpy.ma # directory /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/__init__.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/__init__.py
# import numpy.ma # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/__init__.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/core.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/core.py
# import numpy.ma.core # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/core.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/unicode_escape.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/unicode_escape.py
# import encodings.unicode_escape # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/unicode_escape.pyc
# # /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/extras.pyc matches /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/extras.py
# import numpy.ma.extras # precompiled from /Users/rajrsingh/.local/lib/python2.7/site-packages/numpy/ma/extras.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/rddsampler.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/rddsampler.py
# import pyspark.rddsampler # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/rddsampler.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/shuffle.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/shuffle.py
# import pyspark.shuffle # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/shuffle.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/heapq3.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/heapq3.py
# import pyspark.heapq3 # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/heapq3.pyc
# import psutil # directory /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil
# # /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/__init__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/__init__.py
# import psutil # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/__init__.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_common.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_common.py
# import psutil._common # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_common.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_compat.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_compat.py
# import psutil._compat # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_compat.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psosx.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psosx.py
# import psutil._psosx # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psosx.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psposix.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psposix.py
# import psutil._psposix # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psposix.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/glob.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/glob.py
# import glob # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/glob.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psutil_osx.so", 2);
# import psutil._psutil_osx # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psutil_osx.so
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psutil_posix.so", 2);
# import psutil._psutil_posix # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/site-packages/psutil/_psutil_posix.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/traceback_utils.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/traceback_utils.py
# import pyspark.traceback_utils # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/traceback_utils.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/status.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/status.py
# import pyspark.status # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/status.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/profiler.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/profiler.py
# import pyspark.profiler # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/profiler.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/cProfile.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/cProfile.py
# import cProfile # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/cProfile.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_lsprof.so", 2);
# import _lsprof # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_lsprof.so
# # /Users/rajrsingh/anaconda/lib/python2.7/pstats.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/pstats.py
# import pstats # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/pstats.pyc
# import pyspark.sql # directory /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/__init__.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/__init__.py
# import pyspark.sql # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/__init__.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/types.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/types.py
# import pyspark.sql.types # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/types.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/calendar.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/calendar.py
# import calendar # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/calendar.pyc
# import json # directory /Users/rajrsingh/anaconda/lib/python2.7/json
# # /Users/rajrsingh/anaconda/lib/python2.7/json/__init__.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/json/__init__.py
# import json # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/json/__init__.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/json/decoder.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/json/decoder.py
# import json.decoder # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/json/decoder.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/json/scanner.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/json/scanner.py
# import json.scanner # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/json/scanner.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_json.so", 2);
# import _json # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/_json.so
# # /Users/rajrsingh/anaconda/lib/python2.7/json/encoder.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/json/encoder.py
# import json.encoder # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/json/encoder.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/array.so", 2);
# import array # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/array.so
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/context.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/context.py
# import pyspark.sql.context # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/context.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/session.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/session.py
# import pyspark.sql.session # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/session.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/catalog.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/catalog.py
# import pyspark.sql.catalog # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/catalog.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/dataframe.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/dataframe.py
# import pyspark.sql.dataframe # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/dataframe.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/column.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/column.py
# import pyspark.sql.column # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/column.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/readwriter.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/readwriter.py
# import pyspark.sql.readwriter # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/readwriter.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/utils.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/utils.py
# import pyspark.sql.utils # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/utils.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/streaming.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/streaming.py
# import pyspark.sql.streaming # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/streaming.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/functions.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/functions.py
# import pyspark.sql.functions # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/functions.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/conf.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/conf.py
# import pyspark.sql.conf # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/conf.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/group.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/group.py
# import pyspark.sql.group # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/group.pyc
# # /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/window.pyc matches /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/window.py
# import pyspark.sql.window # precompiled from /Users/rajrsingh/workspace/lib/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/window.pyc
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel).
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/idna.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/idna.py
# import encodings.idna # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/idna.pyc
# # /Users/rajrsingh/anaconda/lib/python2.7/stringprep.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/stringprep.py
# import stringprep # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/stringprep.pyc
# dlopen("/Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/unicodedata.so", 2);
# import unicodedata # dynamically loaded from /Users/rajrsingh/anaconda/lib/python2.7/lib-dynload/unicodedata.so
# # /Users/rajrsingh/anaconda/lib/python2.7/encodings/ascii.pyc matches /Users/rajrsingh/anaconda/lib/python2.7/encodings/ascii.py
# import encodings.ascii # precompiled from /Users/rajrsingh/anaconda/lib/python2.7/encodings/ascii.pyc
# 17/06/08 12:21:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 17/06/08 12:21:18 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.0.2
#       /_/
#
# Using Python version 2.7.11 (default, Dec  6 2015 18:57:58)
# SparkSession available as 'spark'.
# >>>

# %%
homesdf = pixiedust.sampleData(6)
# homesdf = pd.read_csv("https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv")
# Out:
# Downloading 'Million dollar home sales in NE Mass late 2016' from https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv
#                 <div>
#                     <span id="pm_label4b5065ba">Starting download...</span>
#                     <progress id="pm_progress4b5065ba" max="100" value="0" style="width:200px"></progress>
#                 </div>
# Creating pySpark DataFrame for 'Million dollar home sales in NE Mass late 2016'. Please wait...
# Successfully created pySpark DataFrame for 'Million dollar home sales in NE Mass late 2016'

# %%
roadslines = {
    "type": "FeatureCollection", 
    "features": [
        {
            "type": "Feature", 
            "properties": {}, 
            "geometry": {
                "type": "LineString", 
                "coordinates": [
                  [-71.0771656036377,42.364537198664884],
                  [-71.07780933380127,42.36133451106724],
                  [-71.07562065124512,42.359812384483625],
                  [-71.07557773590088,42.35610204645879]
                ]
            }
        }, 
        {
            "type": "Feature", 
            "properties": {
                "name": "Highway to the Danger Zone"
            }, 
            "geometry": {
                "type": "LineString", 
                "coordinates": [
                  [-71.09179973602294,42.35848049347556],
                  [-71.08287334442139,42.356419177928906],
                  [-71.07184410095215,42.35794138670829],
                  [-71.06772422790527,42.35686315929846]
                ]
            }
        }
    ]
}
roadslayer = {
    "id": "Roads",
    "maptype": "mapbox", 
    "order": 2,
    "type": "line",
    "source": {
        "type": "geojson",
        "data": roadslines
    },
    "paint": {
        "line-color": "rgba(128,0,128,0.65)",
        "line-width": 6, 
        "line-blur": 2, 
        "line-opacity": 0.75
    },
    "layout": {
        "line-join": "round"        
    }
}

# %%
dangerzones = {
    "type": "FeatureCollection", 
    "features": [
        {
            "type": "Feature", 
            "properties": {
                "name": "Danger Zone"
            }, 
            "geometry": {
                "type": "Polygon", 
                "coordinates": [
                    [[-71.08828067779541, 42.360890561289295],
                    [-71.08802318572998, 42.35032997408756],
                    [-71.07295989990234, 42.35591176680853],
                    [-71.07583522796631, 42.3609539828782],
                    [-71.08828067779541, 42.360890561289295]]
                ]
            }
        }
    ]
}
dglayer = {
    "id": "Danger Zone",
    "maptype": "mapbox", 
    "order": 3,
    "type": "fill",
    "source": {
        "type": "geojson",
        "data": dangerzones
    },
    "paint": {
        "fill-antialias": True, 
        "fill-color": "rgba(248,64,0,1.0)",
        "fill-outline-color": "#ff0000"
    },
    "layout": {}
}

# %%
custompt = {
    "type": "FeatureCollection", 
    "features": [
        {
            "type": "Feature", 
            "properties": {}, 
            "geometry": {
                "type": "Point", 
                "coordinates": [-71.0771, 42.3599]
            }
        }, 
        {
            "type": "Feature", 
            "properties": {}, 
            "geometry": {
                "type": "Point", 
                "coordinates": [-71.0771, 42.3610]
            }
        }
    ]
}
customLayer = {
    "id": "specialdata",
    "maptype": "mapbox", 
    "order": 1,
    "type": "circle",
    "source": {
        "type": "geojson",
        "data": custompt
    },
    "paint": {
        "circle-color": "rgba(0,0,255,0.85)", 
        "circle-radius": 20
    },
    "layout": {}
}

# %%
display(homesdf)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;d93caff4&quot;, &quot;command&quot;: &quot;display(homesdf,cell_id=&apos;DA7DAA2542B54964896C1ED022284A3D&apos;,nostore_pixiedust=&apos;true&apos;,kind=&apos;choropleth&apos;,keyFields=&apos;LATITUDE,LONGITUDE&apos;,aggregation=&apos;SUM&apos;,rowCount=&apos;500&apos;,handlerId=&apos;mapView&apos;,valueFields=&apos;BEDS&apos;,mapboxtoken=&apos;pk.eyJ1IjoibWFwYm94IiwiYSI6ImNpejY4M29iazA2Z2gycXA4N2pmbDZmangifQ.-g_vE53SD2WrJ6tFX7QHmA&apos;,legend=&apos;true&apos;,nostore_cw=&apos;1098&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;options&quot;: {&quot;nostore_bokeh&quot;: &quot;false&quot;, &quot;kind&quot;: &quot;choropleth&quot;, &quot;cell_id&quot;: &quot;DA7DAA2542B54964896C1ED022284A3D&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;showchrome&quot;: &quot;true&quot;, &quot;aggregation&quot;: &quot;SUM&quot;, &quot;legend&quot;: &quot;true&quot;, &quot;rowCount&quot;: &quot;500&quot;, &quot;handlerId&quot;: &quot;mapView&quot;, &quot;valueFields&quot;: &quot;BEDS&quot;, &quot;keyFields&quot;: &quot;LATITUDE,LONGITUDE&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;mapboxtoken&quot;: &quot;pk.eyJ1IjoibWFwYm94IiwiYSI6ImNpejY4M29iazA2Z2gycXA4N2pmbDZmangifQ.-g_vE53SD2WrJ6tFX7QHmA&quot;}}">
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-d93caff4" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#   <div id="pixiedust-output-wrapper-d93caff4" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menud93caff4-dataframe" title="DataFrame Table">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menud93caff4-dataframe').on('click',
#
#
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTMLd93caff4');
#         if (n.length == 0 ){
#             n = $('#wrapperHTMLd93caff4');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="DA7DAA2542B54964896C1ED022284A3D".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#executiond93caff4");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#
#                         if(curCell&&curCell.output_area&&curCell.output_area.outputs){
#                             setTimeout(function(){
#                                 var data = JSON.parse(JSON.stringify(content.data));
#                                 if(!!data["text/html"])data["text/html"]=html;
#                                 function savedData(data){
#
#                                     var markup='<style type="text/css">.pd_warning{display:none;}</style>';
#                                     markup+='<div class="pd_warning"><em>Hey, there\'s something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>';
#                                     nodes = $.parseHTML(data["text/html"], null, true);
#                                     var s = $(nodes).wrap("<div>").parent().find(".pd_save").not(".pd_save .pd_save")
#                                     s.each(function(){
#                                         var found = false;
#                                         if ( $(this).attr("id") ){
#                                             var n = $("#" + $(this).attr("id"));
#                                             if (n.length>0){
#                                                 found=true;
#                                                 n.each(function(){
#                                                     $(this).addClass("is-viewer-good");
#                                                 });
#                                                 markup+=n.wrap("<div>").parent().html();
#                                             }
#                                         }else{
#                                             $(this).addClass("is-viewer-good");
#                                         }
#                                         if (!found){
#                                             markup+=$(this).parent().html();
#                                         }
#                                     });
#                                     data["text/html"] = markup;
#                                     return data;
#                                 }
#                                 curCell.output_area.outputs.push({"data": savedData(data),"metadata":content.metadata,"output_type":msg_type});
#                             },2000);
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigured93caff4" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <script>
#   window.iframeLoaded = window.iframeLoaded || function(iframe) {
#     try {
#       iframe.contentWindow["triggerPDEvent"] = function(eventInfo) {
#         $(document).trigger('pd_event', eventInfo);
#       }
#     } catch (e) {
#       console.log(e)
#     }
#   }
# </script>
# <iframe style="width:878.4px;height:658.8px" srcdoc="<!DOCTYPE html><html lang=&quot;en&quot;><head>    <meta charset=&quot;UTF-8&quot;>    <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;>    <title>Pixiedust Mapbox map</title>    <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v0.32.1/mapbox-gl.js&quot;></script>    <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v0.32.1/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />    <style>    .mapboxgl-popup {        max-width: 200px;    }    .mapboxgl-popup-content h3 {         margin: 2px 0 2px 0;        font-style: italic;    }    #map canvas {        cursor: crosshair;    }    .legend {        background-color: rgba(255,255,255, 0.75);        border-radius: 3px;        position: absolute;        left: calc(100% - 172px);        top: 14px;        box-shadow: 0 1px 2px rgba(0,0,0,0.10);        font-size: 12px;        line-height: 18px;        padding: 10px;        z-index: 1;    }    .legend h4 {        margin: 0 0 10px;    }    .legend div span {        border-radius: 50%;        display: inline-block;        height: 10px;        margin-right: 5px;        width: 10px;    }    body {         background-color:#333;         margin:0px !important;         overflow: hidden;        font-family: &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif;    }    </style></head><body><div id=&quot;mapd93caff4&quot; style=&quot;width:calc(878.4px - 4px);height:calc(658.8px - 4px)&quot; ></div><div id=&quot;maplegend&quot; class=&quot;legend&quot;>            <h4>BEDS</h4>                <div><span style=&quot;background-color: #ffffcc&quot;></span>1</div>                <div><span style=&quot;background-color: #a1dab4&quot;></span>3.0</div>                <div><span style=&quot;background-color: #41b6c4&quot;></span>4.0</div>                <div><span style=&quot;background-color: #2c7fb8&quot;></span>5.0</div>                <div><span style=&quot;background-color: #253494&quot;></span>58</div>            </div><script>    var comment = &quot;&quot;;    mapboxgl.accessToken=&quot;pk.eyJ1IjoibWFwYm94IiwiYSI6ImNpejY4M29iazA2Z2gycXA4N2pmbDZmangifQ.-g_vE53SD2WrJ6tFX7QHmA&quot;;    var map = new mapboxgl.Map({        container: &quot;mapd93caff4&quot;,        style: &quot;mapbox://styles/mapbox/light-v9&quot;    });    var popup = new mapboxgl.Popup({closeButton: false,closeOnClick: true});        map.on(&quot;mousemove&quot;, function (e) {        var fs = map.queryRenderedFeatures(e.point,{layers:[&quot;pxlayer&quot;]});        map.getCanvas().style.cursor=(fs.length)?&quot;pointer&quot;:&quot;&quot;;        if (!fs.length) {popup.remove();return;};        popuphtml = &quot;&quot;;        fs.forEach(function(f){            var keylength = Object.keys(f.properties).length;            for (var key in f.properties) {                popuphtml += &quot;<hr>\n&quot;;                popuphtml += &quot;<h3>&quot;+f.layer.id.toUpperCase()+&quot;</h3>\n&quot;;                popuphtml += &quot;<b>&quot;+key+&quot;: </b> &quot;+f.properties[key]+&quot;<br/>\n&quot;;            }        });        popup.setLngLat(e.lngLat).setHTML(popuphtml).addTo(map);    });                map.on(&quot;load&quot;, function() {        var mapdata={&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-71.224498699999998, 42.213987299999999]}, &quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;BEDS&quot;: 4}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-70.869932000000006, 42.214190000000002]}, &quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;BEDS&quot;: 4}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-71.2199119, 42.214221000000002]}, &quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;BEDS&quot;: 4}}, {&quot;geom ...

# %%
from pixiedust.display.app import *
from pixiedust.utils.shellAccess import ShellAccess
import geojson

# %%
@PixieApp
class MapboxUserLayers:
    
    @route()
    def main(self):
        self.USERLAYERS = []
        for key in ShellAccess:
            v = ShellAccess[key]
            if isinstance(v, dict) and "source" in v and "type" in v["source"] and v["source"]["type"] == "geojson" and "id" in v and "paint" in v and "layout" in v and "data" in v["source"]:
#                 gj = geojson.loads(v["source"]["data"])
#                 isvalid = geojson.is_valid(gj)
#                 if isvalid["valid"] == "yes":
                self.USERLAYERS.append(v)
#                 else:
#                     print("Invalid GeoJSON: {0}".format(str(v["source"]["data"])))

        return """<pre>{% for layer in this.USERLAYERS %}
        var layertype = "circle";
        {% if layer["type"] %}
        layertype = "{{layer["type"]}}";
        {%endif%}

        var layerpaint = "{}";
        {% if layer["paint"] %}
        layerpaint = "{{layer["paint"]}}";
        {%endif%}

        var layerlayout = "{}";
        {% if layer["layout"] %}
        layerlayout = "{{layer["layout"]}}";
        {%endif%}

        map.addLayer({
            "id": "{{layer["id"]}}", 
            "type": layertype, 
            "source": {{layer["source"]}},
            "paint": layerpaint, 
            "layout": layerlayout
        });
        {% endfor %}</pre>
"""

# %%
mbl = MapboxUserLayers()
mbl.run()

# %% [markdown]
# ## Notes

# %%
# %pixiedustLog -l debug
